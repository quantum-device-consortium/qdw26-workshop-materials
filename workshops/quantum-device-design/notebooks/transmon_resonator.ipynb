# %% [markdown]
# > ## ⚠️ Running this notebook in the Docker workshop image?
# >
# > These notebooks were written assuming a **local install with a display**
# > — every cell with `MetalGUI(design)` or `gui.screenshot()` requires Qt
# > with a working X server, which the Docker image does not have.
# >
# > **In Docker, do this instead:**
# > - Replace `gui = MetalGUI(design)` with nothing (skip the GUI cell).
# > - Replace `gui.rebuild(); gui.screenshot()` with `qm.view(design)` — it
# >   returns a `matplotlib.figure.Figure` and renders inline in JupyterLab,
# >   no Qt required. Same code-path the chip exports use.
# > - The chip design, simulation, and analysis cells are unchanged.
# >
# > If you want the full Qt GUI, run **outside** Docker: `pip install
# > 'quantum-metal[full]'` on your local machine, open this notebook in
# > Jupyter, and `MetalGUI(design)` will work.

# %% [markdown]
# # Designing Small-Scale Devices with **Qiskit Metal** Designs, **palace** and **SQDMetal**

# %% [markdown]
# **Author: Murat Can Sarihan, PhD, Research Scientist, Google Quantum AI**
#
# Thanks to the contributors, Zlatko Minev, Sadman Ahmed Shanto and Eli Levenson-Falk.

# %% [markdown]
# This tutorial explores the simulation of [Qiskit Metal](https://github.com/qiskit-community/qiskit-metal)  `design` objects using `palace`, facilitated by `SQDMetal`. The design of quantum devices, the foundation of the quantum ecosystem, is a multi-step process. Qiskit Metal endeavors to simplify and organize this undertaking.
#
# **About Qiskit Metal**
#
# [Qiskit Metal](https://github.com/qiskit-community/qiskit-metal)
#  \( [docs here](https://qiskit-community.github.io/qiskit-metal/index.html), [tutorials here](https://qiskit-community.github.io/qiskit-metal/tut/index.html)  \)  aims to provide a community-driven platform for quantum chip development, from concept to layout to electromagentics to Hamiltonians and to fabrication, within an open framework. It aims to foster innovation and make the design of quantum devices more accessible.  By automating and building in best practices, testing on real devices, Metal aims to make quantum hardware modeling more straightforward, reduce errors, and improve design speed.  It was started and led by Zlatko Minev, developed with the IBM Qiskit Metal team and many open-source contributors. It employs the permissive Apache 2.0 license and is now a community-maintained open-source package.
#
#  The [Qiskit Metal tutorials](https://qiskit-community.github.io/qiskit-metal/tut/index.html) and [20+ videos on YouTube](https://www.youtube.com/playlist?list=PLOFEBzvs-VvqHl5ZqVmhB_FcSqmLufsjb) offer a good starting point for exploration.
#
# **Contributing to the Future of Device Design**
#
# The continued development of Qiskit Metal relies on its community. If you have an interest in quantum hardware and wish to contribute, consider becoming a maintainer or exploring funding opportunities. We invite you to the **Quantum Metal and device design session**. This will be a discussion with Zlatko Minev, Eli Levenson-Falk, and other key figures in the Metal community about its future, the formation of a board of directors, and a maintainer group. If contributing to this effort interests you, we encourage you to connect at this workshop and **join the Thursday workshop on the future of Metal.**
#
#
# **What This Tutorial Covers**
#
# Here, we will walk through electrostatic and eigenmode simulations of a qubit-cavity system. We will use `palace`, an open-source finite element analysis tool, through the `SQDMetal` interface. While Qiskit Metal also supports other tools like Elmer, this guide focuses on the `palace` integration.
#
# We will learn to:
# 1.  Define a qubit-cavity system in Qiskit Metal.
# 2.  Prepare this design for simulation with `SQDMetal`.
# 3.  Run electrostatic simulations in `palace` to examine charge distributions and capacitances.
# 4.  Conduct eigenmode simulations in `palace` to find resonant frequencies and mode profiles.
# 5. Discuss different coupling schemes between two qubits for larger-scale quantum devices
#
# This tutorial aims to provide a working knowledge of how these open-source tools can be combined for the analysis of superconducting quantum circuits, helping to reveal the underlying physics at play.
#
# **Requirements:**
#
# * [ ] Ensure that [`SQDMetal`](https://github.com/sqdlab/SQDMetal) is installed in your environment. This package includes installation of Qiskit Metal.
# * [ ] Ensure that [`palace`](https://github.com/sqdlab/palace) is installed in your environment. Instructions are [here](https://lfl-lab.github.io/SQuADDS/source/resources/palace.html).
#
# Let us begin the exploration.

# %%
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy = True
# %matplotlib inline
# %config Completer.use_jedi = False
# %config InlineBackend.figure_format = 'svg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.environ['QISKIT_METAL_HEADLESS'] = 'True'

import qiskit_metal as metal
# ... the rest of your imports
from qiskit_metal.analyses.hamiltonian.transmon_charge_basis import Hcpb
from qiskit_metal.analyses.hamiltonian.transmon_CPB_analytic import Hcpb_analytic
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


import scqubits as scq
from scqubits import HilbertSpace, InteractionTerm, ParameterSweep

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
import pyEPR as epr
from qiskit_metal.qlibrary.couplers.tunable_coupler_01 import TunableCoupler01

from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent
import qiskit_metal.analyses.quantization.lumped_capacitive as lumped_cap
import qiskit_metal.analyses.quantization.lumped_oscillator_model as lom_func
from collections import OrderedDict
# from squadds.components.qubits import TransmonCross
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
# from squadds.components.airbridge.airbridge_generator import AirbridgeGenerator
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee

import numpy as np
import matplotlib.pyplot as plt
from SQDMetal.Comps.Xmon import Xmon
from SQDMetal.Comps.Junctions import JunctionDolanPinStretch
from SQDMetal.Comps.Capacitors import CapacitorProngPin
from SQDMetal.Utilities.Materials import MaterialInterface


hbar = 6.62607015e-034 / (2 * np.pi)  # J.s
flux_0 = hbar * np.pi / 1.6e-19   # J.s / phi_0

# %%
# Define path to the Palace executable
# Auto-discover the palace executable — works inside the workshop's docker
# image (palace is on PATH via spack) and on local installs where palace is
# in $PATH. If you have it elsewhere, replace this with the explicit path.
import shutil
path_to_palace = shutil.which("palace")
if path_to_palace is None:
    raise RuntimeError(
        "palace executable not found on PATH. "
        "If using the workshop Docker image you should not hit this — "
        "check 'docker compose exec dev which palace'. "
        "If running locally, set path_to_palace='/your/path/to/palace' here."
    )

# %% [markdown]
# # Transmon + Resonator System

# %% [markdown]
# Let's start discussing how a transmon qubit electrically look like. We can essentially identify a transmon qubit system with its control and readout system as a lumped electrical circuit. Below, we used a nice visualization package called "schemdraw" to draw an example transmon circuit.

# %%
# Install schemdraw if you haven't already: 
# !pip install schemdraw
# Out:
# Collecting schemdraw
#   Downloading schemdraw-0.22-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: schemdraw
# Successfully installed schemdraw-0.22

# %%
import schemdraw
import schemdraw.elements as elm
import schemdraw.flow as flow

# %%
# Create a new drawing
d = schemdraw.Drawing()

# --- Define Nodes ---
bottom_node = (0,0) # Common ground node

# --- Draw the Transmon (Qubit) Circuit ---
# Drawing the charge line
d += elm.Ground().at(bottom_node)
d += elm.Line().up().length(0.5)
d += elm.SourceV().up().label('$V_g$')
d += elm.Capacitor().right().label('$C_g$')

# Drawing the qubit circuit
charge_node = d.here
d += elm.Line().down().length(0.5)
junction_node = d.here
d += elm.Line().left().length(1)
d += elm.Josephson().down().label('$E_J, C_J$')
d += elm.Line().right().length(1)
d += elm.Line().right().length(1).at(junction_node)
d += elm.Capacitor().down().label('$C_B$')
d += elm.Line().left().length(1)
d += elm.Ground()
d += elm.Line().right().length(0.5).at(charge_node)
d += elm.Capacitor().right().label('$C_{qr}$')

# Drawing the resonator circuit
d += elm.Line().down().length(0.5)
resonator_node = d.here
d += elm.Line().left().length(1)
d += elm.Inductor().down().label('$L_r$')
d += elm.Line().right().length(1)
d += elm.Line().right().length(1).at(resonator_node)
d += elm.Capacitor().down().label('$C_r$')
d += elm.Line().left().length(1)
d += elm.Ground()
d.draw()

# %% [markdown]
# A basic structure for a single qubit system can be drawn as above. We have the transmon at the center of the circuit, defined by the parallel branch of Josepshon junction and a shunting capacitor. We have added a capacitively-coupled control line to the left, which creates charge fluctuations on our qubit. In order to readout the quantum state of the qubit, we have coupled our qubit to a resonator, which is modeled as an LC resonator capacitively coupled from the right. We will use the dispersive readout concepts we learned throughout the workshop to design our readout circuit.
#
# Our first task is determining the properties of our transmon. We will start with designing the Hamiltonian of the transmon.
# The transmon Hamiltonian is given by:
#
# $$
# \hat{H}=4E_{C}\left(\hat{n}-n_{g}\right)-E_{J}\cos\left(\hat{\phi}\right)\,,
# $$
#
# where $E_{C}$ is the charging energy, $E_{J}$ is the Josephson energy, $\hat n$ is the number of Cooper pairs transferred between charge islands, $\hat{\phi}$ is the phase difference between charge islands, and $n_{g}$ is effective offset charge of the device. Expressions for the charging energy, Josephson energy and offset charge can be written as:
#
# $$
# E_{C}=\frac{e^{2}}{2C_{\Sigma}}\,,\qquad n_{g}=-\frac{C_{d}\dot{\Phi}_{s}\left(t\right)}{2e}\:,\qquad E_{J}=\frac{\phi_{0}^{2}}{L_{J}}\,,
# $$
#
# where $C_{\Sigma} = C_{J}+C_{B}+C_{g}$ (the sum of the Josephson capacitance, shunting capacitance and gate capacitance), $L_{J}$ is the inductance of the Josephson junction, and $\phi$ is the magnetic flux.
#
# The  are
# $$
# \hat{\phi}\equiv\frac{\hat{\Phi}}{\phi_{0}},\qquad\hat{n}\equiv\frac{\hat{Q}}{2e}\,,
# $$
#
# Observe that $\hat \phi$ and $\hat n$ are both dimensionless, and they obey the commutation relationship:
#
# $$
# [\hat{\phi}, \hat{n}] = i
# $$
#
#
# Using the operator relations above, we can write the transmon Hamiltonian in the charge ($\hat n$) basis as given below, where $\hat{n} = \sum_{n=-\inf}^{\inf} |n\rangle\langle n|$:
#
# $$H=4E_\text{C}(\hat{n}-n_g)^2-\frac{1}{2}E_\text{J}\sum_n(|n\rangle\langle n+1|+\text{h.c.}),$$
#
#
# Writing the transmon Hamiltonian this way will help us to easily diagonalize the Hamiltonian and extract our qubit resonances.

# %% [markdown]
# ### Charge Dispersion

# %% [markdown]
# Let's model the hamiltonian to see how the energy structure looks like. For this purpose, we can either use the Hcpb (Hamiltonian - Cooper Pair Box) class within Qiskit Metal, or we can use the open source scqubits package.
#
# Let's start by defining the range of offset charge from -2.0 to +2.0 and also by defining a normalization for the eigenvalues, which will be the transition energy between the first two states evaluated at the degeneracy point where ng=0.5. For this exercise, first we'll take Josephson Energy to be equal to the charging energy and then we will check how our system behaves for different Josephson energies.

# %%
# Define the charging energies to iterate over
ng = np.linspace(-2.0,2.0,101) # this represents the charging energy (ng)
E_c = 220
E_j_values = [E_c * 1, E_c * 10, E_c*50]
# Create a figure with subplots
fig, axes = plt.subplots(1, len(E_j_values), figsize=(15, 5))

# Iterate over the charging energies
for ax_idx, E_j in enumerate(E_j_values):
    epsilon0, epsilon1, epsilon2, epsilon3 = [], [], [], []
    # Calculate charge dispersion for each Ej/Ec ratio
    for i in ng:
        H = Hcpb(nlevels=10, Ej=E_j, Ec=E_c, ng=i)
        H_norm = Hcpb(nlevels=2, Ej=E_j, Ec=E_c, ng=0.5)
        norm = H_norm.fij(0,1) # normalization constant
        epsilon0.append(H.evalue_k(0)/norm)
        epsilon1.append(H.evalue_k(1)/norm)
        epsilon2.append(H.evalue_k(2)/norm)
        epsilon3.append(H.evalue_k(3)/norm)
    floor = min(epsilon0)
    # Plot the charge dispersion on the current subplot
    ax = axes[ax_idx]
    ax.plot(ng, epsilon0-floor, 'k', label="m=0")
    ax.plot(ng, epsilon1-floor, 'b', label="m=1")
    ax.plot(ng, epsilon2-floor, 'r', label="m=2")
    ax.plot(ng, epsilon3-floor, 'g', label="m=3")
    ax.set_xlabel("$n_g$")
    ax.set_ylabel("Em/E01")
    ax.set_title(f"Ej/Ec = {E_j/E_c}")
    ax.legend(title="Energy Level", loc='upper right')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# In the figures above, we see that the change in the frequency with the offset charges reduce with increasing $E_J/E_C$ ratio. This is very important for the coherence of our qubits, since the charge noise present in your environment would couple to your qubit anytime and cause frequency fluctuations. These frequency fluctuations cause incoherence for your qubits.

# %% [markdown]
# As we see here, for a transmon with equal inductive and capacitive energy, we observe huge swings in frequency with the gate charge, which is called charge dispersion.The peak-to-peak value of the charge dispersion for the mth energy level is given by the expression: $\epsilon_{m} = E_{m}(n_{g}=0.5) - E_{m}(n_{g}=0.0)$. We can plot $\epsilon_{m}/E_{01}$ as a function of $E_{J}/E_{C}$ for the first few energy levels.
#
# We can start by defining a value of charging energy and creating empty lists for $\epsilon_{0}$ through $\epsilon_{4}$:

# %%
E_c=220.0 # charging energy 
epsilon0, epsilon1, epsilon2, epsilon3 = [], [], [], []    # charge dispersion for m=0 through m=4
x = np.linspace(1,140,101)           # this this ratio of Ej/Ec which will go on the x-axis.

# %% [markdown]
# Next, we simply evaluate the expression given above for $\epsilon_{m}$ based on $E_{m}$ and $E_{0}$. We use two separate Hamiltonians to do this; one evaluated at $n_{g}=0.5$ and one evaluated at $n_{g}=0.0$. We also normalize by the transition energy between the lowest two states evaluated at the degeneracy point ($E_{01}$.) Finally, we populate the lists each $\epsilon_{m}$.

# %%
for i in x:
    E_j = i*E_c 
    H_zero = Hcpb(nlevels=15, Ej=i*E_c, Ec=E_c, ng=0.0)
    H_half = Hcpb(nlevels=15, Ej=i*E_c, Ec=E_c, ng=0.5)
    
    H_norm = Hcpb(nlevels=15, Ej=i*E_c, Ec=E_c, ng=0.5)
    norm = H_norm.fij(0,1)                         # normalization constant 
    
    epsilon0.append(abs(H_half.evalue_k(0) - H_zero.evalue_k(0))/norm)
    epsilon1.append(abs(H_half.evalue_k(1) - H_zero.evalue_k(1))/norm)
    epsilon2.append(abs(H_half.evalue_k(2) - H_zero.evalue_k(2))/norm)
    epsilon3.append(abs(H_half.evalue_k(3) - H_zero.evalue_k(3))/norm)

# %% [markdown]
# We can plot these values to see the exponential decrease in the charge dispersion with increasing $E_{J}/E_{C}$. The important feature of a transmon qubit is insensitivity to the charge noise due to large $E_J/E_C$ ratio. This is ensured by adding a parallel capacitance $C_B$ to the josephson junction.

# %%
plt.plot(x, epsilon0, 'k', label="m=0")
plt.plot(x, epsilon1, 'b', label="m=1")
plt.plot(x, epsilon2, 'r', label="m=2")
plt.plot(x, epsilon3, 'g', label="m=3") 
plt.yscale("log")
plt.xlabel("EJ/Ec")
plt.ylabel("Epsilon/E01")
plt.legend(title="Energy Level", loc='upper right')

# %% [markdown]
# Now, let's use another useful package called scqubits to calculate our transmon qubit frequencies. scqubits will help us to diagonalize our hamiltonian and extract the resonance of the qubit

# %%
import scqubits as scq

qubit = scq.Transmon(
    EJ=18, # GHz, Josephson energy
    EC=0.18, # GHz, charging energy
    ng=0.001, # offset charge
    ncut=40, # number of levels to consider
    truncated_dim=4     # after diagonalization, we will keep 3 levels
)
evals = qubit.eigenvals(evals_count=12)
frequency_q = (evals[1] - evals[0])
print(f"Frequency of 01 transition = {(evals[1] - evals[0])* 1000:.0f} MHz")
print(f"Anharmonicity = {((evals[2] - evals[1]) - (evals[1] - evals[0]))* 1000:.0f} MHz")
# Out:
# Frequency of 01 transition = 4904 MHz
# Anharmonicity = -197 MHz

# %% [markdown]
# We set our qubit to have an $E_J/E_C$ ratio of 100. Let's have a look at how our qubit wavefunction looks like in terms of charge and flux basis.

# %%
#Plot the wavefunction in charge and flux basis
qubit.plot_n_wavefunction()
qubit.plot_phi_wavefunction(which=[0,1,2], mode='real')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %% [markdown]
# As we see, our qubit wavefunction is highly delocalized in the charge basis, while it is localized in flux basis within the cosine potential due to Josephson junction. This delocalization helps us to be independent from the offset gate charge fluctuations.

# %%
#Again, we can plot the eigenvalues as a function of gate charges to get an idea of charge dispersion.
ng_list = np.linspace(-2, 2, 220)
qubit.plot_evals_vs_paramvals('ng', ng_list, evals_count=6, subtract_ground=True);
# Out:
# Spectral data:   0%|          | 0/220 [00:00<?, ?it/s]

# %% [markdown]
# As we see from the wavefunction in the flux basis, we can identify our transmon as a weakly anharmonic oscillator in flux basis and diagonalize the Hamiltonian to obtain our energy eigenstates in terms of ladder operations $\hat{b}$ and $\hat{b}^{\dag}$, i.e. number of excitations.
#
# In this case, our Hamiltonian becomes:
#
# $$
# \hat{H}= \hbar\omega_q \hat{b}^{\dag}\hat{b}-\frac{E_C}{2} \hat{b}^{\dag}\hat{b}^{\dag}\hat{b}\hat{b}
# $$
# where, $\hbar\omega_q = \sqrt{8E_CE_J}-E_C$, which corresponds to the transition frequency between ground and first excited state. This transition is where quantum states are logically assigned.
#
# The second component of the Hamiltonian depends on number of excitations present, which changes the transition frequency between higher excited states. This term is what makes our transmon oscillator anharmonic, where transition frequencies between each level are different from each other. The anharmonicity(or qubit nonlinearity) $\alpha$ is approximately equal to $E_C$, and helps us to distinguish between different qubit transitions, which is important for high-fidelity control of the qubits and prevent leakage to higher order transitions.
#
# While designing a qubit, the important considerations are:
# - Determine $E_J$ and $E_C$ according to the desired qubit frequency
# - Having a large enough $E_J/E_C$ ratio to suppress the effects of charge noise
# - Finally, having an appropriate $E_C$ (~100-400 MHz) to achieve better control and prevent leakage.
#
# In summary, the $E_J$ and $E_C$ values are not independent from each other and should be carefully determined according to the qubit frequency regime desired for operation. Let's use the transmon parameters we used to simulate with scqubits to design our device.

# %%
import qiskit_metal.analyses.quantization.lumped_capacitive as lumped_cap
E_c = 0.18 # charging energy # GHz
E_j = 18 # Josephson energy
C_shunt  = lumped_cap.Cs_from_Ec(hbar*2*np.pi*E_c*1e9)  # input in Joules, thus multiplied by Planck's constant
I_junction = lumped_cap.Ic_from_Ej(hbar*2*np.pi*E_j*1e9) #input in Joules, thus multiplied by Planck's constant
L_junction = flux_0 / (2 * np.pi * I_junction) # in H
print(f"Shunt capacitance = {C_shunt*1e15:.2f} fF")
print(f"Junction critical current = {I_junction*1e9:.2f} nA")
print(f"Junction inductance = {L_junction*1e9:.2f} nH")
# Calculate the ratio of EJ/EC
print(f"EJ/EC = {E_j/E_c:.2f}")
# Out:
# Shunt capacitance = 107.61 fF
# Junction critical current = 36.26 nA
# Junction inductance = 9.09 nH
# EJ/EC = 100.00

# %% [markdown]
# ## Tunable Transmon

# %% [markdown]
# State of the art transmon devices are designed to have a tunable frequency, in order to be able to tune qubit properties to have best coherence, or to bring two qubits in resonance for achieving high-fidelity two qubit gate operations. For this purpose, the single Josephson Junction in transmon is replaced by a SQUID loop of two parallel Josephson Junctions. Such a qubit can be tuned by applying an external magnetic field within the loop.
#
# The flux sensitivity of tunable transmons can be reduced at the expense of tunable range, which improves coherence of the qubit under the presence of flux noise.
#
# The Hamiltonian of a tunable transmon becomes :
#
# $$
# H = 4E_C\hat{n}^2 - E_{J\Sigma}\sqrt{cos^2(\phi_{ext})+ d^2 sin^2(\phi_{ext})} cos(\phi)
# $$
# where $E_{J\Sigma} = E_{J1} + E_{J2}$ and $ d = E_{J1} - E_{J2}/E_{J\Sigma}$. Thus we can treat this Hamiltonian as a single-junction transmon with effective Josepshon energy of $E_{J\Sigma}\sqrt{cos^2(\phi_{ext})+ d^2 sin^2(\phi_{ext})}$. The Josephson energy is controlled by the external flux $\phi_{ext}$.

# %%
tune_tmon = scq.TunableTransmon(
    EJmax=18,
    EC=0.18,
    d=0.15,
    flux=0.0,
    ng=0.0,
    ncut=40
)

flux_list = np.linspace(-1.1, 1.1, 220)
tune_tmon.plot_evals_vs_paramvals('flux', flux_list, subtract_ground=True);
# Out:
# Spectral data:   0%|          | 0/220 [00:00<?, ?it/s]

# %% [markdown]
# # Capacitance simulation of the qubit

# %% [markdown]
# Let's start designing our qubit and simulating our qubit capacitances to obtain desired parameters using Palace. In this workshop, we will be using transmon-cross (Xmon) geometry to realize the transmon we have designed. There are other physical realizations for transmons that can be used for the same purpose.

# %%
design = designs.DesignPlanar({}, overwrite_enabled=True)
design.delete_all_components()
gui = MetalGUI(design)


# Set up chip dimensions 
design.chips.main.size.size_x = '2.4mm'
design.chips.main.size.size_y = '2.4mm'
design.chips.main.size.size_z = '-280um'
design.chips.main.size.center_x = '0mm'
design.chips.main.size.center_y = '-1mm'

# Resonator and feedline gap width (W) and center conductor width (S) 
design.variables['cpw_width'] = '10 um' #S
design.variables['cpw_gap'] = '6 um' #W 
# Lets create the qubit with a junction and a claw

### Qubit
# Qubit
xmon = Xmon(design, 'xmon', options=Dict(pos_x = '0', pos_y='-1',
                                    vBar_width='50um', hBar_width='50um', vBar_gap=f'{50}um', hBar_gap=f'{50}um',
                                    cross_width=f'{320}um', cross_height=f'{320}um',
                                    gap_up='40um', gap_left='40um', gap_right='40um', gap_down='40um'))

# Junction
JunctionDolanPinStretch(design, 'junction', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'xmon',pin='right')),
                                                         dist_extend='40um',
                                                         layer=2,
                                                         finger_width='0.4um', t_pad_size='0.385um',
                                                         squid_width='5.4um', prong_width='0.9um'))


# Claw
CapacitorProngPin(design, 'claw', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'xmon',pin='up')),
                                                prong_width='10um', prong_length='20um', pin_gap_side='10um',
                                                gap_side='20um', pad_thickness='20um',
                                                gap_front='20um', gap_back='20um', trace_width='10um'))

# Check the design
# rebuild the GUI
design.rebuild()
gui.rebuild()
gui.autoscale()
gui.screenshot('sims/xmon.png')
# Out:
# 12:14AM 44s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: Populating font family aliases took 103 ms. Replace uses of missing font family "Courier" with one that exists to avoid this cost.

# %%
from SQDMetal.PALACE.Capacitance_Simulation import PALACE_Capacitance_Simulation
# Define the options for the simulation
user_defined_options = {
                "mesh_refinement": 0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                "solver_order": 1,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                "solver_tol": 1.0e-8,                              #error residual tolerance for iterative solver
                "solver_maxits": 500,                              #number of solver iterations
                "mesh_max": 120e-6,                                #maxiumum element size for the mesh in mm
                "mesh_sampling": 150,                              #number of points to mesh along a geometry
                "fillet_resolution":12,                            #number of vertices per quarter turn on a filleted path
                "num_cpus": 10,                                      #number of CPU cores to use for simulation
                "palace_dir":path_to_palace
                }

# %%
# initialize the meshing environment
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"

import gmsh
gmsh.initialize()

os.makedirs('sims', exist_ok=True)
# Out:
# Warning : Gmsh has aleady been initialized

# %%
#Create the Palace Eigenmode simulation
cap_sim = PALACE_Capacitance_Simulation(name = 'transmon_cross_cap_sim',                                 #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "sims/",            #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                             #choose simulation mode 'HPC' or 'simPC'
                                        meshing = 'GMSH',                                           #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        view_design_gmsh_gui = False,                               #view design in GMSH gui
                                        create_files = True,
                                        )                                        #create mesh, config and HPC batch files
# adding metallic and ground planes
cap_sim.add_metallic(1, threshold=1e-10, fuse_threshold=1e-10)
cap_sim.add_ground_plane(threshold=1e-10)

# %%
# Retrieve the bounds of the qubit area for finer meshing
bounds = design.components["xmon"].qgeometry_bounds()
bounds
# Out:
# array([-0.2, -1.2,  0.2, -0.8])

# %%
#Fine-mesh the transmon cross qubit region
cap_sim.fine_mesh_in_rectangle(bounds[0]*1e-3, bounds[1]*1e-3, bounds[2]*1e-3, bounds[3]*1e-3, mesh_sampling=100, mesh_min=1e-6, mesh_max=50e-3)

# %%
# prepare the simulation files
cap_sim.prepare_simulation()

# %%
# The order of the components in this figure will help us to identify the indices of the capacitance matrix
cap_sim.display_conductor_indices()

# %%
cap_matrix = cap_sim.run()
# Out:
# >> /opt/homebrew/bin/mpirun -n 10 /Users/mcansarihan/qubit_design/palace/build/bin/palace-arm64.bin transmon_cross_cap_sim.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: v0.13.0-454-gcd4d7b78
# Running with 10 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 16 elements in 1 iterations of local bisection for under-resolved interior boundaries
# Added 2387 duplicate vertices for interior boundaries in the mesh
# Added 5178 duplicate boundary elements for interior boundaries in the mesh
# Added 520 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 10 subdomains
#
# Characteristic length and time scales:
#  L₀ = 2.880e-03 m, t₀ = 9.607e-03 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-1.440e-03, -2.440e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+1.440e-03, +4.400e-04, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices          1305        1608        2231       16081
#  edges             9155       10016       11827      100167
#  faces            15316       16109       17417      161096
#  elements          7479        7700        7874       77007
#  neighbors            7           8           9
#
#             minimum     maximum
#  h       0.00233395   0.0768152
#  kappa      1.04237     7.71192
#
# Configuring Dirichlet BC at attributes:
#  7, 1-3
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 16081, ND (p = 1): 100167, RT (p = 1): 161096
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 16081 unknowns
#
# Computing electrostatic fields for 3 terminal boundaries
#
# It 1/3: Index = 1 (elapsed time = 1.67e-07 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 1.332296e+01
#   1 KSP residual norm ||r||_B = 9.478677e-01
#   2 KSP residual norm ||r||_B = 1.638306e-01
#   3 KSP residual norm ||r||_B = 3.036733e-02
#   4 KSP residual norm ||r||_B = 5.947244e-03
#   5 KSP residual norm ||r||_B = 1.119570e-03
#   6 KSP residual norm ||r||_B = 2.116346e-04
#   7 KSP residual norm ||r||_B = 3.850903e-05
#   8 KSP residual norm ||r||_B = 7.452232e-06
#   9 KSP residual norm ||r||_B = 1.281856e-06
#  10 KSP residual norm ||r||_B = 2.011533e-07
# PCG solver converged in 10 iterations (avg. reduction factor: 1.404e-01)
#  Sol. ||V|| = 9.188717e+01 (||RHS|| = 6.725833e+01)
#  Field energy E = 4.625e-01 J
#
#  Wrote fields to disk for source 1
#  Updating solution error estimates
#
# It 2/3: Index = 2 (elapsed time = 3.44e-01 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 3.582227e+00
#   1 KSP residual norm ||r||_B = 5.405401e-01
#   2 KSP residual norm ||r||_B = 1.038791e-01
#   3 KSP residual norm ||r||_B = 1.832825e-02
#   4 KSP residual norm ||r||_B = 3.384496e-03
#   5 KSP residual norm ||r||_B = 6.218593e-04
#   6 KSP residual norm ||r||_B = 1.191562e-04
#   7 KSP residual norm ||r||_B = 2.311545e-05
#   8 KSP residual norm ||r||_B = 4.086632e-06
#   9 KSP residual norm ||r||_B = 7.004405e-07
#  10 KSP residual norm ||r||_B = 1.287765e-07
# PCG solver converged in 10 iterations (avg. reduction factor: 1.468e-01)
#  Sol. ||V|| = 4.222382e+01 (||RHS|| = 2.740933e+01)
#  Field energy E = 2.005e-02 J
#
#  Wrote fields to disk for source 2
#  Updating solution error estimates
#
# It 3/3: Index = 3 (elapsed time = 7.29e-01 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 1.187151e+00
#   1 KSP residual norm ||r||_B = 1.431694e-01
#   2 KSP residual norm ||r||_B = 2.369835e-02
#   3 KSP residual norm ||r||_B = 4.555880e-03
#   4 KSP residual norm ||r||_B = 8.188884e-04
#   5 KSP residual norm ||r||_B = 1.551595e-04
#   6 KSP residual norm ||r||_B = 2.555554e-05
#   7 KSP residual norm ||r||_B = 4.768947e-06
#   8 KSP residual norm ||r||_B = 9.443622e-07
#   9 KSP residual norm ||r||_B = 1.765454e-07
#  10 KSP residual norm ||r||_B = 2.954051e-08
# PCG solver converged in 10 iterations (avg. reduction factor: 1.429e-01)
#  Sol. ||V|| = 1.070894e+01 (||RHS|| = 8.257708e+00)
#  Field energy E = 6.663e-03 J
#
#  Wrote fields to disk for source 3
#  Updating solution error estimates
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 4.426e-01, global unknowns = 16081
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.025       0.031       0.028
#   Mesh Preprocessing             0.966       0.968       0.967
# Operator Construction            0.097       0.111       0.105
# Linear Solve                     0.014       0.019       0.016
#   Setup                          0.044       0.045       0.045
#   Preconditioner                 0.068       0.072       0.070
# Estimation                       0.008       0.024       0.015
#   Construction                   0.454       0.456       0.455
#   Solve                          0.368       0.369       0.369
# Postprocessing                   0.082       0.086       0.084
# Disk IO                          0.927       0.930       0.928
# --------------------------------------------------------------
# Total                            3.109       3.127       3.117
#
# Error in plotting: 'Data array (V) not present in this dataset.'

# %%
cdf = pd.DataFrame(cap_matrix*1e15)

# get rid of the first column
cdf = cdf.iloc[:, 1:]

# assigning the columns and indices based on our geometry
cdf.columns = ["ground", "xmon", "claw"]
cdf.index = ["ground", "xmon", "claw"]
cdf = cdf.reindex(index=["ground", "claw", "xmon"], columns=["ground", "claw", "xmon"])
cdf
# Out:
#              ground       claw        xmon
# ground  2455.162393 -16.698079  -67.995531
# claw     -16.698079  35.370860  -16.516659
# xmon     -67.995531 -16.516659  106.447520

# %% [markdown]
# We obtained the Maxwell capacitance matrix for the transmon cross qubit. The values are in femtofarads (fF). This capacitance matrix describe the relationship between total charge on each conductor and conductor voltages, i.e. $Q = Cv$ which are measured with respect to a ground at infinity.
#
# The diagonal elements of the capacitance matrix represent the self-capacitance of each component, while the off-diagonal elements represent the mutual capacitance between components. Off diagonal elements have negative sign since the voltage on mutual capacitances are defined as $V_i-V_j$.
#
# For example, let's start with following:
# $$
# \begin{pmatrix}
# Q_1 \\
# Q_2 \\
# Q_3 \\
# \end{pmatrix}
#  =
# \begin{pmatrix}
# C_{11} & C_{12} & C_{13} \\
# C_{21} & C_{22} & C_{23}  \\
# C_{31} & C_{32} & C_{33} \\
# \end{pmatrix}
# \begin{pmatrix}
# V_1 \\
# V_2 \\
# V_3 \\
# \end{pmatrix}
# $$
#
# For each node, we can define the charges in terms of node voltages.
# $$
# Q_1 = C_{11} V_1 + C_{12}(V_1 - V_2) + C_{13}(V_1 - V_3) \\
# Q_2 = C_{21} (V_2 - V_1) + C_{22} V_2 + C_{23}(V_2 - V_3) \\
# Q_3 = C_{31} (V_3 - V_1) + C_{32}(V_3 - V_2) + C_{33} V_3 \\
# $$
#
# Reorganizing this in terms of voltages would give us the capacitive matrix with negative off-diagonal elements.
# $$
# Q_1 = (C_{11} + C_{12} + C_{13}) V_1 -C_{12} V_2 - C_{13} V_3 \\
# Q_2 = -C_{21} V_1 + (C_{22} + C_{21} + C_{23}) V_2 - C_{23} V_3 \\
# Q_3 = -C_{31} V_1 -C_{32} V_2 + (C_{33} + C_{31} + C_{32}) V_3 \\
# $$
#
#
# The self-capacitance of the transmon cross is 106.33 fF, while the self-capacitance of the claw is 35 fF. The mutual capacitance between the transmon cross and the claw is 16 fF. We will use these values to determine our coupling to the readout and to calculate the qubit frequency.

# %% [markdown]
# ## Eigenmode simulation of the qubit

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"

import gmsh
gmsh.initialize()

# %%
# Define the hyper-parameters for the eigenmode simulation
from SQDMetal.PALACE.Eigenmode_Simulation import PALACE_Eigenmode_Simulation

#Eigenmode Simulation Options
user_defined_options = {
                 "mesh_refinement":  0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                 "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                 "starting_freq": 4e9,                              #starting frequency in Hz 
                 "number_of_freqs":3,                              #number of eigenmodes to find
                 "solns_to_save": 3,                                #number of electromagnetic field visualizations to save
                 "solver_order": 1,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                 "solver_tol": 5.0e-4,                              #error residual tolerance foriterative solver
                 "solver_maxits": 10,                              #number of solver iterations
                 "mesh_max": 120e-3,                                #maxiumum element size for the mesh in mm
                 "mesh_min": 10e-3,                                 #minimum element size for the mesh in mm
                 "mesh_sampling": 130,                              #number of points to mesh along a geometry
                 "fillet_resolution":12,   
                 "num_cpus": 4,                                      #number of CPU cores to use for simulation
                 "palace_dir":path_to_palace
                }

#Creat the Palace Eigenmode simulation
eigen_sim = PALACE_Eigenmode_Simulation(name ='GMSH_eigen_test',                              #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "sims/",            #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                               #choose simulation mode 'HPC' or 'simPC'                                          
                                        meshing = 'GMSH',                                         #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        view_design_gmsh_gui = False,                               #view design in GMSH gui 
                                        create_files = True)                                        #create mesh, config and HPC batch files

# Assigning the materials to the interfaces, add ports to the design, and add some mesh.


eigen_sim.add_metallic(1, threshold=1e-10, fuse_threshold=1e-10)
eigen_sim.add_ground_plane(threshold=1e-10)

#Fine-mesh the transmon cross qubit region
bounds = design.components["xmon"].qgeometry_bounds()
eigen_sim.fine_mesh_in_rectangle(bounds[0]*1e-3, bounds[1]*1e-3, bounds[2]*1e-3, bounds[3]*1e-3, mesh_sampling=100, mesh_min=15e-6, mesh_max=120e-6)

#Add in the RF ports
# In eigenmode simulations, in order to extract the mode loss to the environment, we need to add ports terminated with 50 Ohm resistors.
eigen_sim.create_port_JosephsonJunction('junction', L_J=L_junction, C_J=2e-15)

# #Fine-mesh routed paths and around the xmon
eigen_sim.fine_mesh_around_comp_boundaries(['xmon','junction'], min_size=14e-6, max_size=75e-6)

eigen_sim.setup_EPR_interfaces(metal_air=MaterialInterface('Aluminium-Vacuum'), substrate_air=MaterialInterface('Silicon-Vacuum'), substrate_metal=MaterialInterface('Silicon-Aluminium'))
eigen_sim.prepare_simulation()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from SQDMetal.PALACE.Utilities.GMSH_Navigator import GMSH_Navigator

# Let's look how the mesh looks in GMSH
# Open the GMSH GUI

gmsh_nav = GMSH_Navigator(eigen_sim.path_mesh)
gmsh_nav.open_GUI()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/sqdmetal_env/lib/python3.11/site-packages/qiskit_metal/_gui/widgets/variable_table/prop_val_table_model.py:76, in PropValTable.auto_refresh(self)
#      73     self.timer.start(self.__refreshtime)
#      74     self.timer.timeout.connect(self.auto_refresh)
# ---> 76 def auto_refresh(self):
#      77     """Do an automatic refresh."""
#      78     newRowCount = self.rowCount(self)
#
# KeyboardInterrupt:

# %%
# If all looks good, lets run the simulation
eigen_sim.run()
# Out:
# >> /opt/homebrew/bin/mpirun -n 4 /Users/mcansarihan/qubit_design/palace/build/bin/palace-arm64.bin GMSH_eigen_test.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: v0.13.0-454-gcd4d7b78
# Running with 4 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 57 elements in 1 iterations of local bisection for under-resolved interior boundaries
# Added 1901 duplicate vertices for interior boundaries in the mesh
# Added 4174 duplicate boundary elements for interior boundaries in the mesh
# Added 1066 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 4 subdomains
#
# Characteristic length and time scales:
#  L₀ = 2.880e-03 m, t₀ = 9.607e-03 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-1.440e-03, -2.440e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+1.440e-03, +4.400e-04, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices          3774        4173        4621       16692
#  edges            24187       25220       26327      100881
#  faces            39264       39823       40371      159293
#  elements         18663       18775       18876       75102
#  neighbors            3           3           3
#
#             minimum     maximum
#  h        0.0022574   0.0514108
#  kappa      1.03957     12.1019
#
# Configuring Robin absorbing BC (order 1) at attributes:
#  8
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  4: Ls = 2.454e-09 H/sq, Cs = 7.407e-15 F/sq, n = (-0.0,-0.0,-1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: L = 9.090e-09 H,C = 2.000e-15 F
#
# Configuring Dirichlet PEC BC at attributes:
#  1-3
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 16692, ND (p = 1): 100881, RT (p = 1): 159293
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 1.596e+02, δ = 1.339e-04
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 4.000e+00 GHz (2.414e-01)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 100881 unknowns
#  Level 0 (auxiliary) (p = 1): 16692 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.364186e+02
#  1 (restart 0) KSP residual norm 1.021622e-01
# FGMRES solver converged in 1 iteration (avg. reduction factor: 1.905e-04)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.760793e+02
#  1 (restart 0) KSP residual norm 3.823374e-02
# FGMRES solver converged in 1 iteration (avg. reduction factor: 2.171e-04)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.589501e+01
#  1 (restart 0) KSP residual norm 5.375649e-02
#  2 (restart 0) KSP residual norm 1.820926e-02
# FGMRES solver converged in 2 iterations (avg. reduction factor: 1.662e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.025142e+01
#  1 (restart 0) KSP residual norm 8.377031e-02
#  2 (restart 0) KSP residual norm 1.852087e-02
# FGMRES solver converged in 2 iterations (avg. reduction factor: 1.753e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.124043e+01
#  1 (restart 0) KSP residual norm 4.740017e-01
#  2 (restart 0) KSP residual norm 6.500488e-02
#  3 (restart 0) KSP residual norm 4.848874e-02
#  4 (restart 0) KSP residual norm 1.570373e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.179e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.649228e+00
#  1 (restart 0) KSP residual norm 1.855769e+00
#  2 (restart 0) KSP residual norm 2.681235e-01
#  3 (restart 0) KSP residual norm 1.684428e-01
#  4 (restart 0) KSP residual norm 6.825893e-02
#  5 (restart 0) KSP residual norm 1.195575e-02
#  6 (restart 0) KSP residual norm 7.662339e-03
#  7 (restart 0) KSP residual norm 2.194038e-03
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.017e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.185394e+01
#  1 (restart 0) KSP residual norm 2.190724e+00
#  2 (restart 0) KSP residual norm 3.462427e-01
#  3 (restart 0) KSP residual norm 2.347795e-01
#  4 (restart 0) KSP residual norm 8.593796e-02
#  5 (restart 0) KSP residual norm 1.591507e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.983e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.176939e+01
#  1 (restart 0) KSP residual norm 4.145367e+00
#  2 (restart 0) KSP residual norm 2.873351e-01
#  3 (restart 0) KSP residual norm 1.969001e-01
#  4 (restart 0) KSP residual norm 8.298197e-02
#  5 (restart 0) KSP residual norm 1.208745e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.070e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.722742e+01
#  1 (restart 0) KSP residual norm 3.063754e+00
#  2 (restart 0) KSP residual norm 2.617359e-01
#  3 (restart 0) KSP residual norm 1.389807e-01
#  4 (restart 0) KSP residual norm 7.065712e-02
#  5 (restart 0) KSP residual norm 9.242927e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.643e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.744894e+01
#  1 (restart 0) KSP residual norm 4.053010e+00
#  2 (restart 0) KSP residual norm 2.637747e-01
#  3 (restart 0) KSP residual norm 1.225685e-01
#  4 (restart 0) KSP residual norm 5.464606e-02
#  5 (restart 0) KSP residual norm 6.860293e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.706e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.651345e+01
#  1 (restart 0) KSP residual norm 4.637580e+00
#  2 (restart 0) KSP residual norm 3.990589e-01
#  3 (restart 0) KSP residual norm 2.275640e-01
#  4 (restart 0) KSP residual norm 1.114637e-01
#  5 (restart 0) KSP residual norm 1.426586e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.846e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.834437e+01
#  1 (restart 0) KSP residual norm 6.328996e+00
#  2 (restart 0) KSP residual norm 4.285583e-01
#  3 (restart 0) KSP residual norm 1.815063e-01
#  4 (restart 0) KSP residual norm 1.086064e-01
#  5 (restart 0) KSP residual norm 1.271728e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.014e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.119777e+01
#  1 (restart 0) KSP residual norm 4.211902e-01
#  2 (restart 0) KSP residual norm 1.334126e-01
#  3 (restart 0) KSP residual norm 6.268329e-02
#  4 (restart 0) KSP residual norm 2.905744e-02
#  5 (restart 0) KSP residual norm 3.665324e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.637e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.013148e+01
#  1 (restart 0) KSP residual norm 2.767905e+00
#  2 (restart 0) KSP residual norm 2.890048e-01
#  3 (restart 0) KSP residual norm 1.151505e-01
#  4 (restart 0) KSP residual norm 8.043031e-02
#  5 (restart 0) KSP residual norm 1.032023e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.831e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.179319e+01
#  1 (restart 0) KSP residual norm 1.553967e+00
#  2 (restart 0) KSP residual norm 2.810640e-01
#  3 (restart 0) KSP residual norm 8.215263e-02
#  4 (restart 0) KSP residual norm 4.686532e-02
#  5 (restart 0) KSP residual norm 6.224617e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.644e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.907682e+01
#  1 (restart 0) KSP residual norm 1.445500e+00
#  2 (restart 0) KSP residual norm 1.883974e-01
#  3 (restart 0) KSP residual norm 1.019480e-01
#  4 (restart 0) KSP residual norm 5.004855e-02
#  5 (restart 0) KSP residual norm 7.458901e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.661e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.203111e+01
#  1 (restart 0) KSP residual norm 9.808633e-01
#  2 (restart 0) KSP residual norm 2.291843e-01
#  3 (restart 0) KSP residual norm 1.013654e-01
#  4 (restart 0) KSP residual norm 3.805669e-02
#  5 (restart 0) KSP residual norm 6.509700e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.600e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.393968e+01
#  1 (restart 0) KSP residual norm 2.871856e+00
#  2 (restart 0) KSP residual norm 5.129220e-01
#  3 (restart 0) KSP residual norm 1.013102e-01
#  4 (restart 0) KSP residual norm 7.596158e-02
#  5 (restart 0) KSP residual norm 9.888780e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.963e-01)
#   Eigenvalue approximations and residual norms for  solve.
#   1 EPS nconv=1 first unconverged value (error) -0.016987+0.00618282i (8.69693111e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.468271e+01
#  1 (restart 0) KSP residual norm 2.451932e+00
#  2 (restart 0) KSP residual norm 4.375373e-01
#  3 (restart 0) KSP residual norm 1.065401e-01
#  4 (restart 0) KSP residual norm 7.395880e-02
#  5 (restart 0) KSP residual norm 8.739321e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.907e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.655677e+01
#  1 (restart 0) KSP residual norm 1.129326e+00
#  2 (restart 0) KSP residual norm 1.805820e-01
#  3 (restart 0) KSP residual norm 7.523935e-02
#  4 (restart 0) KSP residual norm 4.165980e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.441e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.571012e+02
#  1 (restart 0) KSP residual norm 3.221354e+00
#  2 (restart 0) KSP residual norm 2.519524e-01
#  3 (restart 0) KSP residual norm 9.552363e-02
#  4 (restart 0) KSP residual norm 5.453998e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.365e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.438830e+01
#  1 (restart 0) KSP residual norm 1.578499e+00
#  2 (restart 0) KSP residual norm 2.626165e-01
#  3 (restart 0) KSP residual norm 1.691317e-01
#  4 (restart 0) KSP residual norm 6.575694e-02
#  5 (restart 0) KSP residual norm 9.014116e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.695e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.127492e+01
#  1 (restart 0) KSP residual norm 3.838994e+00
#  2 (restart 0) KSP residual norm 2.150383e-01
#  3 (restart 0) KSP residual norm 1.098340e-01
#  4 (restart 0) KSP residual norm 3.950157e-02
#  5 (restart 0) KSP residual norm 5.994001e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.635e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.769951e+01
#  1 (restart 0) KSP residual norm 9.136982e-01
#  2 (restart 0) KSP residual norm 1.784228e-01
#  3 (restart 0) KSP residual norm 6.078220e-02
#  4 (restart 0) KSP residual norm 2.838516e-02
#  5 (restart 0) KSP residual norm 4.452700e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.639e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.006887e+01
#  1 (restart 0) KSP residual norm 2.254256e+00
#  2 (restart 0) KSP residual norm 3.904943e-01
#  3 (restart 0) KSP residual norm 8.517368e-02
#  4 (restart 0) KSP residual norm 3.168152e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.458e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.750807e+01
#  1 (restart 0) KSP residual norm 7.854559e-01
#  2 (restart 0) KSP residual norm 1.774920e-01
#  3 (restart 0) KSP residual norm 1.147180e-01
#  4 (restart 0) KSP residual norm 3.815710e-02
#  5 (restart 0) KSP residual norm 6.929814e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.645e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.710901e+01
#  1 (restart 0) KSP residual norm 1.734169e+00
#  2 (restart 0) KSP residual norm 2.691572e-01
#  3 (restart 0) KSP residual norm 1.281249e-01
#  4 (restart 0) KSP residual norm 3.897596e-02
#  5 (restart 0) KSP residual norm 7.321410e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.933e-01)
#   2 EPS nconv=1 first unconverged value (error) 0.000232768+0.0113197i (4.28744329e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.642478e+02
#  1 (restart 0) KSP residual norm 1.702726e+00
#  2 (restart 0) KSP residual norm 2.718743e-01
#  3 (restart 0) KSP residual norm 1.166059e-01
#  4 (restart 0) KSP residual norm 6.488572e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.410e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.413596e+01
#  1 (restart 0) KSP residual norm 4.551614e-01
#  2 (restart 0) KSP residual norm 1.259070e-01
#  3 (restart 0) KSP residual norm 4.680202e-02
# FGMRES solver converged in 3 iterations (avg. reduction factor: 7.922e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.939312e+02
#  1 (restart 0) KSP residual norm 8.383705e-01
#  2 (restart 0) KSP residual norm 1.823983e-01
#  3 (restart 0) KSP residual norm 6.848863e-02
# FGMRES solver converged in 3 iterations (avg. reduction factor: 7.068e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.003386e+01
#  1 (restart 0) KSP residual norm 8.025616e-01
#  2 (restart 0) KSP residual norm 2.184715e-01
#  3 (restart 0) KSP residual norm 5.519402e-02
#  4 (restart 0) KSP residual norm 4.151468e-02
#  5 (restart 0) KSP residual norm 7.381967e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.713e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.309364e+01
#  1 (restart 0) KSP residual norm 9.886365e-01
#  2 (restart 0) KSP residual norm 1.239582e-01
#  3 (restart 0) KSP residual norm 5.518069e-02
#  4 (restart 0) KSP residual norm 3.303003e-02
#  5 (restart 0) KSP residual norm 4.218579e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.462e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.369674e+01
#  1 (restart 0) KSP residual norm 8.177469e-01
#  2 (restart 0) KSP residual norm 2.595198e-01
#  3 (restart 0) KSP residual norm 8.799772e-02
#  4 (restart 0) KSP residual norm 6.621255e-02
#  5 (restart 0) KSP residual norm 9.902535e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.681e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.427133e+01
#  1 (restart 0) KSP residual norm 1.660756e+00
#  2 (restart 0) KSP residual norm 3.009141e-01
#  3 (restart 0) KSP residual norm 5.738547e-02
#  4 (restart 0) KSP residual norm 3.758266e-02
#  5 (restart 0) KSP residual norm 4.658469e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.685e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.182062e+02
#  1 (restart 0) KSP residual norm 1.741697e+00
#  2 (restart 0) KSP residual norm 2.795215e-01
#  3 (restart 0) KSP residual norm 1.532842e-01
#  4 (restart 0) KSP residual norm 7.362764e-02
#  5 (restart 0) KSP residual norm 1.026762e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.541e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.370833e+01
#  1 (restart 0) KSP residual norm 2.295901e+00
#  2 (restart 0) KSP residual norm 2.626516e-01
#  3 (restart 0) KSP residual norm 8.209575e-02
#  4 (restart 0) KSP residual norm 4.038004e-02
#  5 (restart 0) KSP residual norm 5.135927e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.724e-01)
#   3 EPS nconv=1 first unconverged value (error) 0.000314874+0.0114138i (1.36906878e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.460490e+01
#  1 (restart 0) KSP residual norm 3.031216e+00
#  2 (restart 0) KSP residual norm 4.865351e-01
#  3 (restart 0) KSP residual norm 1.585187e-01
#  4 (restart 0) KSP residual norm 1.209292e-01
#  5 (restart 0) KSP residual norm 1.561517e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.956e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.662165e+01
#  1 (restart 0) KSP residual norm 4.813320e-01
#  2 (restart 0) KSP residual norm 1.281897e-01
#  3 (restart 0) KSP residual norm 8.572222e-02
#  4 (restart 0) KSP residual norm 4.033516e-02
#  5 (restart 0) KSP residual norm 4.680203e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.665e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.540407e+01
#  1 (restart 0) KSP residual norm 1.323773e+00
#  2 (restart 0) KSP residual norm 2.820334e-01
#  3 (restart 0) KSP residual norm 7.725016e-02
#  4 (restart 0) KSP residual norm 4.941746e-02
#  5 (restart 0) KSP residual norm 6.624366e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.920e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.144139e+01
#  1 (restart 0) KSP residual norm 1.069142e+00
#  2 (restart 0) KSP residual norm 1.908050e-01
#  3 (restart 0) KSP residual norm 6.732533e-02
#  4 (restart 0) KSP residual norm 4.343859e-02
#  5 (restart 0) KSP residual norm 6.294425e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.966e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.766213e+01
#  1 (restart 0) KSP residual norm 1.760882e+00
#  2 (restart 0) KSP residual norm 1.876431e-01
#  3 (restart 0) KSP residual norm 7.749215e-02
#  4 (restart 0) KSP residual norm 4.108212e-02
#  5 (restart 0) KSP residual norm 5.698752e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.831e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.250226e+01
#  1 (restart 0) KSP residual norm 1.254079e+00
#  2 (restart 0) KSP residual norm 2.454526e-01
#  3 (restart 0) KSP residual norm 9.254449e-02
#  4 (restart 0) KSP residual norm 4.979544e-02
#  5 (restart 0) KSP residual norm 7.198754e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.761e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.656566e+01
#  1 (restart 0) KSP residual norm 1.702737e+00
#  2 (restart 0) KSP residual norm 2.939430e-01
#  3 (restart 0) KSP residual norm 5.974939e-02
#  4 (restart 0) KSP residual norm 4.165988e-02
#  5 (restart 0) KSP residual norm 4.961764e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.974e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.978802e+01
#  1 (restart 0) KSP residual norm 9.893342e-01
#  2 (restart 0) KSP residual norm 1.126579e-01
#  3 (restart 0) KSP residual norm 7.324095e-02
#  4 (restart 0) KSP residual norm 1.666161e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.431e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.108005e+01
#  1 (restart 0) KSP residual norm 9.372555e-01
#  2 (restart 0) KSP residual norm 3.024807e-01
#  3 (restart 0) KSP residual norm 1.398303e-01
#  4 (restart 0) KSP residual norm 9.095750e-02
#  5 (restart 0) KSP residual norm 6.930339e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.011e-01)
#   4 EPS nconv=1 first unconverged value (error) 6.90197e-05+0.0113029i (4.62751484e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.984545e+01
#  1 (restart 0) KSP residual norm 8.789539e-01
#  2 (restart 0) KSP residual norm 2.584608e-01
#  3 (restart 0) KSP residual norm 1.415105e-01
#  4 (restart 0) KSP residual norm 6.146402e-02
#  5 (restart 0) KSP residual norm 9.616361e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.743e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.481857e+01
#  1 (restart 0) KSP residual norm 1.614851e-01
#  2 (restart 0) KSP residual norm 6.607934e-02
#  3 (restart 0) KSP residual norm 4.865378e-02
#  4 (restart 0) KSP residual norm 1.713719e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.489e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.448377e+00
#  1 (restart 0) KSP residual norm 2.484760e-01
#  2 (restart 0) KSP residual norm 8.603380e-02
#  3 (restart 0) KSP residual norm 2.742351e-02
#  4 (restart 0) KSP residual norm 1.596939e-02
#  5 (restart 0) KSP residual norm 1.860390e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.815e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.498302e+01
#  1 (restart 0) KSP residual norm 2.574534e-01
#  2 (restart 0) KSP residual norm 8.660005e-02
#  3 (restart 0) KSP residual norm 3.400326e-02
#  4 (restart 0) KSP residual norm 1.896315e-02
#  5 (restart 0) KSP residual norm 2.504451e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.756e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.320281e+01
#  1 (restart 0) KSP residual norm 2.689664e-01
#  2 (restart 0) KSP residual norm 9.583584e-02
#  3 (restart 0) KSP residual norm 3.978120e-02
#  4 (restart 0) KSP residual norm 2.007100e-02
#  5 (restart 0) KSP residual norm 2.750525e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.835e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.767255e+01
#  1 (restart 0) KSP residual norm 5.973694e-01
#  2 (restart 0) KSP residual norm 1.822520e-01
#  3 (restart 0) KSP residual norm 4.565782e-02
#  4 (restart 0) KSP residual norm 2.883612e-02
#  5 (restart 0) KSP residual norm 3.956713e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.862e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.666071e+01
#  1 (restart 0) KSP residual norm 4.472163e-01
#  2 (restart 0) KSP residual norm 1.613425e-01
#  3 (restart 0) KSP residual norm 1.077063e-01
#  4 (restart 0) KSP residual norm 3.105157e-02
#  5 (restart 0) KSP residual norm 6.407191e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.689e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.867976e+01
#  1 (restart 0) KSP residual norm 4.315273e-01
#  2 (restart 0) KSP residual norm 1.656210e-01
#  3 (restart 0) KSP residual norm 1.368910e-01
#  4 (restart 0) KSP residual norm 3.982287e-02
#  5 (restart 0) KSP residual norm 7.123758e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.071e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.136237e+01
#  1 (restart 0) KSP residual norm 7.544877e-01
#  2 (restart 0) KSP residual norm 2.336788e-01
#  3 (restart 0) KSP residual norm 1.094069e-01
#  4 (restart 0) KSP residual norm 3.379317e-02
#  5 (restart 0) KSP residual norm 6.642961e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.669e-01)
#   5 EPS nconv=1 first unconverged value (error) -0.0133208+0.010605i (2.68736070e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.127923e+01
#  1 (restart 0) KSP residual norm 4.506124e-01
#  2 (restart 0) KSP residual norm 1.491718e-01
#  3 (restart 0) KSP residual norm 6.200573e-02
#  4 (restart 0) KSP residual norm 4.032749e-02
#  5 (restart 0) KSP residual norm 5.541317e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.681e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.159261e+01
#  1 (restart 0) KSP residual norm 2.238109e-01
#  2 (restart 0) KSP residual norm 9.539202e-02
#  3 (restart 0) KSP residual norm 6.507983e-02
#  4 (restart 0) KSP residual norm 2.027667e-02
#  5 (restart 0) KSP residual norm 3.521196e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.620e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.686236e+01
#  1 (restart 0) KSP residual norm 2.724152e-01
#  2 (restart 0) KSP residual norm 8.206343e-02
#  3 (restart 0) KSP residual norm 3.907555e-02
#  4 (restart 0) KSP residual norm 2.186516e-02
#  5 (restart 0) KSP residual norm 2.608067e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.729e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.783815e+01
#  1 (restart 0) KSP residual norm 5.753336e-01
#  2 (restart 0) KSP residual norm 1.730444e-01
#  3 (restart 0) KSP residual norm 5.794139e-02
#  4 (restart 0) KSP residual norm 3.077184e-02
#  5 (restart 0) KSP residual norm 4.212581e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.722e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.079127e+01
#  1 (restart 0) KSP residual norm 3.390827e-01
#  2 (restart 0) KSP residual norm 8.618046e-02
#  3 (restart 0) KSP residual norm 5.003261e-02
#  4 (restart 0) KSP residual norm 2.611700e-02
#  5 (restart 0) KSP residual norm 3.163607e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.965e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.522318e+01
#  1 (restart 0) KSP residual norm 5.268144e-01
#  2 (restart 0) KSP residual norm 1.543744e-01
#  3 (restart 0) KSP residual norm 7.314875e-02
#  4 (restart 0) KSP residual norm 3.163400e-02
#  5 (restart 0) KSP residual norm 4.329523e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.652e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.523745e+01
#  1 (restart 0) KSP residual norm 6.070649e-01
#  2 (restart 0) KSP residual norm 1.834262e-01
#  3 (restart 0) KSP residual norm 7.744297e-02
#  4 (restart 0) KSP residual norm 3.834682e-02
#  5 (restart 0) KSP residual norm 4.214467e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.643e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.881945e+00
#  1 (restart 0) KSP residual norm 9.312687e-01
#  2 (restart 0) KSP residual norm 2.233172e-01
#  3 (restart 0) KSP residual norm 9.107625e-02
#  4 (restart 0) KSP residual norm 3.473631e-02
#  5 (restart 0) KSP residual norm 4.833051e-03
#  6 (restart 0) KSP residual norm 3.400861e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.749e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.825067e+01
#  1 (restart 0) KSP residual norm 6.042198e-01
#  2 (restart 0) KSP residual norm 1.726770e-01
#  3 (restart 0) KSP residual norm 7.397358e-02
#  4 (restart 0) KSP residual norm 4.187905e-02
#  5 (restart 0) KSP residual norm 4.961247e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.774e-01)
#   6 EPS nconv=1 first unconverged value (error) -0.01357+0.0104642i (1.91159759e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.869545e+01
#  1 (restart 0) KSP residual norm 3.619731e-01
#  2 (restart 0) KSP residual norm 1.466364e-01
#  3 (restart 0) KSP residual norm 9.518878e-02
#  4 (restart 0) KSP residual norm 3.802482e-02
#  5 (restart 0) KSP residual norm 5.407801e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.695e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.987536e+01
#  1 (restart 0) KSP residual norm 2.226291e-01
#  2 (restart 0) KSP residual norm 8.978327e-02
#  3 (restart 0) KSP residual norm 4.575628e-02
#  4 (restart 0) KSP residual norm 1.760092e-02
#  5 (restart 0) KSP residual norm 2.742974e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.690e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.312560e+01
#  1 (restart 0) KSP residual norm 3.709888e-01
#  2 (restart 0) KSP residual norm 1.164198e-01
#  3 (restart 0) KSP residual norm 3.294878e-02
#  4 (restart 0) KSP residual norm 2.374951e-02
#  5 (restart 0) KSP residual norm 2.270193e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.768e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.230182e+01
#  1 (restart 0) KSP residual norm 3.958618e-01
#  2 (restart 0) KSP residual norm 1.412601e-01
#  3 (restart 0) KSP residual norm 4.046617e-02
#  4 (restart 0) KSP residual norm 3.018756e-02
#  5 (restart 0) KSP residual norm 3.697441e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.754e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.377053e+01
#  1 (restart 0) KSP residual norm 2.503332e-01
#  2 (restart 0) KSP residual norm 8.461178e-02
#  3 (restart 0) KSP residual norm 6.070598e-02
#  4 (restart 0) KSP residual norm 2.636195e-02
#  5 (restart 0) KSP residual norm 3.847068e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.745e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.165647e+01
#  1 (restart 0) KSP residual norm 3.221079e-01
#  2 (restart 0) KSP residual norm 1.054452e-01
#  3 (restart 0) KSP residual norm 5.422599e-02
#  4 (restart 0) KSP residual norm 2.461817e-02
#  5 (restart 0) KSP residual norm 2.894647e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.901e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.365490e+01
#  1 (restart 0) KSP residual norm 6.106405e-01
#  2 (restart 0) KSP residual norm 2.076020e-01
#  3 (restart 0) KSP residual norm 7.846946e-02
#  4 (restart 0) KSP residual norm 4.728798e-02
#  5 (restart 0) KSP residual norm 5.908731e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.684e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.872926e+01
#  1 (restart 0) KSP residual norm 5.647548e-01
#  2 (restart 0) KSP residual norm 1.756529e-01
#  3 (restart 0) KSP residual norm 9.878154e-02
#  4 (restart 0) KSP residual norm 5.264715e-02
#  5 (restart 0) KSP residual norm 6.676451e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.767e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.854947e+01
#  1 (restart 0) KSP residual norm 7.061090e-01
#  2 (restart 0) KSP residual norm 2.259419e-01
#  3 (restart 0) KSP residual norm 7.690778e-02
#  4 (restart 0) KSP residual norm 5.608851e-02
#  5 (restart 0) KSP residual norm 7.497539e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.922e-01)
#   7 EPS nconv=1 first unconverged value (error) -0.013624+0.0106748i (9.71194783e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.686413e+01
#  1 (restart 0) KSP residual norm 4.999430e-01
#  2 (restart 0) KSP residual norm 1.651553e-01
#  3 (restart 0) KSP residual norm 1.191351e-01
#  4 (restart 0) KSP residual norm 4.853744e-02
#  5 (restart 0) KSP residual norm 7.179597e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.726e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.575976e+00
#  1 (restart 0) KSP residual norm 1.555983e-01
#  2 (restart 0) KSP residual norm 6.128173e-02
#  3 (restart 0) KSP residual norm 2.911872e-02
#  4 (restart 0) KSP residual norm 1.088680e-02
#  5 (restart 0) KSP residual norm 1.594040e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.839e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.068057e+01
#  1 (restart 0) KSP residual norm 2.210100e-01
#  2 (restart 0) KSP residual norm 7.220950e-02
#  3 (restart 0) KSP residual norm 2.992608e-02
#  4 (restart 0) KSP residual norm 1.572012e-02
#  5 (restart 0) KSP residual norm 2.225926e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.836e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.707518e+01
#  1 (restart 0) KSP residual norm 1.341739e-01
#  2 (restart 0) KSP residual norm 5.312338e-02
#  3 (restart 0) KSP residual norm 3.093187e-02
#  4 (restart 0) KSP residual norm 1.471106e-02
#  5 (restart 0) KSP residual norm 2.141559e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.658e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.253498e+01
#  1 (restart 0) KSP residual norm 6.831339e-01
#  2 (restart 0) KSP residual norm 2.249950e-01
#  3 (restart 0) KSP residual norm 4.789921e-02
#  4 (restart 0) KSP residual norm 3.433370e-02
#  5 (restart 0) KSP residual norm 4.274491e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.801e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.877421e+01
#  1 (restart 0) KSP residual norm 3.643730e-01
#  2 (restart 0) KSP residual norm 9.564546e-02
#  3 (restart 0) KSP residual norm 6.670024e-02
#  4 (restart 0) KSP residual norm 2.883882e-02
#  5 (restart 0) KSP residual norm 4.236141e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.865e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.711528e+01
#  1 (restart 0) KSP residual norm 5.664386e-01
#  2 (restart 0) KSP residual norm 1.912041e-01
#  3 (restart 0) KSP residual norm 6.732128e-02
#  4 (restart 0) KSP residual norm 3.637289e-02
#  5 (restart 0) KSP residual norm 4.671696e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.767e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.201452e+01
#  1 (restart 0) KSP residual norm 4.197270e-01
#  2 (restart 0) KSP residual norm 1.543162e-01
#  3 (restart 0) KSP residual norm 9.770997e-02
#  4 (restart 0) KSP residual norm 3.357301e-02
#  5 (restart 0) KSP residual norm 5.278799e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.659e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.478431e+01
#  1 (restart 0) KSP residual norm 3.291937e-01
#  2 (restart 0) KSP residual norm 8.998498e-02
#  3 (restart 0) KSP residual norm 5.834469e-02
#  4 (restart 0) KSP residual norm 3.249089e-02
#  5 (restart 0) KSP residual norm 4.908302e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.698e-01)
#   8 EPS nconv=1 first unconverged value (error) -0.0135394+0.0104917i (5.80294004e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.865821e+01
#  1 (restart 0) KSP residual norm 5.358707e-01
#  2 (restart 0) KSP residual norm 1.808214e-01
#  3 (restart 0) KSP residual norm 9.347159e-02
#  4 (restart 0) KSP residual norm 5.527731e-02
#  5 (restart 0) KSP residual norm 6.830945e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.776e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.878972e+00
#  1 (restart 0) KSP residual norm 1.175569e-01
#  2 (restart 0) KSP residual norm 3.375097e-02
#  3 (restart 0) KSP residual norm 2.146249e-02
#  4 (restart 0) KSP residual norm 1.027239e-02
#  5 (restart 0) KSP residual norm 1.376348e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.694e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.255111e+00
#  1 (restart 0) KSP residual norm 2.540891e-01
#  2 (restart 0) KSP residual norm 3.804042e-02
#  3 (restart 0) KSP residual norm 2.379720e-02
#  4 (restart 0) KSP residual norm 1.761253e-02
#  5 (restart 0) KSP residual norm 1.821380e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.120e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.333388e+01
#  1 (restart 0) KSP residual norm 1.842373e-01
#  2 (restart 0) KSP residual norm 4.788648e-02
#  3 (restart 0) KSP residual norm 3.037742e-02
#  4 (restart 0) KSP residual norm 1.590714e-02
#  5 (restart 0) KSP residual norm 2.109018e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.737e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.187509e+01
#  1 (restart 0) KSP residual norm 7.258530e-01
#  2 (restart 0) KSP residual norm 2.346340e-01
#  3 (restart 0) KSP residual norm 6.047401e-02
#  4 (restart 0) KSP residual norm 4.202418e-02
#  5 (restart 0) KSP residual norm 4.690217e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.086e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.555952e+01
#  1 (restart 0) KSP residual norm 4.309841e-01
#  2 (restart 0) KSP residual norm 9.191559e-02
#  3 (restart 0) KSP residual norm 7.891111e-02
#  4 (restart 0) KSP residual norm 3.696530e-02
#  5 (restart 0) KSP residual norm 4.894031e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.805e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.043283e+01
#  1 (restart 0) KSP residual norm 3.395139e-01
#  2 (restart 0) KSP residual norm 1.089763e-01
#  3 (restart 0) KSP residual norm 5.363753e-02
#  4 (restart 0) KSP residual norm 3.622288e-02
#  5 (restart 0) KSP residual norm 4.935058e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.163e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.549137e+01
#  1 (restart 0) KSP residual norm 3.677080e-01
#  2 (restart 0) KSP residual norm 1.235009e-01
#  3 (restart 0) KSP residual norm 9.302600e-02
#  4 (restart 0) KSP residual norm 2.525630e-02
#  5 (restart 0) KSP residual norm 4.221346e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.937e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.618107e+01
#  1 (restart 0) KSP residual norm 5.090255e-01
#  2 (restart 0) KSP residual norm 1.057738e-01
#  3 (restart 0) KSP residual norm 6.359250e-02
#  4 (restart 0) KSP residual norm 4.080530e-02
#  5 (restart 0) KSP residual norm 5.578748e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.728e-01)
#   9 EPS nconv=1 first unconverged value (error) -0.01361+0.0103701i (5.63496171e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.949850e+01
#  1 (restart 0) KSP residual norm 5.671868e-01
#  2 (restart 0) KSP residual norm 1.567034e-01
#  3 (restart 0) KSP residual norm 1.025937e-01
#  4 (restart 0) KSP residual norm 4.151042e-02
#  5 (restart 0) KSP residual norm 6.847798e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.038e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.349918e+00
#  1 (restart 0) KSP residual norm 9.662533e-02
#  2 (restart 0) KSP residual norm 1.673421e-02
#  3 (restart 0) KSP residual norm 8.867739e-03
#  4 (restart 0) KSP residual norm 6.545444e-03
#  5 (restart 0) KSP residual norm 3.336894e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.899e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.648349e+00
#  1 (restart 0) KSP residual norm 2.790117e-01
#  2 (restart 0) KSP residual norm 1.027611e-01
#  3 (restart 0) KSP residual norm 1.762452e-02
#  4 (restart 0) KSP residual norm 1.026261e-02
#  5 (restart 0) KSP residual norm 1.844739e-03
#  6 (restart 0) KSP residual norm 5.781949e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.454e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.974232e+00
#  1 (restart 0) KSP residual norm 3.039691e-01
#  2 (restart 0) KSP residual norm 8.690942e-02
#  3 (restart 0) KSP residual norm 2.129435e-02
#  4 (restart 0) KSP residual norm 1.643024e-02
#  5 (restart 0) KSP residual norm 1.246843e-03
#  6 (restart 0) KSP residual norm 5.891763e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.585e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.021513e+00
#  1 (restart 0) KSP residual norm 3.401935e-01
#  2 (restart 0) KSP residual norm 1.313067e-01
#  3 (restart 0) KSP residual norm 7.359238e-02
#  4 (restart 0) KSP residual norm 4.226033e-02
#  5 (restart 0) KSP residual norm 5.245889e-03
#  6 (restart 0) KSP residual norm 2.391596e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.643e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.576130e+00
#  1 (restart 0) KSP residual norm 2.958543e-01
#  2 (restart 0) KSP residual norm 1.208676e-01
#  3 (restart 0) KSP residual norm 4.674895e-02
#  4 (restart 0) KSP residual norm 3.220738e-02
#  5 (restart 0) KSP residual norm 2.550660e-03
#  6 (restart 0) KSP residual norm 1.701567e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.794e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.170056e+01
#  1 (restart 0) KSP residual norm 2.772735e-01
#  2 (restart 0) KSP residual norm 8.723014e-02
#  3 (restart 0) KSP residual norm 5.318327e-02
#  4 (restart 0) KSP residual norm 2.137923e-02
#  5 (restart 0) KSP residual norm 2.691974e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.872e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.523178e+01
#  1 (restart 0) KSP residual norm 5.291266e-01
#  2 (restart 0) KSP residual norm 1.647597e-01
#  3 (restart 0) KSP residual norm 8.473436e-02
#  4 (restart 0) KSP residual norm 3.824661e-02
#  5 (restart 0) KSP residual norm 4.395375e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.771e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.552745e+01
#  1 (restart 0) KSP residual norm 6.882709e-01
#  2 (restart 0) KSP residual norm 2.513456e-01
#  3 (restart 0) KSP residual norm 8.467215e-02
#  4 (restart 0) KSP residual norm 3.753269e-02
#  5 (restart 0) KSP residual norm 5.592297e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.854e-01)
#  10 EPS nconv=1 first unconverged value (error) -0.00885048+0.00164185i (2.58645271e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.182407e+01
#  1 (restart 0) KSP residual norm 5.498588e-01
#  2 (restart 0) KSP residual norm 1.790338e-01
#  3 (restart 0) KSP residual norm 9.561476e-02
#  4 (restart 0) KSP residual norm 5.359481e-02
#  5 (restart 0) KSP residual norm 5.353004e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.665e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.905018e+00
#  1 (restart 0) KSP residual norm 3.610921e-01
#  2 (restart 0) KSP residual norm 8.694783e-02
#  3 (restart 0) KSP residual norm 3.098862e-02
#  4 (restart 0) KSP residual norm 1.735826e-02
#  5 (restart 0) KSP residual norm 2.260314e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.909e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.944413e+00
#  1 (restart 0) KSP residual norm 4.343672e-01
#  2 (restart 0) KSP residual norm 1.219647e-01
#  3 (restart 0) KSP residual norm 4.060393e-02
#  4 (restart 0) KSP residual norm 3.051479e-02
#  5 (restart 0) KSP residual norm 2.171864e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.991e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.031267e+01
#  1 (restart 0) KSP residual norm 3.754636e-01
#  2 (restart 0) KSP residual norm 1.098978e-01
#  3 (restart 0) KSP residual norm 4.292097e-02
#  4 (restart 0) KSP residual norm 2.429730e-02
#  5 (restart 0) KSP residual norm 2.064469e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.821e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.157843e+00
#  1 (restart 0) KSP residual norm 3.024708e-01
#  2 (restart 0) KSP residual norm 9.878953e-02
#  3 (restart 0) KSP residual norm 3.206998e-02
#  4 (restart 0) KSP residual norm 1.698697e-02
#  5 (restart 0) KSP residual norm 2.161392e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.882e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.733440e+00
#  1 (restart 0) KSP residual norm 4.129292e-01
#  2 (restart 0) KSP residual norm 1.460787e-01
#  3 (restart 0) KSP residual norm 2.908639e-02
#  4 (restart 0) KSP residual norm 2.113097e-02
#  5 (restart 0) KSP residual norm 2.984452e-03
#  6 (restart 0) KSP residual norm 9.295608e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.642e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.370016e+01
#  1 (restart 0) KSP residual norm 4.347059e-01
#  2 (restart 0) KSP residual norm 1.574409e-01
#  3 (restart 0) KSP residual norm 5.327239e-02
#  4 (restart 0) KSP residual norm 3.595937e-02
#  5 (restart 0) KSP residual norm 4.881457e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.043e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.439971e+01
#  1 (restart 0) KSP residual norm 7.326992e-01
#  2 (restart 0) KSP residual norm 2.320678e-01
#  3 (restart 0) KSP residual norm 9.950631e-02
#  4 (restart 0) KSP residual norm 6.420584e-02
#  5 (restart 0) KSP residual norm 7.619233e-03
#  6 (restart 0) KSP residual norm 3.449756e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.492e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.575681e+01
#  1 (restart 0) KSP residual norm 6.557033e-01
#  2 (restart 0) KSP residual norm 1.291822e-01
#  3 (restart 0) KSP residual norm 9.390646e-02
#  4 (restart 0) KSP residual norm 4.987415e-02
#  5 (restart 0) KSP residual norm 5.502398e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.035e-01)
#  11 EPS nconv=1 first unconverged value (error) -0.0136189+0.0104658i (1.79820347e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.263352e+01
#  1 (restart 0) KSP residual norm 5.441285e-01
#  2 (restart 0) KSP residual norm 1.854998e-01
#  3 (restart 0) KSP residual norm 1.059990e-01
#  4 (restart 0) KSP residual norm 6.373626e-02
#  5 (restart 0) KSP residual norm 6.048460e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.793e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.110469e+00
#  1 (restart 0) KSP residual norm 9.082141e-02
#  2 (restart 0) KSP residual norm 2.652023e-02
#  3 (restart 0) KSP residual norm 7.118384e-03
#  4 (restart 0) KSP residual norm 5.043044e-03
#  5 (restart 0) KSP residual norm 3.648736e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.768e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.071285e+00
#  1 (restart 0) KSP residual norm 2.909849e-01
#  2 (restart 0) KSP residual norm 5.174419e-02
#  3 (restart 0) KSP residual norm 2.450533e-02
#  4 (restart 0) KSP residual norm 1.885439e-02
#  5 (restart 0) KSP residual norm 1.509152e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.971e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.351223e+01
#  1 (restart 0) KSP residual norm 3.836228e-01
#  2 (restart 0) KSP residual norm 7.582644e-02
#  3 (restart 0) KSP residual norm 3.714745e-02
#  4 (restart 0) KSP residual norm 2.695449e-02
#  5 (restart 0) KSP residual norm 2.714006e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.822e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.725348e+01
#  1 (restart 0) KSP residual norm 5.862012e-01
#  2 (restart 0) KSP residual norm 1.611636e-01
#  3 (restart 0) KSP residual norm 5.465535e-02
#  4 (restart 0) KSP residual norm 3.682721e-02
#  5 (restart 0) KSP residual norm 3.395150e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.656e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.241235e+01
#  1 (restart 0) KSP residual norm 5.158763e-01
#  2 (restart 0) KSP residual norm 1.803495e-01
#  3 (restart 0) KSP residual norm 7.039606e-02
#  4 (restart 0) KSP residual norm 5.210725e-02
#  5 (restart 0) KSP residual norm 5.776677e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.686e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.492857e+01
#  1 (restart 0) KSP residual norm 5.222243e-01
#  2 (restart 0) KSP residual norm 1.824339e-01
#  3 (restart 0) KSP residual norm 4.009768e-02
#  4 (restart 0) KSP residual norm 2.660549e-02
#  5 (restart 0) KSP residual norm 2.858946e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.805e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.198135e+01
#  1 (restart 0) KSP residual norm 7.056177e-01
#  2 (restart 0) KSP residual norm 2.151885e-01
#  3 (restart 0) KSP residual norm 9.631037e-02
#  4 (restart 0) KSP residual norm 4.822144e-02
#  5 (restart 0) KSP residual norm 5.224916e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.885e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.333932e+00
#  1 (restart 0) KSP residual norm 6.946268e-01
#  2 (restart 0) KSP residual norm 2.320199e-01
#  3 (restart 0) KSP residual norm 8.297430e-02
#  4 (restart 0) KSP residual norm 5.608968e-02
#  5 (restart 0) KSP residual norm 7.160328e-03
#  6 (restart 0) KSP residual norm 2.726174e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.625e-01)
#  12 EPS nconv=1 first unconverged value (error) -0.0135768+0.0104748i (1.37479337e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.596045e+01
#  1 (restart 0) KSP residual norm 5.537144e-01
#  2 (restart 0) KSP residual norm 1.778408e-01
#  3 (restart 0) KSP residual norm 6.350266e-02
#  4 (restart 0) KSP residual norm 3.736200e-02
#  5 (restart 0) KSP residual norm 5.389260e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.834e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.659166e+00
#  1 (restart 0) KSP residual norm 1.071409e-01
#  2 (restart 0) KSP residual norm 3.129466e-02
#  3 (restart 0) KSP residual norm 9.317808e-03
#  4 (restart 0) KSP residual norm 6.159610e-03
#  5 (restart 0) KSP residual norm 4.836895e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.963e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.407964e+00
#  1 (restart 0) KSP residual norm 2.147833e-01
#  2 (restart 0) KSP residual norm 7.383214e-02
#  3 (restart 0) KSP residual norm 1.881835e-02
#  4 (restart 0) KSP residual norm 1.344711e-02
#  5 (restart 0) KSP residual norm 1.456572e-03
#  6 (restart 0) KSP residual norm 6.698698e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.555e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.112191e+01
#  1 (restart 0) KSP residual norm 2.861698e-01
#  2 (restart 0) KSP residual norm 9.538885e-02
#  3 (restart 0) KSP residual norm 2.757453e-02
#  4 (restart 0) KSP residual norm 1.647159e-02
#  5 (restart 0) KSP residual norm 2.578439e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.875e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.237877e+00
#  1 (restart 0) KSP residual norm 3.576171e-01
#  2 (restart 0) KSP residual norm 1.181510e-01
#  3 (restart 0) KSP residual norm 3.519625e-02
#  4 (restart 0) KSP residual norm 2.396386e-02
#  5 (restart 0) KSP residual norm 3.264714e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.087e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.198145e+01
#  1 (restart 0) KSP residual norm 3.065539e-01
#  2 (restart 0) KSP residual norm 9.869784e-02
#  3 (restart 0) KSP residual norm 3.443078e-02
#  4 (restart 0) KSP residual norm 1.978820e-02
#  5 (restart 0) KSP residual norm 2.795727e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.878e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.114395e+00
#  1 (restart 0) KSP residual norm 2.896872e-01
#  2 (restart 0) KSP residual norm 8.121013e-02
#  3 (restart 0) KSP residual norm 3.064190e-02
#  4 (restart 0) KSP residual norm 1.990826e-02
#  5 (restart 0) KSP residual norm 2.493758e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.037e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.589564e+01
#  1 (restart 0) KSP residual norm 2.792464e-01
#  2 (restart 0) KSP residual norm 9.599837e-02
#  3 (restart 0) KSP residual norm 7.146353e-02
#  4 (restart 0) KSP residual norm 2.685521e-02
#  5 (restart 0) KSP residual norm 4.174027e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.633e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.577598e+01
#  1 (restart 0) KSP residual norm 7.916810e-01
#  2 (restart 0) KSP residual norm 2.515770e-01
#  3 (restart 0) KSP residual norm 1.143610e-01
#  4 (restart 0) KSP residual norm 6.357715e-02
#  5 (restart 0) KSP residual norm 7.801735e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.763e-01)
#  13 EPS nconv=1 first unconverged value (error) -0.0135837+0.0104629i (5.53716462e-04)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.485789e+01
#  1 (restart 0) KSP residual norm 5.702860e-01
#  2 (restart 0) KSP residual norm 1.851123e-01
#  3 (restart 0) KSP residual norm 8.051508e-02
#  4 (restart 0) KSP residual norm 4.741472e-02
#  5 (restart 0) KSP residual norm 6.079449e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.771e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.154557e+00
#  1 (restart 0) KSP residual norm 1.659906e-01
#  2 (restart 0) KSP residual norm 3.548776e-02
#  3 (restart 0) KSP residual norm 1.948030e-02
#  4 (restart 0) KSP residual norm 9.399777e-03
#  5 (restart 0) KSP residual norm 1.187997e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.808e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.204918e+01
#  1 (restart 0) KSP residual norm 3.232027e-01
#  2 (restart 0) KSP residual norm 8.436117e-02
#  3 (restart 0) KSP residual norm 3.268396e-02
#  4 (restart 0) KSP residual norm 2.170072e-02
#  5 (restart 0) KSP residual norm 2.671054e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.858e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.135490e+01
#  1 (restart 0) KSP residual norm 1.989324e-01
#  2 (restart 0) KSP residual norm 4.583066e-02
#  3 (restart 0) KSP residual norm 3.871067e-02
#  4 (restart 0) KSP residual norm 1.905718e-02
#  5 (restart 0) KSP residual norm 2.760625e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.668e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.590634e+01
#  1 (restart 0) KSP residual norm 2.741856e-01
#  2 (restart 0) KSP residual norm 8.629672e-02
#  3 (restart 0) KSP residual norm 3.399460e-02
#  4 (restart 0) KSP residual norm 2.034539e-02
#  5 (restart 0) KSP residual norm 2.751911e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.769e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.157475e+01
#  1 (restart 0) KSP residual norm 5.006418e-01
#  2 (restart 0) KSP residual norm 1.462763e-01
#  3 (restart 0) KSP residual norm 4.309777e-02
#  4 (restart 0) KSP residual norm 2.605201e-02
#  5 (restart 0) KSP residual norm 3.189271e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.941e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.244073e+00
#  1 (restart 0) KSP residual norm 4.858605e-01
#  2 (restart 0) KSP residual norm 1.575380e-01
#  3 (restart 0) KSP residual norm 4.750898e-02
#  4 (restart 0) KSP residual norm 3.275535e-02
#  5 (restart 0) KSP residual norm 4.359986e-03
#  6 (restart 0) KSP residual norm 1.886566e-03
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.590e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.153645e+01
#  1 (restart 0) KSP residual norm 4.207236e-01
#  2 (restart 0) KSP residual norm 1.406036e-01
#  3 (restart 0) KSP residual norm 5.368605e-02
#  4 (restart 0) KSP residual norm 3.336915e-02
#  5 (restart 0) KSP residual norm 4.561310e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.842e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.445622e+01
#  1 (restart 0) KSP residual norm 6.586064e-01
#  2 (restart 0) KSP residual norm 2.148996e-01
#  3 (restart 0) KSP residual norm 8.793705e-02
#  4 (restart 0) KSP residual norm 5.307977e-02
#  5 (restart 0) KSP residual norm 6.461864e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.925e-01)
#  14 EPS nconv=4 first unconverged value (error) 2.64711e-06+0.0129085i (8.37917067e-04)
#
#  Linear eigensolve converged (4 eigenpairs) due to CONVERGED_TOL; iterations 14
#  Total number of linear systems solved: 135
#  Total number of linear solver iterations: 662
#  Found 4 converged eigenvalues (first = -6.303e-05+3.090e-01i)
#
# Computing solution error estimates and performing postprocessing
#
# m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
# 1,      +5.118998e+00,      +1.044288e-03,      +2.450951e+03,      +2.013672e-03,      +1.389190e-07
#  Wrote mode 1 to disk
# 2,      +2.767107e+01,      +3.596173e+01,      +6.308857e-01,      +2.211350e-01,      +1.524419e-05
#  Wrote mode 2 to disk
# 3,      +2.991644e+01,      +1.684205e-03,      +8.881471e+03,      +1.552124e-01,      +1.070341e-05
#  Wrote mode 3 to disk
# 4,      +3.226352e+01,      -8.316225e-04,      +1.939794e+04,      +1.437562e-01,      +9.912922e-06
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 4.419e-01, global unknowns = 100881
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.025       0.027       0.026
#   Mesh Preprocessing             0.710       0.710       0.710
# Operator Construction            0.796       0.796       0.796
# Linear Solve                    18.186      18.210      18.200
#   Setup                          0.273       0.273       0.273
#   Preconditioner                18.769      18.794      18.782
# Eigenvalue Solve                 4.070       4.073       4.072
# Div.-Free Projection            23.404      23.411      23.408
# Estimation                       0.062       0.066       0.064
#   Construction                   0.741       0.741       0.741
#   Solve                          1.445       1.448       1.447
# Postprocessing                   0.354       0.359       0.356
# Disk IO                          3.049       3.052       3.051
# --------------------------------------------------------------
# Total                           71.939      71.939      71.939
#
# Error in plotting: 'Data array (E_real) not present in this dataset.'

# %%
# Reading the eigenmode data now
def read_csv_to_dataframe(file_path):
    return pd.read_csv(file_path)

eigen_df = read_csv_to_dataframe(os.path.join(eigen_sim._output_data_dir, 'eig.csv'))
eigen_df.columns = eigen_df.columns.str.strip()
eigen_df["kappa (kHz)"] = eigen_df["Re{f} (GHz)"] / eigen_df["Q"] * 1e6
eigen_df
# Out:
#      m  Re{f} (GHz)  Im{f} (GHz)             Q  Error (Bkwd.)  Error (Abs.)  \
# 0  1.0     5.118998     0.001044   2450.950555   1.389190e-07      0.002014
# 1  2.0    27.671070    35.961731      0.630886   1.524419e-05      0.221135
# 2  3.0    29.916443     0.001684   8881.471455   1.070341e-05      0.155212
# 3  4.0    32.263520    -0.000832  19397.935058   9.912922e-06      0.143756
#
#     kappa (kHz)
# 0  2.088577e+03
# 1  4.386067e+07
# 2  3.368411e+03
# 3  1.663245e+03

# %%
from IPython.display import display, Image
mode_num = 0
display(Image(filename=f"{eigen_sim._output_data_dir}/eig{mode_num}_ErealMag.png"))

# %% [markdown]
# # The Jaynes-Cummings model
#
# The Jaynes-Cummings model describes a system composed of a qubit (two-level system) coupled to a harmonic oscillator. The coupling is such that a qubit excitation can be "converted" into a photon and vice versa. Here we wrote our Jaynes-Cummings model under rotating-wave approximation, which assumes photon number is conserved and fast rotating terms are eliminated.
#
# $\displaystyle H=-\frac{\omega_q}{2}\sigma_z + \omega_r a^\dagger a + g (a\sigma_+ + a^\dagger \sigma_-)$
#
# This model can be solved exactly, resulting in the following eigenenergies:
#
# $\displaystyle E_0 = -\frac{1}{2}\omega_q$,
#
# $\displaystyle E_{n\pm} =  \bigg(n-\frac{1}{2}\bigg) \omega_r \pm \sqrt{\frac{\Delta^2}{4}+n g^2}$,
#
# where $\Delta=\omega_r-\omega_q$ and $n=1,2,\ldots$.

# %% [markdown]
# Let's simulate the transmon-resonator coupled system in scqubits first! We defined our resonator at 6 GHz and set our interaction rate, g to 50 MHz.

# %%
frequency_r = 4.9
g = 0.05
qubit_generic = scq.GenericQubit(E = frequency_q )
osc = scq.Oscillator(
    E_osc=frequency_r,
    truncated_dim=10  # up to 9 photons
)
# Form a list of all components making up the Hilbert space.
hilbertspace = HilbertSpace([qubit_generic, osc])

hilbertspace.add_interaction(
    g_strength = g,
    op1 = qubit_generic.sm_operator,
    op2 = osc.creation_operator,
    add_hc = True
)
evals = hilbertspace.eigenvals(evals_count=6)
print(evals)
# Out:
# [-2.4520622  2.4479378  2.4520622  7.3479378  7.3520622 12.2479378]

# %% [markdown]
# When the detuning between the qubit and the resonator is less than the coupling rate, the energy levels of the qubit and the resonator hybridize and and a Rabi splitting of $2\sqrt{n}g$ forms up between two modes. In this case there will be coherent swapping interactions between two systems. This would change the qubit state when a measurement needs to be done on the qubit.

# %%
frequency_r = 6
g = 0.05
qubit_generic = scq.GenericQubit(E = frequency_q )
osc = scq.Oscillator(
    E_osc=frequency_r,
    truncated_dim=10  # up to 9 photons
)
# Form a list of all components making up the Hilbert space.
hilbertspace = HilbertSpace([qubit_generic, osc])

hilbertspace.add_interaction(
    g_strength = g,
    op1 = qubit_generic.sm_operator,
    op2 = osc.creation_operator,
    add_hc = True
)
evals = hilbertspace.eigenvals(evals_count=6)
print(evals)
# Out:
# [-2.4520622   2.44978565  3.55021435  8.44751848  9.55248152 14.44526057]

# %% [markdown]
# In order to achieve a readout without destroying the stored quantum information, we detune our resonator so that $g << |f_q - f_r|$, which is also called as dispersive limit. In the dispersive limit, there is no exchange interaction between qubits, but a state-dependent frequency shift, $\chi$, between two systems.
#
# In the dispersive limit, the Hamiltonian of the system becomes:
#
# $$
# H_{disp} = (\omega_r + \chi\sigma_z)(a^{\dag}a + 1/2) + (\omega_q + \chi)\sigma_z
# $$
# where $\chi \approx g^2/\Delta $, assuming the qubit energy levels are truncated to 0-1 states and only valid at low photon numbers $n = a^{\dag}a < \Delta^2/(4g^2)$.
#
# From the circuit QED picture of qubit-resonator interaction, g can be estimated as follows (please see Blais et al. for more details).
#
# $$
# g = \omega_r \frac{C_g}{C_{\Sigma}}(\frac{E_J}{2E_C})^{1/4} \sqrt{\pi Z_r / R_K}
# $$
#
# While designing readout system, we need to be mindful about the interplay between readout speed, fidelity and qubit coherence. The qubit readout is done by analyzing the state-dependent frequency and phase shift of the resonator over time. Thus, larger resonator dissipation rate, $\kappa$, and dispersive shift $\chi$, would lead to faster and better state readout.
#
# On the other hand, $\chi$ scales with coupling strength, which requires a stronger coupling between qubit and resonator in order to increase the dispersive shift. A high dispersive shift exposes qubit to the outside world, thus cause a loss in coherence.
#
# When the readout dynamics are analyzed carefully, the maximal state distinguishability is reached when $2\chi = \kappa$ as a simple rule of thumb. As a designer, you should consider your coherence limits and how they are affected by the qubit-resonator coupling. For this purpose, ABCD matrix methods can be used to calculate admittance seen by qubit , $Y_{11}$ to estimate qubit decay.
#
# Here, let's work on a resonator design that satisfies this criteria.

# %% [markdown]
# # Drawing transmon + resonator system

# %% [markdown]
# Let's add a readout resonator to our transmon and simulate below. We will be using a lambda\2 coplanar waveguide based transmission line resonator to do readout.
#
# The resonance frequency of a resonator is given by:
#
# $$
# f_{res} = \frac {c}{\sqrt \epsilon_{eff}} \frac{1}{2l}
# $$
#
# where l is the length of the resonator and $v_p = \frac {c}{\sqrt \epsilon_{eff}}$ is phase velocity of the waveguide.
#
# Phase velocity is dependent on the effective permittivity of the coplanar waveguide. The permittivity of silicon substrate is 11.45, and the mode of coplanar waveguide is distributed between silicon and air. Thus as a first initial guess, we can take $\epsilon_{eff} = (11.45 + 1)/2 \approx 6.22$. Phase velocity $v_p$ can also be extracted using inductance and capacitance of resonator per unit length, $v_p = 1/ \sqrt{L_r C_r}$. A careful EM simulation is required to extract exact parameters, since the phase velocity will also depend on the geometry of the resonator and presence of other layers.
#
# Another important parameter for the resonator is its characteristic impedance, $Z_0 = \sqrt{\frac{L_r}{C_r}}$. For good impedance matching with respect to rest of the microwave circuit and control lines going out of the device, we will adjust our coplanar waveguide geometry to have $Z_0 = 50 \Omega$.
#
#
# The resonator is coupled to a bus waveguide from the open-end. At the open-end the voltage and capacitive energy of the resonator is at maximum, thus, the resonator-bus coupling is highly capacitive. We can control the resonator decay rate $\kappa$, by controlling the length and gap of the coupling region.

# %%
# Let's calculate the approximate length of the resonator for 6 GHz resonant frequency
length_approx = 3e8 / np.sqrt(6.2) /6e9/2 * 1000
print(f"Approximate length of the resonator = {length_approx:.2f} mm")
# Out:
# Approximate length of the resonator = 10.04 mm

# %% [markdown]
# The approximate length we obtained above is a good starting point, however the actual resonance frequency will also depend on the terminations and couplings to the resonator. Capacitances present in the circuit will cause phase delays, and alter the resonance frequency. You may do transmission matrix analysis (ABCD) or similar network simulation methods to include the capacitance phase delays into account.

# %%
design = designs.DesignPlanar({}, overwrite_enabled=True)
design.delete_all_components()
gui = MetalGUI(design)


# Set up chip dimensions 
design.chips.main.size.size_x = '3.5mm'
design.chips.main.size.size_y = '3mm'
design.chips.main.size.size_z = '-280um'
design.chips.main.size.center_x = '0mm'
design.chips.main.size.center_y = '-1mm'

# Resonator and feedline gap width (W) and center conductor width (S) 
design.variables['cpw_width'] = '8 um' #S
design.variables['cpw_gap'] = '4 um' #W 
# Lets create the qubit with a junction and a claw

## Qubit
xmon = Xmon(design, 'xmon', options=Dict(pos_x = '0mm', pos_y='-1.6',
                                    vBar_width='50um', hBar_width='50um', vBar_gap=f'{50}um', hBar_gap=f'{50}um',
                                    cross_width=f'{320}um', cross_height=f'{320}um',
                                    gap_up='40um', gap_left='40um', gap_right='40um', gap_down='40um'))

# Junction
JunctionDolanPinStretch(design, 'junction', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'xmon',pin='down')),
                                                         dist_extend='40um',
                                                         layer=2,
                                                         finger_width='0.4um', t_pad_size='0.385um',
                                                         squid_width='5.4um', prong_width='0.9um'))


# # Claw
CapacitorProngPin(design, 'claw', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'xmon',pin='up')),
                                                prong_width='10um', prong_length='20um', pin_gap_side='10um',
                                                gap_side='20um', pad_thickness='20um',
                                                gap_front='20um', gap_back='20um', trace_width='10um'))

# Lauchpad 1
x1 = '-1.2mm'
y1 = '0mm'
launch_options1 = dict(chip='main', pos_x=x1, pos_y=y1, orientation='360', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP1 = LaunchpadWirebond(design, 'LP1', options = launch_options1)

# Launchpad 2
x2 = '1.2mm'
y1 = '0mm'
launch_options2 = dict(chip='main', pos_x=x2, pos_y=y1, orientation='180', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP2 = LaunchpadWirebond(design, 'LP2', options = launch_options2)

# Using path finder to connect the two launchpads
feedline = RoutePathfinder(design, 'feedline', options = dict(chip='main', trace_width ='8um',
                                            trace_gap ='4um',
                                            fillet='200um',                                                            
                                            hfss_wire_bonds = True,
                                            lead=dict(end_straight='0.1mm'),
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='LP1',
                                                    pin='tie'),
                                                end_pin=Dict(
                                                    component='LP2',
                                                    pin='tie')
                                            )))
#open to ground for resonator
otg1 = OpenToGround(design, 'otg1', options=dict(chip='main', pos_x='-0.2mm',  pos_y='-40um', orientation = 180, width = '8um', gap='4um',))

# Use RouteMeander to fix the total length of the resonator
res1 = RouteMeander(design, 'resonator',  Dict(
        trace_width ='8um',
        trace_gap ='4um',
        total_length='8.6mm',
        hfss_wire_bonds = False,
        fillet='100um',
        lead = dict(start_straight='100um'),
        meander = dict(spacing='0.2mm'),
        pin_inputs=Dict(
        start_pin=Dict(component= 'otg1', pin= 'open'),
        end_pin=Dict(component= 'claw', pin= 'a')), ))


# rebuild the GUI
design.rebuild()
gui.rebuild()
gui.autoscale()
gui.screenshot('sims/qubit-cavity.png')

# %% [markdown]
# ## Eigenmodal Simulation

# %% [markdown]
# Define the hyper-parameters for the eigenmode simulation

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"

import gmsh

gmsh.initialize()

# %%
# Define the hyper-parameters for the eigenmode simulation
from SQDMetal.PALACE.Eigenmode_Simulation import PALACE_Eigenmode_Simulation

#Eigenmode Simulation Options
user_defined_options = {
                 "mesh_refinement":  0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                 "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                 "starting_freq": 4e9,                              #starting frequency in Hz 
                 "number_of_freqs":6,                              #number of eigenmodes to find
                 "solns_to_save": 6,                                #number of electromagnetic field visualizations to save
                 "solver_order": 1,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                 "solver_tol": 5.0e-4,                              #error residual tolerance foriterative solver
                 "solver_maxits": 10,                              #number of solver iterations
                 "mesh_max": 120e-3,                                #maxiumum element size for the mesh in mm
                 "mesh_min": 10e-3,                                 #minimum element size for the mesh in mm
                 "mesh_sampling": 130,                              #number of points to mesh along a geometry
                 "fillet_resolution":12,   
                 "num_cpus": 4,                                      #number of CPU cores to use for simulation
                 "palace_dir":path_to_palace
                }

#Creat the Palace Eigenmode simulation
eigen_sim = PALACE_Eigenmode_Simulation(name ='GMSH_eigen_test',                              #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "sims/",            #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                               #choose simulation mode 'HPC' or 'simPC'                                          
                                        meshing = 'GMSH',                                         #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        view_design_gmsh_gui = False,                               #view design in GMSH gui 
                                        create_files = True)                                        #create mesh, config and HPC batch files

# Assigning the materials to the interfaces, add ports to the design, and add some mesh.


eigen_sim.add_metallic(1, threshold=1e-10, fuse_threshold=1e-10)
eigen_sim.add_ground_plane(threshold=1e-10)

#Fine-mesh the transmon cross qubit region
bounds = design.components["xmon"].qgeometry_bounds()
eigen_sim.fine_mesh_in_rectangle(bounds[0]*1e-3, bounds[1]*1e-3, bounds[2]*1e-3, bounds[3]*1e-3, mesh_sampling=100, mesh_min=15e-6, mesh_max=120e-6)

#Add in the RF ports
# In eigenmode simulations, in order to extract the mode loss to the environment, we need to add ports terminated with 50 Ohm resistors.
eigen_sim.create_port_CPW_on_Launcher('LP1', 20e-6,)
eigen_sim.create_port_CPW_on_Launcher('LP2', 20e-6,)
eigen_sim.create_port_JosephsonJunction('junction', L_J=L_junction, C_J=2e-15)

# #Fine-mesh routed paths and around the xmon

eigen_sim.fine_mesh_around_comp_boundaries(['feedline', 'resonator'], min_size=15e-6, max_size=200e-6)
eigen_sim.fine_mesh_around_comp_boundaries(['xmon','junction'], min_size=14e-6, max_size=75e-6)

eigen_sim.setup_EPR_interfaces(metal_air=MaterialInterface('Aluminium-Vacuum'), substrate_air=MaterialInterface('Silicon-Vacuum'), substrate_metal=MaterialInterface('Silicon-Aluminium'))
eigen_sim.prepare_simulation()

# %%
from SQDMetal.PALACE.Utilities.GMSH_Navigator import GMSH_Navigator

# Let's look how the mesh looks in GMSH
# Open the GMSH GUI

gmsh_nav = GMSH_Navigator(eigen_sim.path_mesh)
gmsh_nav.open_GUI()

# %%
import json

#This is required for Palace to run eigenmode simulation while 50 ohm ports are used
with open(eigen_sim._sim_config, 'r') as file:
    sim_config_dict = json.load(file)
print(sim_config_dict)

del sim_config_dict["Boundaries"]["LumpedPort"][0]["Excitation"]

with open(eigen_sim._sim_config, 'w') as file:
    json.dump(sim_config_dict, file, indent=4)
# Out:
# {'Problem': {'Type': 'Eigenmode', 'Verbose': 2, 'Output': 'outputFiles'}, 'Model': {'Mesh': 'GMSH_eigen_test.msh', 'L0': 0.001, 'Refinement': {'UniformLevels': 0}}, 'Domains': {'Materials': [{'Attributes': [12], 'Permeability': 1.0, 'Permittivity': 1.0, 'LossTan': 0.0}, {'Attributes': [11], 'Permeability': 1, 'Permittivity': 11.45, 'LossTan': 2.7e-06}]}, 'Boundaries': {'PEC': {'Attributes': [1, 2, 3, 4]}, 'LumpedPort': [{'Index': 1, 'Elements': [{'Attributes': [5], 'Direction': [-0.0, -1.0, 0]}, {'Attributes': [6], 'Direction': [0.0, 1.0, 0]}], 'R': 50, 'L': 0, 'C': 0, 'Excitation': True}, {'Index': 2, 'Elements': [{'Attributes': [7], 'Direction': [0.0, 1.0, 0]}, {'Attributes': [8], 'Direction': [-0.0, -1.0, 0]}], 'R': 50, 'L': 0, 'C': 0}, {'Index': 3, 'Attributes': [9], 'Direction': [0.0, -1.0, 0], 'R': 0, 'L': 9.089882230412858e-09, 'C': 2e-15}], 'Postprocessing': {'Dielectric': [{'Index': 1, 'Attributes': [10], 'Type': 'SA', 'Thickness': 2e-06, 'Permittivity': 3.85, 'LossTan': 0.006}, {'Index': 2, 'Attributes': [1, 2, 3, 4], 'Type': 'MS', 'Thickness': 2e-06, 'Permittivity': 10.0, 'LossTan': 0.0003}, {'Index': 3, 'Attributes': [1, 2, 3, 4], 'Type': 'MA', 'Thickness': 2e-06, 'Permittivity': 10.0, 'LossTan': 0.0005}]}, 'Absorbing': {'Attributes': [13], 'Order': 1}}, 'Solver': {'Order': 1, 'Eigenmode': {'N': 6, 'Tol': 0.0005, 'Target': 4.0, 'Save': 6}, 'Linear': {'Type': 'SuperLU', 'KSPType': 'FGMRES', 'Tol': 0.0005, 'MaxIts': 10}}}

# %%
# If all looks good, lets run the simulation
eigen_sim.run()
# Out:
# >> /opt/homebrew/bin/mpirun -n 4 /Users/mcansarihan/qubit_design/palace/build/bin/palace-arm64.bin GMSH_eigen_test.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: v0.13.0-454-gcd4d7b78
# Running with 4 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 3956 elements in 2 iterations of local bisection for under-resolved interior boundaries
# Added 8296 duplicate vertices for interior boundaries in the mesh
# Added 20187 duplicate boundary elements for interior boundaries in the mesh
# Added 1442 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 4 subdomains
#
# Characteristic length and time scales:
#  L₀ = 4.200e-03 m, t₀ = 1.401e-02 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-2.100e-03, -2.800e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+2.100e-03, +8.000e-04, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices         10473       11484       12068       45939
#  edges            65253       68081       69792      272327
#  faces           104263      106077      107200      424310
#  elements         49480       49481       49482      197924
#  neighbors            3           3           3
#
#             minimum     maximum
#  h      6.98754e-05   0.0355707
#  kappa      1.02447     2127.05
#
# Configuring Robin absorbing BC (order 1) at attributes:
#  13
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  5: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,+1.0)
#  6: Rs = 6.667e+01 Ω/sq, n = (+0.0,-0.0,-1.0)
#  7: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,-1.0)
#  8: Rs = 6.667e+01 Ω/sq, n = (+0.0,-0.0,+1.0)
#  9: Ls = 2.454e-09 H/sq, Cs = 7.407e-15 F/sq, n = (+0.0,+0.0,-1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: R = 5.000e+01 Ω
#  Index = 2: R = 5.000e+01 Ω
#  Index = 3: L = 9.090e-09 H,C = 2.000e-15 F
#
# Configuring Dirichlet PEC BC at attributes:
#  1-4
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 45939, ND (p = 1): 272327, RT (p = 1): 424310
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 1.014e+03, δ = 4.965e-06
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 4.000e+00 GHz (3.521e-01)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 272327 unknowns
#  Level 0 (auxiliary) (p = 1): 45939 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.662895e+03
#  1 (restart 0) KSP residual norm 1.368615e-01
# FGMRES solver converged in 1 iteration (avg. reduction factor: 8.230e-05)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.009748e+02
#  1 (restart 0) KSP residual norm 3.203670e-01
#  2 (restart 0) KSP residual norm 1.341477e-01
# FGMRES solver converged in 2 iterations (avg. reduction factor: 2.111e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.467549e+01
#  1 (restart 0) KSP residual norm 4.391094e-01
#  2 (restart 0) KSP residual norm 4.382276e-01
#  3 (restart 0) KSP residual norm 3.351639e-01
#  4 (restart 0) KSP residual norm 1.265485e-02
#  5 (restart 0) KSP residual norm 6.213582e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.115e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.887683e+01
#  1 (restart 0) KSP residual norm 1.034873e+00
#  2 (restart 0) KSP residual norm 1.032334e+00
#  3 (restart 0) KSP residual norm 7.837291e-01
#  4 (restart 0) KSP residual norm 4.318561e-02
#  5 (restart 0) KSP residual norm 3.020065e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.130e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.843162e+01
#  1 (restart 0) KSP residual norm 1.951661e+00
#  2 (restart 0) KSP residual norm 1.938474e+00
#  3 (restart 0) KSP residual norm 1.403192e+00
#  4 (restart 0) KSP residual norm 6.465576e-02
#  5 (restart 0) KSP residual norm 2.899074e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.967e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.113839e+02
#  1 (restart 0) KSP residual norm 2.634201e+00
#  2 (restart 0) KSP residual norm 2.620807e+00
#  3 (restart 0) KSP residual norm 1.861700e+00
#  4 (restart 0) KSP residual norm 7.384244e-02
#  5 (restart 0) KSP residual norm 2.912389e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.921e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.109965e+02
#  1 (restart 0) KSP residual norm 5.897094e-01
#  2 (restart 0) KSP residual norm 3.965088e-01
#  3 (restart 0) KSP residual norm 3.757671e-01
#  4 (restart 0) KSP residual norm 5.886051e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.173e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.603001e+02
#  1 (restart 0) KSP residual norm 1.268494e+00
#  2 (restart 0) KSP residual norm 1.008663e+00
#  3 (restart 0) KSP residual norm 6.285979e-01
#  4 (restart 0) KSP residual norm 4.930081e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.324e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.152188e+02
#  1 (restart 0) KSP residual norm 9.698298e-01
#  2 (restart 0) KSP residual norm 9.580676e-01
#  3 (restart 0) KSP residual norm 6.614119e-01
#  4 (restart 0) KSP residual norm 1.453394e-01
#  5 (restart 0) KSP residual norm 3.889016e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.021e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.011298e+01
#  1 (restart 0) KSP residual norm 1.194809e+00
#  2 (restart 0) KSP residual norm 1.190588e+00
#  3 (restart 0) KSP residual norm 8.898616e-01
#  4 (restart 0) KSP residual norm 7.651459e-02
#  5 (restart 0) KSP residual norm 3.081215e-02
#  6 (restart 0) KSP residual norm 1.871419e-02
#  7 (restart 0) KSP residual norm 6.510610e-03
# FGMRES solver converged in 7 iterations (avg. reduction factor: 2.995e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.180610e+01
#  1 (restart 0) KSP residual norm 5.323940e-01
#  2 (restart 0) KSP residual norm 5.299217e-01
#  3 (restart 0) KSP residual norm 3.454140e-01
#  4 (restart 0) KSP residual norm 1.486979e-01
#  5 (restart 0) KSP residual norm 3.976842e-02
#  6 (restart 0) KSP residual norm 2.898010e-02
#  7 (restart 0) KSP residual norm 1.094731e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.078e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.281648e+01
#  1 (restart 0) KSP residual norm 3.487499e+00
#  2 (restart 0) KSP residual norm 3.430212e+00
#  3 (restart 0) KSP residual norm 2.338796e+00
#  4 (restart 0) KSP residual norm 2.485885e-01
#  5 (restart 0) KSP residual norm 7.963666e-02
#  6 (restart 0) KSP residual norm 5.461395e-02
#  7 (restart 0) KSP residual norm 2.137929e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.376e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.112653e+01
#  1 (restart 0) KSP residual norm 3.261877e+00
#  2 (restart 0) KSP residual norm 3.157831e+00
#  3 (restart 0) KSP residual norm 2.183453e+00
#  4 (restart 0) KSP residual norm 3.153407e-01
#  5 (restart 0) KSP residual norm 7.834126e-02
#  6 (restart 0) KSP residual norm 5.834038e-02
#  7 (restart 0) KSP residual norm 2.260046e-02
#  8 (restart 0) KSP residual norm 7.843510e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.428e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.086361e+02
#  1 (restart 0) KSP residual norm 7.359948e+00
#  2 (restart 0) KSP residual norm 7.189340e+00
#  3 (restart 0) KSP residual norm 3.796999e+00
#  4 (restart 0) KSP residual norm 3.918326e-01
#  5 (restart 0) KSP residual norm 1.279618e-01
#  6 (restart 0) KSP residual norm 9.315934e-02
#  7 (restart 0) KSP residual norm 3.028681e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.106e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.444472e+01
#  1 (restart 0) KSP residual norm 2.197359e+01
#  2 (restart 0) KSP residual norm 2.157832e+01
#  3 (restart 0) KSP residual norm 1.023754e+00
#  4 (restart 0) KSP residual norm 9.982117e-01
#  5 (restart 0) KSP residual norm 1.834542e-01
#  6 (restart 0) KSP residual norm 1.488171e-01
#  7 (restart 0) KSP residual norm 5.779603e-02
#  8 (restart 0) KSP residual norm 1.667588e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.443e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.981857e+01
#  1 (restart 0) KSP residual norm 1.048419e+01
#  2 (restart 0) KSP residual norm 1.038171e+01
#  3 (restart 0) KSP residual norm 5.066387e+00
#  4 (restart 0) KSP residual norm 4.942715e-01
#  5 (restart 0) KSP residual norm 2.256037e-01
#  6 (restart 0) KSP residual norm 1.556314e-01
#  7 (restart 0) KSP residual norm 5.146671e-02
#  8 (restart 0) KSP residual norm 1.728216e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.694e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.921583e+01
#  1 (restart 0) KSP residual norm 2.133111e+01
#  2 (restart 0) KSP residual norm 2.094780e+01
#  3 (restart 0) KSP residual norm 4.035132e+00
#  4 (restart 0) KSP residual norm 7.864883e-01
#  5 (restart 0) KSP residual norm 2.873006e-01
#  6 (restart 0) KSP residual norm 2.005657e-01
#  7 (restart 0) KSP residual norm 6.442742e-02
#  8 (restart 0) KSP residual norm 2.334889e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.620e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.635212e+01
#  1 (restart 0) KSP residual norm 1.436971e+01
#  2 (restart 0) KSP residual norm 1.420028e+01
#  3 (restart 0) KSP residual norm 9.180316e+00
#  4 (restart 0) KSP residual norm 1.154810e+00
#  5 (restart 0) KSP residual norm 2.073939e-01
#  6 (restart 0) KSP residual norm 1.671322e-01
#  7 (restart 0) KSP residual norm 5.536409e-02
#  8 (restart 0) KSP residual norm 1.708168e-02
#  9 (restart 0) KSP residual norm 1.332712e-02
# 10 (restart 0) KSP residual norm 5.657103e-03
# FGMRES solver converged in 10 iterations (avg. reduction factor: 4.507e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.422983e+01
#  1 (restart 0) KSP residual norm 3.195037e+01
#  2 (restart 0) KSP residual norm 3.138456e+01
#  3 (restart 0) KSP residual norm 1.736086e+01
#  4 (restart 0) KSP residual norm 2.063143e+00
#  5 (restart 0) KSP residual norm 4.070235e-01
#  6 (restart 0) KSP residual norm 2.341860e-01
#  7 (restart 0) KSP residual norm 8.391093e-02
#  8 (restart 0) KSP residual norm 2.712504e-02
#  9 (restart 0) KSP residual norm 1.825311e-02
# FGMRES solver converged in 9 iterations (avg. reduction factor: 4.113e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.731600e+01
#  1 (restart 0) KSP residual norm 3.707032e+01
#  2 (restart 0) KSP residual norm 3.646366e+01
#  3 (restart 0) KSP residual norm 7.405966e+00
#  4 (restart 0) KSP residual norm 1.688681e+00
#  5 (restart 0) KSP residual norm 2.525003e-01
#  6 (restart 0) KSP residual norm 1.975443e-01
#  7 (restart 0) KSP residual norm 7.393949e-02
#  8 (restart 0) KSP residual norm 2.293648e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.520e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.372385e+01
#  1 (restart 0) KSP residual norm 3.099122e+01
#  2 (restart 0) KSP residual norm 3.056971e+01
#  3 (restart 0) KSP residual norm 1.713282e+01
#  4 (restart 0) KSP residual norm 1.783108e+00
#  5 (restart 0) KSP residual norm 2.917893e-01
#  6 (restart 0) KSP residual norm 2.014866e-01
#  7 (restart 0) KSP residual norm 9.149610e-02
#  8 (restart 0) KSP residual norm 1.906807e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.705e-01)
#   Eigenvalue approximations and residual norms for  solve.
#   1 EPS nconv=3 first unconverged value (error) -0.000924694+0.000540001i (6.25623816e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.149870e+01
#  1 (restart 0) KSP residual norm 3.630278e+01
#  2 (restart 0) KSP residual norm 3.593475e+01
#  3 (restart 0) KSP residual norm 1.316250e+01
#  4 (restart 0) KSP residual norm 2.294995e+00
#  5 (restart 0) KSP residual norm 5.057860e-01
#  6 (restart 0) KSP residual norm 3.458622e-01
#  7 (restart 0) KSP residual norm 1.305016e-01
#  8 (restart 0) KSP residual norm 3.937294e-02
#  9 (restart 0) KSP residual norm 2.686757e-02
# 10 (restart 0) KSP residual norm 8.567659e-03
# FGMRES solver converged in 10 iterations (avg. reduction factor: 4.189e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.548236e+02
#  1 (restart 0) KSP residual norm 7.664776e+00
#  2 (restart 0) KSP residual norm 7.564870e+00
#  3 (restart 0) KSP residual norm 3.748615e+00
#  4 (restart 0) KSP residual norm 4.852519e-01
#  5 (restart 0) KSP residual norm 1.191806e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.158e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.664949e+01
#  1 (restart 0) KSP residual norm 1.103432e+01
#  2 (restart 0) KSP residual norm 1.076565e+01
#  3 (restart 0) KSP residual norm 4.086431e+00
#  4 (restart 0) KSP residual norm 4.604697e-01
#  5 (restart 0) KSP residual norm 1.057318e-01
#  6 (restart 0) KSP residual norm 8.122815e-02
#  7 (restart 0) KSP residual norm 2.635368e-02
#  8 (restart 0) KSP residual norm 7.436906e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.352e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.285082e+01
#  1 (restart 0) KSP residual norm 1.891719e+01
#  2 (restart 0) KSP residual norm 1.855386e+01
#  3 (restart 0) KSP residual norm 7.012617e+00
#  4 (restart 0) KSP residual norm 8.261698e-01
#  5 (restart 0) KSP residual norm 1.756382e-01
#  6 (restart 0) KSP residual norm 1.232319e-01
#  7 (restart 0) KSP residual norm 3.201089e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.254e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.153355e+02
#  1 (restart 0) KSP residual norm 1.773209e+01
#  2 (restart 0) KSP residual norm 1.725602e+01
#  3 (restart 0) KSP residual norm 4.400576e+00
#  4 (restart 0) KSP residual norm 9.212655e-01
#  5 (restart 0) KSP residual norm 1.841237e-01
#  6 (restart 0) KSP residual norm 1.162846e-01
#  7 (restart 0) KSP residual norm 5.640732e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.366e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.711442e+02
#  1 (restart 0) KSP residual norm 1.278610e+01
#  2 (restart 0) KSP residual norm 1.240172e+01
#  3 (restart 0) KSP residual norm 1.991854e+00
#  4 (restart 0) KSP residual norm 6.184093e-01
#  5 (restart 0) KSP residual norm 8.283108e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.173e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.424764e+02
#  1 (restart 0) KSP residual norm 3.092369e+01
#  2 (restart 0) KSP residual norm 3.022430e+01
#  3 (restart 0) KSP residual norm 1.401259e+01
#  4 (restart 0) KSP residual norm 1.156865e+00
#  5 (restart 0) KSP residual norm 2.336092e-01
#  6 (restart 0) KSP residual norm 1.676950e-01
#  7 (restart 0) KSP residual norm 7.331760e-02
#  8 (restart 0) KSP residual norm 1.886898e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.275e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.254450e+01
#  1 (restart 0) KSP residual norm 4.020922e+01
#  2 (restart 0) KSP residual norm 3.936214e+01
#  3 (restart 0) KSP residual norm 1.648385e+01
#  4 (restart 0) KSP residual norm 1.593809e+00
#  5 (restart 0) KSP residual norm 3.320701e-01
#  6 (restart 0) KSP residual norm 2.474883e-01
#  7 (restart 0) KSP residual norm 9.124603e-02
#  8 (restart 0) KSP residual norm 2.607139e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.651e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.039469e+02
#  1 (restart 0) KSP residual norm 2.180991e+01
#  2 (restart 0) KSP residual norm 2.159315e+01
#  3 (restart 0) KSP residual norm 1.274116e+01
#  4 (restart 0) KSP residual norm 1.564652e+00
#  5 (restart 0) KSP residual norm 3.925583e-01
#  6 (restart 0) KSP residual norm 2.550576e-01
#  7 (restart 0) KSP residual norm 8.025904e-02
#  8 (restart 0) KSP residual norm 3.254025e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.647e-01)
#   2 EPS nconv=3 first unconverged value (error) -0.00122279+0.000512073i (7.45166755e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.761807e+01
#  1 (restart 0) KSP residual norm 1.362564e+01
#  2 (restart 0) KSP residual norm 1.354526e+01
#  3 (restart 0) KSP residual norm 8.322933e+00
#  4 (restart 0) KSP residual norm 1.537997e+00
#  5 (restart 0) KSP residual norm 3.208931e-01
#  6 (restart 0) KSP residual norm 2.275213e-01
#  7 (restart 0) KSP residual norm 9.984659e-02
#  8 (restart 0) KSP residual norm 2.980958e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.742e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.555094e+02
#  1 (restart 0) KSP residual norm 1.855598e+00
#  2 (restart 0) KSP residual norm 1.788373e+00
#  3 (restart 0) KSP residual norm 1.383461e+00
#  4 (restart 0) KSP residual norm 3.064621e-01
#  5 (restart 0) KSP residual norm 9.558870e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.063e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.308818e+01
#  1 (restart 0) KSP residual norm 5.328506e+00
#  2 (restart 0) KSP residual norm 5.254069e+00
#  3 (restart 0) KSP residual norm 3.715491e+00
#  4 (restart 0) KSP residual norm 4.502394e-01
#  5 (restart 0) KSP residual norm 1.279259e-01
#  6 (restart 0) KSP residual norm 7.031173e-02
#  7 (restart 0) KSP residual norm 2.685376e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.172e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.255833e+02
#  1 (restart 0) KSP residual norm 5.102048e+00
#  2 (restart 0) KSP residual norm 5.056831e+00
#  3 (restart 0) KSP residual norm 3.101936e+00
#  4 (restart 0) KSP residual norm 3.510793e-01
#  5 (restart 0) KSP residual norm 8.938480e-02
#  6 (restart 0) KSP residual norm 6.192918e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.811e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.159812e+02
#  1 (restart 0) KSP residual norm 1.505700e+00
#  2 (restart 0) KSP residual norm 1.397301e+00
#  3 (restart 0) KSP residual norm 4.549615e-01
#  4 (restart 0) KSP residual norm 2.465532e-01
#  5 (restart 0) KSP residual norm 5.936839e-02
#  6 (restart 0) KSP residual norm 3.727977e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.617e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.203920e+02
#  1 (restart 0) KSP residual norm 7.163422e+00
#  2 (restart 0) KSP residual norm 7.071564e+00
#  3 (restart 0) KSP residual norm 3.913816e+00
#  4 (restart 0) KSP residual norm 1.302061e+00
#  5 (restart 0) KSP residual norm 2.360270e-01
#  6 (restart 0) KSP residual norm 1.341524e-01
#  7 (restart 0) KSP residual norm 6.894340e-02
#  8 (restart 0) KSP residual norm 1.673342e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.295e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.408038e+02
#  1 (restart 0) KSP residual norm 7.693249e+00
#  2 (restart 0) KSP residual norm 7.354268e+00
#  3 (restart 0) KSP residual norm 5.080719e+00
#  4 (restart 0) KSP residual norm 8.304087e-01
#  5 (restart 0) KSP residual norm 1.598100e-01
#  6 (restart 0) KSP residual norm 1.023178e-01
#  7 (restart 0) KSP residual norm 3.863311e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.099e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.215076e+02
#  1 (restart 0) KSP residual norm 7.707592e+00
#  2 (restart 0) KSP residual norm 7.626996e+00
#  3 (restart 0) KSP residual norm 4.521950e+00
#  4 (restart 0) KSP residual norm 7.901912e-01
#  5 (restart 0) KSP residual norm 1.744442e-01
#  6 (restart 0) KSP residual norm 1.048342e-01
#  7 (restart 0) KSP residual norm 4.669481e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.252e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.128007e+01
#  1 (restart 0) KSP residual norm 1.146024e+01
#  2 (restart 0) KSP residual norm 1.117306e+01
#  3 (restart 0) KSP residual norm 7.725965e+00
#  4 (restart 0) KSP residual norm 9.380040e-01
#  5 (restart 0) KSP residual norm 2.389492e-01
#  6 (restart 0) KSP residual norm 1.852060e-01
#  7 (restart 0) KSP residual norm 6.725408e-02
#  8 (restart 0) KSP residual norm 2.667489e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.669e-01)
#   3 EPS nconv=3 first unconverged value (error) -0.00137015+0.000547249i (6.13154591e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.212515e+01
#  1 (restart 0) KSP residual norm 1.657717e+00
#  2 (restart 0) KSP residual norm 1.330527e+00
#  3 (restart 0) KSP residual norm 1.312911e+00
#  4 (restart 0) KSP residual norm 1.048802e+00
#  5 (restart 0) KSP residual norm 1.612273e-01
#  6 (restart 0) KSP residual norm 9.891313e-02
#  7 (restart 0) KSP residual norm 5.571613e-02
#  8 (restart 0) KSP residual norm 1.489980e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.528e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.293636e+01
#  1 (restart 0) KSP residual norm 1.169947e+00
#  2 (restart 0) KSP residual norm 1.138662e+00
#  3 (restart 0) KSP residual norm 5.545552e-01
#  4 (restart 0) KSP residual norm 1.505733e-01
#  5 (restart 0) KSP residual norm 4.273618e-02
#  6 (restart 0) KSP residual norm 3.065009e-02
#  7 (restart 0) KSP residual norm 1.357983e-02
#  8 (restart 0) KSP residual norm 4.873901e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.475e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.838713e+01
#  1 (restart 0) KSP residual norm 4.226484e+00
#  2 (restart 0) KSP residual norm 4.045739e+00
#  3 (restart 0) KSP residual norm 2.536461e+00
#  4 (restart 0) KSP residual norm 2.871074e-01
#  5 (restart 0) KSP residual norm 1.214239e-01
#  6 (restart 0) KSP residual norm 9.067043e-02
#  7 (restart 0) KSP residual norm 2.946947e-02
#  8 (restart 0) KSP residual norm 9.057301e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.341e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.357337e+00
#  1 (restart 0) KSP residual norm 2.216332e+00
#  2 (restart 0) KSP residual norm 2.201353e+00
#  3 (restart 0) KSP residual norm 1.030192e+00
#  4 (restart 0) KSP residual norm 3.584505e-01
#  5 (restart 0) KSP residual norm 7.393818e-02
#  6 (restart 0) KSP residual norm 3.901641e-02
#  7 (restart 0) KSP residual norm 1.776136e-02
#  8 (restart 0) KSP residual norm 5.018518e-03
#  9 (restart 0) KSP residual norm 3.216483e-03
# 10 (restart 0) KSP residual norm 9.920966e-04
# FGMRES solver converged in 10 iterations (avg. reduction factor: 4.162e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.233802e+01
#  1 (restart 0) KSP residual norm 8.712586e-01
#  2 (restart 0) KSP residual norm 8.684067e-01
#  3 (restart 0) KSP residual norm 7.153204e-01
#  4 (restart 0) KSP residual norm 6.504149e-01
#  5 (restart 0) KSP residual norm 1.162748e-01
#  6 (restart 0) KSP residual norm 7.756409e-02
#  7 (restart 0) KSP residual norm 3.462748e-02
#  8 (restart 0) KSP residual norm 1.200538e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.602e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.911528e+01
#  1 (restart 0) KSP residual norm 3.809743e+00
#  2 (restart 0) KSP residual norm 3.769828e+00
#  3 (restart 0) KSP residual norm 2.059990e+00
#  4 (restart 0) KSP residual norm 7.601289e-01
#  5 (restart 0) KSP residual norm 1.460818e-01
#  6 (restart 0) KSP residual norm 6.111294e-02
#  7 (restart 0) KSP residual norm 2.956521e-02
#  8 (restart 0) KSP residual norm 6.744708e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.702e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.056090e+01
#  1 (restart 0) KSP residual norm 1.947418e+00
#  2 (restart 0) KSP residual norm 1.899941e+00
#  3 (restart 0) KSP residual norm 1.455116e+00
#  4 (restart 0) KSP residual norm 1.074494e+00
#  5 (restart 0) KSP residual norm 1.608949e-01
#  6 (restart 0) KSP residual norm 6.755411e-02
#  7 (restart 0) KSP residual norm 4.634330e-02
#  8 (restart 0) KSP residual norm 1.049662e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.690e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.032534e+02
#  1 (restart 0) KSP residual norm 4.030559e+00
#  2 (restart 0) KSP residual norm 3.806897e+00
#  3 (restart 0) KSP residual norm 2.647494e+00
#  4 (restart 0) KSP residual norm 8.200242e-01
#  5 (restart 0) KSP residual norm 1.625217e-01
#  6 (restart 0) KSP residual norm 1.212213e-01
#  7 (restart 0) KSP residual norm 5.663520e-02
#  8 (restart 0) KSP residual norm 2.044578e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.444e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.093519e+02
#  1 (restart 0) KSP residual norm 4.497597e+00
#  2 (restart 0) KSP residual norm 4.492593e+00
#  3 (restart 0) KSP residual norm 3.312881e+00
#  4 (restart 0) KSP residual norm 8.851128e-01
#  5 (restart 0) KSP residual norm 1.744421e-01
#  6 (restart 0) KSP residual norm 1.235296e-01
#  7 (restart 0) KSP residual norm 5.677653e-02
#  8 (restart 0) KSP residual norm 2.184113e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.448e-01)
#   4 EPS nconv=3 first unconverged value (error) -0.00125244+0.00042094i (5.23226036e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.247686e+02
#  1 (restart 0) KSP residual norm 3.699040e+00
#  2 (restart 0) KSP residual norm 3.688750e+00
#  3 (restart 0) KSP residual norm 2.819233e+00
#  4 (restart 0) KSP residual norm 1.132757e+00
#  5 (restart 0) KSP residual norm 2.442227e-01
#  6 (restart 0) KSP residual norm 1.683778e-01
#  7 (restart 0) KSP residual norm 6.537387e-02
#  8 (restart 0) KSP residual norm 2.695056e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.482e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.281626e+01
#  1 (restart 0) KSP residual norm 1.649385e+00
#  2 (restart 0) KSP residual norm 1.532629e+00
#  3 (restart 0) KSP residual norm 1.011466e+00
#  4 (restart 0) KSP residual norm 2.058408e-01
#  5 (restart 0) KSP residual norm 7.060482e-02
#  6 (restart 0) KSP residual norm 5.503705e-02
#  7 (restart 0) KSP residual norm 2.051785e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.356e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.638086e+01
#  1 (restart 0) KSP residual norm 6.630901e-01
#  2 (restart 0) KSP residual norm 5.143487e-01
#  3 (restart 0) KSP residual norm 4.431124e-01
#  4 (restart 0) KSP residual norm 2.468823e-01
#  5 (restart 0) KSP residual norm 8.025922e-02
#  6 (restart 0) KSP residual norm 6.395140e-02
#  7 (restart 0) KSP residual norm 2.220281e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.355e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.144393e+01
#  1 (restart 0) KSP residual norm 1.443214e+00
#  2 (restart 0) KSP residual norm 1.442940e+00
#  3 (restart 0) KSP residual norm 1.075453e+00
#  4 (restart 0) KSP residual norm 3.044939e-01
#  5 (restart 0) KSP residual norm 6.840261e-02
#  6 (restart 0) KSP residual norm 3.918490e-02
#  7 (restart 0) KSP residual norm 1.294887e-02
#  8 (restart 0) KSP residual norm 4.669933e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.770e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.276570e+00
#  1 (restart 0) KSP residual norm 1.709770e+00
#  2 (restart 0) KSP residual norm 1.627755e+00
#  3 (restart 0) KSP residual norm 1.113789e+00
#  4 (restart 0) KSP residual norm 4.284757e-01
#  5 (restart 0) KSP residual norm 6.725719e-02
#  6 (restart 0) KSP residual norm 2.787601e-02
#  7 (restart 0) KSP residual norm 1.579823e-02
#  8 (restart 0) KSP residual norm 4.566456e-03
#  9 (restart 0) KSP residual norm 2.126979e-03
# FGMRES solver converged in 9 iterations (avg. reduction factor: 4.196e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.324556e+01
#  1 (restart 0) KSP residual norm 1.752203e+00
#  2 (restart 0) KSP residual norm 1.714271e+00
#  3 (restart 0) KSP residual norm 1.165312e+00
#  4 (restart 0) KSP residual norm 3.762322e-01
#  5 (restart 0) KSP residual norm 1.219081e-01
#  6 (restart 0) KSP residual norm 9.881083e-02
#  7 (restart 0) KSP residual norm 3.445493e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.347e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.958225e+01
#  1 (restart 0) KSP residual norm 1.745345e+00
#  2 (restart 0) KSP residual norm 1.736681e+00
#  3 (restart 0) KSP residual norm 9.641938e-01
#  4 (restart 0) KSP residual norm 5.961206e-01
#  5 (restart 0) KSP residual norm 9.327395e-02
#  6 (restart 0) KSP residual norm 5.191663e-02
#  7 (restart 0) KSP residual norm 2.076967e-02
#  8 (restart 0) KSP residual norm 6.782871e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.508e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.149915e+01
#  1 (restart 0) KSP residual norm 3.377695e+00
#  2 (restart 0) KSP residual norm 3.366354e+00
#  3 (restart 0) KSP residual norm 9.318514e-01
#  4 (restart 0) KSP residual norm 4.579717e-01
#  5 (restart 0) KSP residual norm 1.222163e-01
#  6 (restart 0) KSP residual norm 9.321934e-02
#  7 (restart 0) KSP residual norm 3.157451e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.202e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.570093e+01
#  1 (restart 0) KSP residual norm 2.700516e+00
#  2 (restart 0) KSP residual norm 2.688874e+00
#  3 (restart 0) KSP residual norm 2.096020e+00
#  4 (restart 0) KSP residual norm 6.836781e-01
#  5 (restart 0) KSP residual norm 1.587631e-01
#  6 (restart 0) KSP residual norm 9.656681e-02
#  7 (restart 0) KSP residual norm 3.393274e-02
#  8 (restart 0) KSP residual norm 1.117272e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.647e-01)
#   5 EPS nconv=3 first unconverged value (error) -0.0012144+0.000411591i (4.36342420e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.805082e+01
#  1 (restart 0) KSP residual norm 3.184621e+00
#  2 (restart 0) KSP residual norm 3.000390e+00
#  3 (restart 0) KSP residual norm 2.119179e+00
#  4 (restart 0) KSP residual norm 9.146184e-01
#  5 (restart 0) KSP residual norm 1.657548e-01
#  6 (restart 0) KSP residual norm 9.607457e-02
#  7 (restart 0) KSP residual norm 5.581531e-02
#  8 (restart 0) KSP residual norm 1.712806e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.437e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.379850e+01
#  1 (restart 0) KSP residual norm 2.604561e+00
#  2 (restart 0) KSP residual norm 2.370571e+00
#  3 (restart 0) KSP residual norm 1.472303e+00
#  4 (restart 0) KSP residual norm 4.782545e-01
#  5 (restart 0) KSP residual norm 1.038749e-01
#  6 (restart 0) KSP residual norm 6.732604e-02
#  7 (restart 0) KSP residual norm 2.610241e-02
#  8 (restart 0) KSP residual norm 7.595634e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.656e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.446574e+01
#  1 (restart 0) KSP residual norm 9.981210e-01
#  2 (restart 0) KSP residual norm 9.480924e-01
#  3 (restart 0) KSP residual norm 4.398746e-01
#  4 (restart 0) KSP residual norm 1.593905e-01
#  5 (restart 0) KSP residual norm 4.287294e-02
#  6 (restart 0) KSP residual norm 2.915434e-02
#  7 (restart 0) KSP residual norm 8.442133e-03
#  8 (restart 0) KSP residual norm 3.488908e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.530e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.960317e+01
#  1 (restart 0) KSP residual norm 1.555244e+00
#  2 (restart 0) KSP residual norm 1.550026e+00
#  3 (restart 0) KSP residual norm 1.175834e+00
#  4 (restart 0) KSP residual norm 4.351068e-01
#  5 (restart 0) KSP residual norm 6.872742e-02
#  6 (restart 0) KSP residual norm 4.797153e-02
#  7 (restart 0) KSP residual norm 2.041638e-02
#  8 (restart 0) KSP residual norm 5.303799e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.581e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.093618e+01
#  1 (restart 0) KSP residual norm 3.481030e+00
#  2 (restart 0) KSP residual norm 3.355497e+00
#  3 (restart 0) KSP residual norm 2.313650e+00
#  4 (restart 0) KSP residual norm 2.459126e-01
#  5 (restart 0) KSP residual norm 8.606540e-02
#  6 (restart 0) KSP residual norm 5.249183e-02
#  7 (restart 0) KSP residual norm 1.560542e-02
#  8 (restart 0) KSP residual norm 5.849483e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.596e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.899138e+01
#  1 (restart 0) KSP residual norm 1.466211e+00
#  2 (restart 0) KSP residual norm 1.269078e+00
#  3 (restart 0) KSP residual norm 1.240493e+00
#  4 (restart 0) KSP residual norm 6.317925e-01
#  5 (restart 0) KSP residual norm 9.152998e-02
#  6 (restart 0) KSP residual norm 7.213749e-02
#  7 (restart 0) KSP residual norm 3.437852e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.375e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.179607e+01
#  1 (restart 0) KSP residual norm 6.929101e-01
#  2 (restart 0) KSP residual norm 6.117752e-01
#  3 (restart 0) KSP residual norm 5.996338e-01
#  4 (restart 0) KSP residual norm 4.688025e-01
#  5 (restart 0) KSP residual norm 1.158299e-01
#  6 (restart 0) KSP residual norm 8.888871e-02
#  7 (restart 0) KSP residual norm 4.135175e-02
#  8 (restart 0) KSP residual norm 1.501184e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.412e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.851189e+01
#  1 (restart 0) KSP residual norm 4.256953e+00
#  2 (restart 0) KSP residual norm 4.190674e+00
#  3 (restart 0) KSP residual norm 3.044467e+00
#  4 (restart 0) KSP residual norm 7.086109e-01
#  5 (restart 0) KSP residual norm 1.376412e-01
#  6 (restart 0) KSP residual norm 7.288630e-02
#  7 (restart 0) KSP residual norm 4.326363e-02
#  8 (restart 0) KSP residual norm 1.332503e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.378e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.269746e+01
#  1 (restart 0) KSP residual norm 3.018943e+00
#  2 (restart 0) KSP residual norm 3.012197e+00
#  3 (restart 0) KSP residual norm 2.064943e+00
#  4 (restart 0) KSP residual norm 5.374500e-01
#  5 (restart 0) KSP residual norm 1.227933e-01
#  6 (restart 0) KSP residual norm 9.992965e-02
#  7 (restart 0) KSP residual norm 3.396953e-02
#  8 (restart 0) KSP residual norm 1.050144e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.447e-01)
#   6 EPS nconv=3 first unconverged value (error) -0.00121327+0.000385515i (2.15712959e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.896783e+01
#  1 (restart 0) KSP residual norm 5.449786e+00
#  2 (restart 0) KSP residual norm 5.433834e+00
#  3 (restart 0) KSP residual norm 2.043473e+00
#  4 (restart 0) KSP residual norm 1.142210e+00
#  5 (restart 0) KSP residual norm 2.086166e-01
#  6 (restart 0) KSP residual norm 1.395308e-01
#  7 (restart 0) KSP residual norm 4.565574e-02
#  8 (restart 0) KSP residual norm 1.407940e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.853e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.793066e+00
#  1 (restart 0) KSP residual norm 1.670966e+00
#  2 (restart 0) KSP residual norm 1.648377e+00
#  3 (restart 0) KSP residual norm 1.059542e+00
#  4 (restart 0) KSP residual norm 1.638021e-01
#  5 (restart 0) KSP residual norm 5.182044e-02
#  6 (restart 0) KSP residual norm 3.849041e-02
#  7 (restart 0) KSP residual norm 9.577847e-03
#  8 (restart 0) KSP residual norm 3.144954e-03
#  9 (restart 0) KSP residual norm 2.405979e-03
# 10 (restart 0) KSP residual norm 4.416225e-04
# FGMRES solver converged in 10 iterations (avg. reduction factor: 4.168e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.944840e+00
#  1 (restart 0) KSP residual norm 2.527964e+00
#  2 (restart 0) KSP residual norm 2.364993e+00
#  3 (restart 0) KSP residual norm 1.597648e+00
#  4 (restart 0) KSP residual norm 3.725896e-01
#  5 (restart 0) KSP residual norm 7.968864e-02
#  6 (restart 0) KSP residual norm 3.444798e-02
#  7 (restart 0) KSP residual norm 1.868119e-02
#  8 (restart 0) KSP residual norm 4.363016e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.855e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 9.176667e+00
#  1 (restart 0) KSP residual norm 1.878243e+00
#  2 (restart 0) KSP residual norm 1.875213e+00
#  3 (restart 0) KSP residual norm 1.259341e+00
#  4 (restart 0) KSP residual norm 2.752038e-01
#  5 (restart 0) KSP residual norm 8.418634e-02
#  6 (restart 0) KSP residual norm 5.001491e-02
#  7 (restart 0) KSP residual norm 9.110881e-03
#  8 (restart 0) KSP residual norm 4.218424e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.827e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.041122e+00
#  1 (restart 0) KSP residual norm 1.823908e+00
#  2 (restart 0) KSP residual norm 1.807920e+00
#  3 (restart 0) KSP residual norm 1.224098e+00
#  4 (restart 0) KSP residual norm 4.875901e-01
#  5 (restart 0) KSP residual norm 1.162037e-01
#  6 (restart 0) KSP residual norm 6.189432e-02
#  7 (restart 0) KSP residual norm 2.531136e-02
#  8 (restart 0) KSP residual norm 5.758189e-03
#  9 (restart 0) KSP residual norm 4.321555e-03
# 10 (restart 0) KSP residual norm 8.871261e-04
# FGMRES solver converged in 10 iterations (avg. reduction factor: 4.213e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.579162e+01
#  1 (restart 0) KSP residual norm 4.375491e+00
#  2 (restart 0) KSP residual norm 4.328405e+00
#  3 (restart 0) KSP residual norm 2.511379e+00
#  4 (restart 0) KSP residual norm 5.016124e-01
#  5 (restart 0) KSP residual norm 1.324452e-01
#  6 (restart 0) KSP residual norm 7.206620e-02
#  7 (restart 0) KSP residual norm 2.298030e-02
#  8 (restart 0) KSP residual norm 8.302211e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.660e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.900223e+01
#  1 (restart 0) KSP residual norm 3.032180e+00
#  2 (restart 0) KSP residual norm 3.014025e+00
#  3 (restart 0) KSP residual norm 2.173616e+00
#  4 (restart 0) KSP residual norm 4.400667e-01
#  5 (restart 0) KSP residual norm 8.116769e-02
#  6 (restart 0) KSP residual norm 6.163932e-02
#  7 (restart 0) KSP residual norm 1.942461e-02
#  8 (restart 0) KSP residual norm 6.469262e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.686e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.508496e+01
#  1 (restart 0) KSP residual norm 2.188101e+00
#  2 (restart 0) KSP residual norm 2.046033e+00
#  3 (restart 0) KSP residual norm 9.973688e-01
#  4 (restart 0) KSP residual norm 6.370716e-01
#  5 (restart 0) KSP residual norm 1.400841e-01
#  6 (restart 0) KSP residual norm 1.047576e-01
#  7 (restart 0) KSP residual norm 3.957490e-02
#  8 (restart 0) KSP residual norm 1.112516e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.653e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.542868e+01
#  1 (restart 0) KSP residual norm 1.737766e+00
#  2 (restart 0) KSP residual norm 1.678893e+00
#  3 (restart 0) KSP residual norm 1.427500e+00
#  4 (restart 0) KSP residual norm 2.602981e-01
#  5 (restart 0) KSP residual norm 1.147665e-01
#  6 (restart 0) KSP residual norm 8.590372e-02
#  7 (restart 0) KSP residual norm 2.032880e-02
#  8 (restart 0) KSP residual norm 8.850947e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.546e-01)
#   7 EPS nconv=3 first unconverged value (error) -0.00082715+0.000362681i (1.39843476e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.326238e+01
#  1 (restart 0) KSP residual norm 3.383447e+00
#  2 (restart 0) KSP residual norm 3.296647e+00
#  3 (restart 0) KSP residual norm 2.081639e+00
#  4 (restart 0) KSP residual norm 8.854402e-01
#  5 (restart 0) KSP residual norm 1.913382e-01
#  6 (restart 0) KSP residual norm 1.082012e-01
#  7 (restart 0) KSP residual norm 5.741675e-02
#  8 (restart 0) KSP residual norm 1.614892e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.491e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.163611e+01
#  1 (restart 0) KSP residual norm 1.104910e+00
#  2 (restart 0) KSP residual norm 1.038779e+00
#  3 (restart 0) KSP residual norm 6.112111e-01
#  4 (restart 0) KSP residual norm 2.051117e-01
#  5 (restart 0) KSP residual norm 5.861791e-02
#  6 (restart 0) KSP residual norm 3.196771e-02
#  7 (restart 0) KSP residual norm 1.025475e-02
#  8 (restart 0) KSP residual norm 3.241665e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.594e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.361353e+00
#  1 (restart 0) KSP residual norm 1.162481e+00
#  2 (restart 0) KSP residual norm 1.124017e+00
#  3 (restart 0) KSP residual norm 9.459586e-01
#  4 (restart 0) KSP residual norm 3.323105e-01
#  5 (restart 0) KSP residual norm 9.802402e-02
#  6 (restart 0) KSP residual norm 4.598781e-02
#  7 (restart 0) KSP residual norm 2.248980e-02
#  8 (restart 0) KSP residual norm 5.176331e-03
#  9 (restart 0) KSP residual norm 3.046264e-03
# 10 (restart 1) KSP residual norm 1.078135e-03
# FGMRES solver did NOT converge in 10 iterations (avg. reduction factor: 4.896e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 7.920e-04 (norm(b) = 1.361e+00)!
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.611365e+01
#  1 (restart 0) KSP residual norm 9.709349e-01
#  2 (restart 0) KSP residual norm 8.117590e-01
#  3 (restart 0) KSP residual norm 4.237666e-01
#  4 (restart 0) KSP residual norm 3.021231e-01
#  5 (restart 0) KSP residual norm 4.870424e-02
#  6 (restart 0) KSP residual norm 3.185172e-02
#  7 (restart 0) KSP residual norm 1.438553e-02
#  8 (restart 0) KSP residual norm 3.823245e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.523e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.625786e+01
#  1 (restart 0) KSP residual norm 1.553653e+00
#  2 (restart 0) KSP residual norm 1.527980e+00
#  3 (restart 0) KSP residual norm 1.282719e+00
#  4 (restart 0) KSP residual norm 5.320078e-01
#  5 (restart 0) KSP residual norm 5.882377e-02
#  6 (restart 0) KSP residual norm 3.784159e-02
#  7 (restart 0) KSP residual norm 2.401657e-02
#  8 (restart 0) KSP residual norm 3.592432e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.492e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.795561e+01
#  1 (restart 0) KSP residual norm 3.186400e+00
#  2 (restart 0) KSP residual norm 3.167479e+00
#  3 (restart 0) KSP residual norm 2.261095e+00
#  4 (restart 0) KSP residual norm 3.254954e-01
#  5 (restart 0) KSP residual norm 6.840321e-02
#  6 (restart 0) KSP residual norm 5.427102e-02
#  7 (restart 0) KSP residual norm 1.652945e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.310e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.139560e+01
#  1 (restart 0) KSP residual norm 5.524732e+00
#  2 (restart 0) KSP residual norm 5.464637e+00
#  3 (restart 0) KSP residual norm 3.199026e+00
#  4 (restart 0) KSP residual norm 8.169000e-01
#  5 (restart 0) KSP residual norm 1.394401e-01
#  6 (restart 0) KSP residual norm 8.413930e-02
#  7 (restart 0) KSP residual norm 4.075829e-02
#  8 (restart 0) KSP residual norm 1.022239e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.541e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.968484e+01
#  1 (restart 0) KSP residual norm 2.777192e+00
#  2 (restart 0) KSP residual norm 2.550249e+00
#  3 (restart 0) KSP residual norm 1.687540e+00
#  4 (restart 0) KSP residual norm 4.723141e-01
#  5 (restart 0) KSP residual norm 1.001212e-01
#  6 (restart 0) KSP residual norm 6.137920e-02
#  7 (restart 0) KSP residual norm 3.403455e-02
#  8 (restart 0) KSP residual norm 9.643591e-03
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.358e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.393931e+01
#  1 (restart 0) KSP residual norm 2.334270e+00
#  2 (restart 0) KSP residual norm 2.247587e+00
#  3 (restart 0) KSP residual norm 1.971285e+00
#  4 (restart 0) KSP residual norm 1.036289e+00
#  5 (restart 0) KSP residual norm 1.764327e-01
#  6 (restart 0) KSP residual norm 1.362598e-01
#  7 (restart 0) KSP residual norm 3.748914e-02
#  8 (restart 0) KSP residual norm 1.514052e-02
# FGMRES solver converged in 8 iterations (avg. reduction factor: 3.522e-01)
#   8 EPS nconv=10 first unconverged value (error) -0.000370202+0.0017122i (6.45179995e-03)
#
#  Linear eigensolve converged (10 eigenpairs) due to CONVERGED_TOL; iterations 8
#  Total number of linear systems solved: 84
#  Total number of linear solver iterations: 622
#  Found 10 converged eigenvalues (first = -1.241e+00+3.984e-01i)
#
# Computing solution error estimates and performing postprocessing
#
#  m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
#  1,      +4.526320e+00,      +1.409453e+01,      +5.251502e-01,      +1.771199e-01,      +4.516226e-07
#  Wrote mode 1 to disk
#  2,      +4.885333e+00,      +5.129264e-03,      +4.762219e+02,      +2.765055e-03,      +7.050551e-09
#  Wrote mode 2 to disk
#  3,      +6.041593e+00,      +1.166847e-01,      +2.589336e+01,      +1.719701e-02,      +4.385014e-08
#  Wrote mode 3 to disk
#  4,      +6.191725e+00,      -6.161481e-04,      +5.024543e+03,      +8.077678e-03,      +2.059702e-08
#  Wrote mode 4 to disk
#  5,      +8.474486e+00,      +8.103149e+00,      +7.234902e-01,      +1.254403e-01,      +3.198519e-07
#  Wrote mode 5 to disk
#  6,      +1.190033e+01,      +1.338343e-01,      +4.446200e+01,      +7.262944e-02,      +1.851929e-07
#  Wrote mode 6 to disk
#  7,      +1.238617e+01,      +3.167277e-02,      +1.955341e+02,      +1.300529e-01,      +3.316126e-07
#  8,      +1.244917e+01,      +1.124651e+00,      +5.557219e+00,      +1.186129e-01,      +3.024426e-07
#  9,      +1.738925e+01,      +1.833036e-01,      +4.743555e+01,      +2.113204e-01,      +5.388240e-07
# 10,      +1.862203e+01,      +1.340622e-03,      +6.945292e+03,      +4.791186e-02,      +1.221651e-07
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 5.389e-01, global unknowns = 272327
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.077       0.095       0.086
#   Mesh Preprocessing             2.789       2.790       2.790
# Operator Construction            2.784       2.801       2.792
# Linear Solve                    48.839      48.855      48.850
#   Setup                          0.717       0.717       0.717
#   Preconditioner                53.067      53.081      53.073
# Eigenvalue Solve                 8.963       8.984       8.970
# Div.-Free Projection            39.267      39.287      39.279
# Estimation                       0.350       0.358       0.353
#   Construction                   2.567       2.569       2.568
#   Solve                         23.477      23.482      23.479
# Postprocessing                   2.906       2.917       2.911
# Disk IO                         16.655      16.661      16.660
# --------------------------------------------------------------
# Total                          202.550     202.550     202.550
#
# Error in plotting: 'Data array (E_real) not present in this dataset.'

# %%
# Reading the eigenmode data now
def read_csv_to_dataframe(file_path):
    return pd.read_csv(file_path)

eigen_df = read_csv_to_dataframe(os.path.join(eigen_sim._output_data_dir, 'eig.csv'))
eigen_df.columns = eigen_df.columns.str.strip()
eigen_df["kappa (kHz)"] = eigen_df["Re{f} (GHz)"] / eigen_df["Q"] * 1e6
eigen_df
# Out:
#      m  Re{f} (GHz)  Im{f} (GHz)           Q  Error (Bkwd.)  Error (Abs.)  \
# 0  1.0     3.284153     3.973750    0.648660   1.220228e-07      0.040100
# 1  2.0     3.457894     5.710651    0.584519   1.493081e-07      0.049067
# 2  3.0     4.036649    -4.759141    0.655634   3.625261e-07      0.119137
# 3  4.0     4.192185     2.903657    0.878129   1.522220e-07      0.050025
# 4  5.0     4.843151    -0.003033  798.338301   9.170083e-08      0.030136
# 5  6.0     5.835183     0.158321   18.435053   1.285800e-07      0.042255
# 6  7.0     6.245550    -0.004420  706.539122   6.962802e-08      0.022882
#
#     kappa (kHz)
# 0  5.062980e+06
# 1  5.915792e+06
# 2  6.156863e+06
# 3  4.773995e+06
# 4  6.066539e+03
# 5  3.165265e+05
# 6  8.839638e+03

# %% [markdown]
# Here, we got the list of eigenmodes of our transmon-resonator system. Now, we can look at field distribution and their concentration to find out qubit and cavity modes.

# %%
from IPython.display import display, Image
mode_num = 4
display(Image(filename=f"{eigen_sim._output_data_dir}/eig{mode_num}_ErealMag.png"))

# %%
from IPython.display import display, Image
mode_num = 6
display(Image(filename=f"{eigen_sim._output_data_dir}/eig{mode_num}_ErealMag.png"))

# %% [markdown]
# After finding the correct modes, we can utilize energy-participation ratio method to calculate parameters of the circuit. Energy-participation ratio is a measure of how much energy is stored in a given component compared to the total energy of the system. Using this method, all self and cross-Kerr matrix elements of the Hamiltonian can be extracted from the system. It can be used to estimate the coupling strength between different components in a circuit, such as qubits and resonators.

# %%
mode_dict = eigen_sim.retrieve_mode_port_EPR_from_file(eigen_sim._output_data_dir)

#get particpation ratios and frequencies from the simulation
participation_ratios = mode_dict['mat_mode_port']
frequencies = mode_dict['eigenfrequencies']

# %%
participation_ratios
# Out:
# array([[-4.02467632e-04],
#        [-3.88908025e-03],
#        [ 3.93792388e-03],
#        [ 1.63634052e-03],
#        [ 2.25104582e+01],
#        [ 3.77715402e-02],
#        [-5.41848410e-01]])

# %%
qubit_idx = 4
cavity_idx = 6

linear_qubit_freq = eigen_df['Re{f} (GHz)'][qubit_idx]*1e9
linear_res_freq = eigen_df['Re{f} (GHz)'][cavity_idx]*1e9
P_qubit = abs(participation_ratios[qubit_idx, 0])
P_cav = abs(participation_ratios[cavity_idx, 0])

# %%
# Participation ratios for qubit and cavity modes
P_qubit, P_cav
# Out:
# (22.51045819486, 0.5418484097669)

# %% [markdown]
# Qiskit metal and pyEPR open-source packages offer a way to directly calculate qubit parameters based on the eigenmode profile obtained from HFSS. With Palace, we are analytically calculating the participation ratios of the qubit-resonator system.

# %%
#Constants used for calculations
from scipy.constants import Planck, e, hbar
phi0 = hbar/(2*e)

#Josephson Energy (Ej) and linear inductance (Lj)
delta_super = (1.8e-4 / 2) * e
Lj = L_junction 
Ej = phi0**2 / Lj

#Normalize Participation Ratios
P_qubit_normalised = P_qubit / (P_qubit + P_cav)
P_cav_normalised = P_cav / (P_qubit + P_cav)

#Enter in Frequencies from Simulation
omega_qubit = 2 * np.pi * linear_qubit_freq
omega_res = 2 * np.pi * linear_res_freq

#phi zero-point fluctuations for qubit
phi_zpf_sq = P_qubit_normalised * hbar * 2 * omega_qubit  / (2*Ej)

#anharmonicity qubit (self kerr)
anharm_qubit = P_qubit_normalised**2 * hbar * omega_qubit**2 / (8*Ej)

#anharmonicity resonator (self kerr)
anharm_res = P_cav_normalised**2 * hbar * omega_res**2 / (8*Ej)

#Charging Energy (Ec)
Ec = anharm_qubit * hbar

#Total Capacitance
C_total = e**2 / (2*Ec)


#cross kerr - dispersive shift (chi)
cross_kerr = (P_qubit_normalised * P_cav_normalised* hbar * omega_qubit * omega_res) / (4*Ej)

#lamb-shift of qubit frequency
lamb_shift_qubit = anharm_qubit - cross_kerr/2

#lamb-shift of res frequency
lamb_shift_res = anharm_res - cross_kerr/2

#detuning, delta
delta = ((linear_res_freq - anharm_res/(2*np.pi)) - (linear_qubit_freq - anharm_qubit/(2*np.pi)))

#resonator-qubit coupling strength (g)
disp_shift_qubit = cross_kerr
g_rwa = np.sqrt(disp_shift_qubit * delta  * (1 + delta/anharm_qubit))

# coupling strength (g) from SQuADDS Paper
Delta = omega_res - omega_qubit      # rad/s
Sigma = omega_res + omega_qubit      # rad/s
alpha = -anharm_qubit                # rad/s (already angular)
chi = -disp_shift_qubit              # rad/s (already angular)
# Denominator (s/rad)
denom = (alpha / (Delta * (Delta - alpha))) - (alpha / (Sigma * (Sigma + alpha)))

# Convert to linear frequency in MHz (optional, for reporting)
g_rad = np.sqrt(chi / (2 * denom))     # rad/s
g_MHz = g_rad / (2 * np.pi * 1e6)    # MHz

# %%
hamiltonian_params = [
    ("Ej", Ej / (hbar * 2 * np.pi *  1e9), "GHz"),
    ("Ec", anharm_qubit  / (2*np.pi*1e9), "GHz"),
    ("Ej/Ec", Ej/Ec, "unitless"),
    ("Lj", Lj/1e-9, "nH"),
    ("C_qubit", C_total/1e-15, "fF"),
    ("Participation Ratio Qubit", P_qubit, "unitless"),
    ("Participation Ratio Qubit (Normalized)", P_qubit_normalised, "unitless"),
    ("Participation Ratio Cavity", P_cav, "unitless"),
    ("Participation Ratio Cavity (Normalized)", P_cav_normalised, "unitless"),
    ("Linear Qubit Frequency", linear_qubit_freq/1e9, "GHz"),
    ("Qubit Frequency", linear_qubit_freq/1e9 - lamb_shift_qubit/(2*np.pi*1e9), "GHz"),
    ("Qubit Anharmonicity", anharm_qubit / (2*np.pi*1e6), "MHz"),
    ("Linear Cavity Frequency", linear_res_freq/1e9, "GHz"),
    ("Cavity Frequency", linear_res_freq/1e9 - lamb_shift_res/(2*np.pi*1e9), "GHz"),
    ("Cavity Anharmonicity", anharm_res / (2*np.pi*1e6), "MHz"),
    ("Dispersive Shift (chi)", cross_kerr/ (2*np.pi*1e6), "MHz"),

    ("Cavity-Qubit Coupling [RWA], g", g_rwa/(2*np.pi*1e6), "MHz"),
    ("Detuning", delta/1e9, "GHz"),
    ("Flux_ZPF_squared", phi_zpf_sq, "unitless"),
]

# Create DataFrame
hamiltonian_df = pd.DataFrame(hamiltonian_params, columns=["Parameter", "Value", "Unit"])

# Function to format values
def format_float_six_decimal(val, idx):
    return f"{val:.6f}"

# Apply formatting
hamiltonian_df['Value'] = [
    format_float_six_decimal(val, idx) for idx, val in enumerate(hamiltonian_df['Value'])
]

print(hamiltonian_df.to_string(index=False))
# Out:
#                               Parameter      Value     Unit
#                                      Ej  17.982798      GHz
#                                      Ec   0.155471      GHz
#                                   Ej/Ec 115.666776 unitless
#                                      Lj   9.089882       nH
#                                 C_qubit 124.590846       fF
#               Participation Ratio Qubit  22.510458 unitless
#  Participation Ratio Qubit (Normalized)   0.976495 unitless
#              Participation Ratio Cavity   0.541848 unitless
# Participation Ratio Cavity (Normalized)   0.023505 unitless
#                  Linear Qubit Frequency   4.843151      GHz
#                         Qubit Frequency   4.692506      GHz
#                     Qubit Anharmonicity 155.470726      MHz
#                 Linear Cavity Frequency   6.245550      GHz
#                        Cavity Frequency   6.250226      GHz
#                    Cavity Anharmonicity   0.149803      MHz
#                  Dispersive Shift (chi)   9.651944      MHz
#          Cavity-Qubit Coupling [RWA], g  78.795288      MHz
#                                Detuning   1.557720      GHz
#                        Flux_ZPF_squared   0.262991 unitless

# %% [markdown]
# # Extra References
#
# You can refer to following articles to learn more about superconducting quantum devices and the design concerns.
#
# 1. Megrant, A. & Chen, Y. Scaling up superconducting quantum computers. Nat. Electron. 1–3 (2025).
#
# 2. Levenson-Falk, E. M. & Shanto, S. A. A Review of Design Concerns in Superconducting Quantum Circuits. arXiv (2024).
#
# 3. Vool, U. & Devoret, M. Introduction to quantum electromagnetic circuits. Int. J. Circuit Theory Appl. 45, 897–934 (2017).
#
# 4. Bardin, J. C., Slichter, D. H. & Reilly, D. J. Microwaves in Quantum Computing. IEEE J. Microwaves 1, 403–427 (2020).
#
# 5. Sete, E. A., Martinis, J. M. & Korotkov, A. N. Quantum theory of a bandpass Purcell filter for qubit readout. Phys. Rev. A 92, 012325 (2015).
#
# 6. Rasmussen, S. E. et al. Superconducting Circuit Companion—an Introduction with Worked Examples. PRX Quantum 2, 040204 (2021).
#
# 7. Gao, Y. Y., Rol, M. A., Touzard, S. & Wang, C. Practical Guide for Building Superconducting Quantum Devices. PRX Quantum 2, 040202 (2021).
#
# 8. Blais, A., Grimsmo, A. L., Girvin, S. M. & Wallraff, A. Circuit quantum electrodynamics. Rev. Mod. Phys. 93, 025005 (2021).
#
# 9. Blais, A., Girvin, S. M. & Oliver, W. D. Quantum information processing and quantum optics with circuit quantum electrodynamics. Nat. Phys. 16, 247–256 (2020).
#
# 10. Krantz, P. et al. A quantum engineer’s guide to superconducting qubits. Appl. Phys. Rev. 6, 021318 (2019).
#
# 11. Kjaergaard, M. et al. Superconducting Qubits: Current State of Play. Annu. Rev. Conden. Ma. P. 11, 1–27 (2019).
#
# 12. Siddiqi, I. Engineering high-coherence superconducting qubits. Nat. Rev. Mater. 6, 875–891 (2021).
#
# 13. Wendin, G. Quantum information processing with superconducting circuits: a review. Rep. Prog. Phys. 80, 106001 (2017).
#
# 14. Koch, J. et al. Charge-insensitive qubit design derived from the Cooper pair box. Phys. Rev. A 76, 042319 (2007).
#
# 15. Houck, A. A. et al. Controlling the Spontaneous Emission of a Superconducting Transmon Qubit. Phys. Rev. Lett. 101, 080502 (2008).
#
# 16. Barends, R. et al. Superconducting quantum circuits at the surface code threshold for fault tolerance. Nature 508, 500–503 (2014).
#
# 17. Barends, R. et al. Coherent Josephson Qubit Suitable for Scalable Quantum Integrated Circuits. Phys. Rev. Lett. 111, 080502 (2013).
#
# 18. Minev, Z. K. et al. Energy-participation quantization of Josephson circuits. npj Quantum Inf. 7, 131 (2021).
#
# 19. Minev, Z. K., McConkey, T. G., Takita, M., Corcoles, A. D. & Gambetta, J. M. Circuit quantum electrodynamics (cQED) with modular quasi-lumped models. arXiv:2103.10344 (2021).

# %% [markdown]
# ## Supplementary : Simulating resonator and feedline only

# %%
design = designs.DesignPlanar({}, overwrite_enabled=True)
design.delete_all_components()
gui = MetalGUI(design)


# Set up chip dimensions 
design.chips.main.size.size_x = '3.5mm'
design.chips.main.size.size_y = '3mm'
design.chips.main.size.size_z = '-280um'
design.chips.main.size.center_x = '0mm'
design.chips.main.size.center_y = '-1mm'

# Resonator and feedline gap width (W) and center conductor width (S) 
design.variables['cpw_width'] = '8 um' #S
design.variables['cpw_gap'] = '4 um' #W 
# Lets create the qubit with a junction and a claw


# Lauchpad 1
x1 = '-1.2mm'
y1 = '0mm'
launch_options1 = dict(chip='main', pos_x=x1, pos_y=y1, orientation='360', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP1 = LaunchpadWirebond(design, 'LP1', options = launch_options1)

# Launchpad 2
x2 = '1.2mm'
y1 = '0mm'
launch_options2 = dict(chip='main', pos_x=x2, pos_y=y1, orientation='180', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP2 = LaunchpadWirebond(design, 'LP2', options = launch_options2)

# Using path finder to connect the two launchpads
feedline = RoutePathfinder(design, 'feedline', options = dict(chip='main', trace_width ='8um',
                                            trace_gap ='4um',
                                            fillet='200um',                                                            
                                            hfss_wire_bonds = True,
                                            lead=dict(end_straight='0.1mm'),
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='LP1',
                                                    pin='tie'),
                                                end_pin=Dict(
                                                    component='LP2',
                                                    pin='tie')
                                            )))
#open to ground for resonator
otg1 = OpenToGround(design, 'otg1', options=dict(chip='main', pos_x='-0.2mm',  pos_y='-20um', orientation = 180, width = '8um', gap='4um',))
otg2 = OpenToGround(design, 'otg2', options=dict(chip='main', pos_x='-0mm',  pos_y='-1.6mm', orientation = 180, width = '8um', gap='4um',))
# Use RouteMeander to fix the total length of the resonator
res1 = RouteMeander(design, 'resonator',  Dict(
        trace_width ='8um',
        trace_gap ='4um',
        total_length='8.6mm',
        hfss_wire_bonds = False,
        fillet='100um',
        lead = dict(start_straight='100um'),
        meander = dict(spacing='0.2mm'),
        pin_inputs=Dict(
        start_pin=Dict(component= 'otg1', pin= 'open'),
        end_pin=Dict(component= 'otg2', pin= 'open')), ))

# rebuild the GUI
design.rebuild()
gui.rebuild()
gui.autoscale()
gui.screenshot('sims/qubit-cavity.png')

# %%
## Eigenmodal Simulation


#Define the hyper-parameters for the eigenmode simulation
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"

import gmsh
gmsh.initialize()
# Define the hyper-parameters for the eigenmode simulation
from SQDMetal.PALACE.Eigenmode_Simulation import PALACE_Eigenmode_Simulation

#Eigenmode Simulation Options
user_defined_options = {
                 "mesh_refinement":  0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                 "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                 "starting_freq": 3e9,                              #starting frequency in Hz 
                 "number_of_freqs":6,                              #number of eigenmodes to find
                 "solns_to_save": 6,                                #number of electromagnetic field visualizations to save
                 "solver_order": 1,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                 "solver_tol": 5.0e-4,                              #error residual tolerance foriterative solver
                 "solver_maxits": 10,                              #number of solver iterations
                 "mesh_max": 120e-3,                                #maxiumum element size for the mesh in mm
                 "mesh_min": 10e-3,                                 #minimum element size for the mesh in mm
                 "mesh_sampling": 130,                              #number of points to mesh along a geometry
                 "fillet_resolution":12,   
                 "num_cpus": 4,                                      #number of CPU cores to use for simulation
                 "palace_dir":path_to_palace
                }

#Creat the Palace Eigenmode simulation
eigen_sim = PALACE_Eigenmode_Simulation(name ='GMSH_eigen_test',                              #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "sims/",            #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                               #choose simulation mode 'HPC' or 'simPC'                                          
                                        meshing = 'GMSH',                                         #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        view_design_gmsh_gui = False,                               #view design in GMSH gui 
                                        create_files = True)                                        #create mesh, config and HPC batch files

# Assigning the materials to the interfaces, add ports to the design, and add some mesh.


eigen_sim.add_metallic(1, threshold=1e-10, fuse_threshold=1e-10)
eigen_sim.add_ground_plane(threshold=1e-10)

#Fine-mesh the transmon cross qubit region
# bounds = design.components["xmon"].qgeometry_bounds()
# eigen_sim.fine_mesh_in_rectangle(bounds[0]*1e-3, bounds[1]*1e-3, bounds[2]*1e-3, bounds[3]*1e-3, mesh_sampling=100, mesh_min=15e-6, mesh_max=120e-6)

#Add in the RF ports
eigen_sim.create_port_CPW_on_Launcher('LP1', 20e-6,)
eigen_sim.create_port_CPW_on_Launcher('LP2', 20e-6,)
# eigen_sim.create_port_JosephsonJunction('junction', L_J=L_junction, C_J=2e-15)

# #Fine-mesh routed paths

eigen_sim.fine_mesh_around_comp_boundaries(['feedline', 'resonator'], min_size=25e-6, max_size=250e-6)
# eigen_sim.fine_mesh_around_comp_boundaries(['xmon','junction'], min_size=14e-6, max_size=75e-6)

eigen_sim.setup_EPR_interfaces(metal_air=MaterialInterface('Aluminium-Vacuum'), substrate_air=MaterialInterface('Silicon-Vacuum'), substrate_metal=MaterialInterface('Silicon-Aluminium'))
eigen_sim.prepare_simulation()


# from SQDMetal.PALACE.Utilities.GMSH_Navigator import GMSH_Navigator

# # Let's look how the mesh looks in GMSH
# # Open the GMSH GUI

# gmsh_nav = GMSH_Navigator(eigen_sim.path_mesh)
# gmsh_nav.open_GUI()

# %%
import json

#This is required for Palace to run eigenmode simulation while 50 ohm ports are used
with open(eigen_sim._sim_config, 'r') as file:
    sim_config_dict = json.load(file)
print(sim_config_dict)

del sim_config_dict["Boundaries"]["LumpedPort"][0]["Excitation"]

with open(eigen_sim._sim_config, 'w') as file:
    json.dump(sim_config_dict, file, indent=4)
# If all looks good, lets run the simulation
eigen_sim.run()
# Reading the eigenmode data now
def read_csv_to_dataframe(file_path):
    return pd.read_csv(file_path)

eigen_df = read_csv_to_dataframe(os.path.join(eigen_sim._output_data_dir, 'eig.csv'))
eigen_df.columns = eigen_df.columns.str.strip()
eigen_df["kappa (kHz)"] = eigen_df["Re{f} (GHz)"] / eigen_df["Q"] * 1e6
eigen_df
# Reading the eigenmode data now
def read_csv_to_dataframe(file_path):
    return pd.read_csv(file_path)

eigen_df = read_csv_to_dataframe(os.path.join(eigen_sim._output_data_dir, 'eig.csv'))
eigen_df.columns = eigen_df.columns.str.strip()
eigen_df["kappa (kHz)"] = eigen_df["Re{f} (GHz)"] / eigen_df["Q"] * 1e6
eigen_df
# Out:
# {'Problem': {'Type': 'Eigenmode', 'Verbose': 2, 'Output': 'outputFiles'}, 'Model': {'Mesh': 'GMSH_eigen_test.msh', 'L0': 0.001, 'Refinement': {'UniformLevels': 0}}, 'Domains': {'Materials': [{'Attributes': [10], 'Permeability': 1.0, 'Permittivity': 1.0, 'LossTan': 0.0}, {'Attributes': [9], 'Permeability': 1, 'Permittivity': 11.45, 'LossTan': 2.7e-06}]}, 'Boundaries': {'PEC': {'Attributes': [1, 2, 3]}, 'LumpedPort': [{'Index': 1, 'Elements': [{'Attributes': [4], 'Direction': [-0.0, -1.0, 0]}, {'Attributes': [5], 'Direction': [0.0, 1.0, 0]}], 'R': 50, 'L': 0, 'C': 0, 'Excitation': True}, {'Index': 2, 'Elements': [{'Attributes': [6], 'Direction': [0.0, 1.0, 0]}, {'Attributes': [7], 'Direction': [-0.0, -1.0, 0]}], 'R': 50, 'L': 0, 'C': 0}], 'Postprocessing': {'Dielectric': [{'Index': 1, 'Attributes': [8], 'Type': 'SA', 'Thickness': 2e-06, 'Permittivity': 3.85, 'LossTan': 0.006}, {'Index': 2, 'Attributes': [1, 2, 3], 'Type': 'MS', 'Thickness': 2e-06, 'Permittivity': 10.0, 'LossTan': 0.0003}, {'Index': 3, 'Attributes': [1, 2, 3], 'Type': 'MA', 'Thickness': 2e-06, 'Permittivity': 10.0, 'LossTan': 0.0005}]}, 'Absorbing': {'Attributes': [11], 'Order': 1}}, 'Solver': {'Order': 1, 'Eigenmode': {'N': 6, 'Tol': 0.0005, 'Target': 3.0, 'Save': 6}, 'Linear': {'Type': 'SuperLU', 'KSPType': 'FGMRES', 'Tol': 0.0005, 'MaxIts': 10}}}
# >> /opt/homebrew/bin/mpirun -n 4 /Users/mcansarihan/qubit_design/palace/build/bin/palace-arm64.bin GMSH_eigen_test.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: v0.13.0-454-gcd4d7b78
# Running with 4 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 4422 elements in 2 iterations of local bisection for under-resolved interior boundaries
# Added 3051 duplicate vertices for interior boundaries in the mesh
# Added 8276 duplicate boundary elements for interior boundaries in the mesh
# Added 216 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 4 subdomains
#
# Characteristic length and time scales:
#  L₀ = 4.200e-03 m, t₀ = 1.401e-02 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-2.100e-03, -2.800e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+2.100e-03, +8.000e-04, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices          2432        2535        2627       10140
#  edges            13281       13488       13702       53952
#  faces            19291       19631       19887       78526
#  elements          8500        8679        8793       34716
#  neighbors            3           3           3
#
#             minimum     maximum
#  h      5.10986e-05   0.0780433
#  kappa      1.09075     3458.06
#
# Configuring Robin absorbing BC (order 1) at attributes:
#  11
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  4: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,+1.0)
#  5: Rs = 6.667e+01 Ω/sq, n = (-0.0,-0.0,-1.0)
#  6: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,-1.0)
#  7: Rs = 6.667e+01 Ω/sq, n = (+0.0,-0.0,+1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: R = 5.000e+01 Ω
#  Index = 2: R = 5.000e+01 Ω
#
# Configuring Dirichlet PEC BC at attributes:
#  1-3
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 10140, ND (p = 1): 53952, RT (p = 1): 78526
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 6.392e+02, δ = 2.505e-06
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 3.000e+00 GHz (2.641e-01)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 53952 unknowns
#  Level 0 (auxiliary) (p = 1): 10140 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 5.384167e+03
#  1 (restart 0) KSP residual norm 1.118798e-01
# FGMRES solver converged in 1 iteration (avg. reduction factor: 2.078e-05)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.030341e+02
#  1 (restart 0) KSP residual norm 3.074932e-01
#  2 (restart 0) KSP residual norm 8.466444e-02
# FGMRES solver converged in 2 iterations (avg. reduction factor: 1.671e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.728349e+02
#  1 (restart 0) KSP residual norm 2.701322e-01
#  2 (restart 0) KSP residual norm 2.663491e-01
#  3 (restart 0) KSP residual norm 3.763055e-02
# FGMRES solver converged in 3 iterations (avg. reduction factor: 4.301e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.281645e+02
#  1 (restart 0) KSP residual norm 3.590926e-01
#  2 (restart 0) KSP residual norm 3.571594e-01
#  3 (restart 0) KSP residual norm 1.540569e-01
# FGMRES solver converged in 3 iterations (avg. reduction factor: 7.772e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 8.593222e+02
#  1 (restart 0) KSP residual norm 1.507538e+00
#  2 (restart 0) KSP residual norm 1.473648e+00
#  3 (restart 0) KSP residual norm 1.151011e-01
# FGMRES solver converged in 3 iterations (avg. reduction factor: 5.117e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.384766e+03
#  1 (restart 0) KSP residual norm 2.281643e+00
#  2 (restart 0) KSP residual norm 2.273675e+00
#  3 (restart 0) KSP residual norm 6.490105e-02
# FGMRES solver converged in 3 iterations (avg. reduction factor: 3.605e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.645371e+02
#  1 (restart 0) KSP residual norm 1.204769e+01
#  2 (restart 0) KSP residual norm 1.152694e+01
#  3 (restart 0) KSP residual norm 2.229385e-01
#  4 (restart 0) KSP residual norm 6.908473e-02
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.173e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.997704e+02
#  1 (restart 0) KSP residual norm 8.094064e+00
#  2 (restart 0) KSP residual norm 7.890346e+00
#  3 (restart 0) KSP residual norm 8.612465e-01
#  4 (restart 0) KSP residual norm 1.141482e-01
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.397e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.281518e+02
#  1 (restart 0) KSP residual norm 2.355281e+01
#  2 (restart 0) KSP residual norm 2.257013e+01
#  3 (restart 0) KSP residual norm 7.423338e-01
#  4 (restart 0) KSP residual norm 1.670575e-01
#  5 (restart 0) KSP residual norm 1.182470e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.048e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.384384e+02
#  1 (restart 0) KSP residual norm 2.998798e+01
#  2 (restart 0) KSP residual norm 2.975234e+01
#  3 (restart 0) KSP residual norm 1.482822e+00
#  4 (restart 0) KSP residual norm 1.491384e-01
#  5 (restart 0) KSP residual norm 1.063033e-01
#  6 (restart 0) KSP residual norm 4.361877e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.609e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.189944e+02
#  1 (restart 0) KSP residual norm 4.686611e+01
#  2 (restart 0) KSP residual norm 4.439577e+01
#  3 (restart 0) KSP residual norm 8.798149e-01
#  4 (restart 0) KSP residual norm 2.083932e-01
#  5 (restart 0) KSP residual norm 1.377908e-01
#  6 (restart 0) KSP residual norm 6.206134e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.563e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.526739e+02
#  1 (restart 0) KSP residual norm 2.785211e+01
#  2 (restart 0) KSP residual norm 2.755512e+01
#  3 (restart 0) KSP residual norm 3.565110e-01
#  4 (restart 0) KSP residual norm 1.326950e-01
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.393e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.827210e+02
#  1 (restart 0) KSP residual norm 2.201326e+01
#  2 (restart 0) KSP residual norm 1.926970e+01
#  3 (restart 0) KSP residual norm 7.773355e-01
#  4 (restart 0) KSP residual norm 1.953418e-01
#  5 (restart 0) KSP residual norm 6.409357e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.037e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.583967e+02
#  1 (restart 0) KSP residual norm 6.374221e+01
#  2 (restart 0) KSP residual norm 6.215934e+01
#  3 (restart 0) KSP residual norm 1.388493e+00
#  4 (restart 0) KSP residual norm 3.814767e-01
#  5 (restart 0) KSP residual norm 1.603171e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.036e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.391898e+02
#  1 (restart 0) KSP residual norm 3.593080e+01
#  2 (restart 0) KSP residual norm 3.339025e+01
#  3 (restart 0) KSP residual norm 1.482806e+00
#  4 (restart 0) KSP residual norm 4.837312e-01
#  5 (restart 0) KSP residual norm 1.313311e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.078e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.280797e+02
#  1 (restart 0) KSP residual norm 8.322207e+01
#  2 (restart 0) KSP residual norm 8.177011e+01
#  3 (restart 0) KSP residual norm 2.522339e+00
#  4 (restart 0) KSP residual norm 7.676251e-01
#  5 (restart 0) KSP residual norm 2.742058e-01
#  6 (restart 0) KSP residual norm 1.633569e-01
#  7 (restart 0) KSP residual norm 3.109785e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.045e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.058083e+02
#  1 (restart 0) KSP residual norm 9.478571e+01
#  2 (restart 0) KSP residual norm 9.434393e+01
#  3 (restart 0) KSP residual norm 1.587199e+00
#  4 (restart 0) KSP residual norm 5.383394e-01
#  5 (restart 0) KSP residual norm 3.162713e-01
#  6 (restart 0) KSP residual norm 1.419539e-01
#  7 (restart 0) KSP residual norm 2.517875e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 2.761e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.241030e+01
#  1 (restart 0) KSP residual norm 7.163656e+00
#  2 (restart 0) KSP residual norm 6.842795e+00
#  3 (restart 0) KSP residual norm 2.613542e+00
#  4 (restart 0) KSP residual norm 7.330089e-01
#  5 (restart 0) KSP residual norm 1.061516e-01
#  6 (restart 0) KSP residual norm 6.549354e-02
#  7 (restart 0) KSP residual norm 1.605681e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.006e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.670069e+02
#  1 (restart 0) KSP residual norm 6.548088e+01
#  2 (restart 0) KSP residual norm 6.428549e+01
#  3 (restart 0) KSP residual norm 1.441087e+00
#  4 (restart 0) KSP residual norm 5.540403e-01
#  5 (restart 0) KSP residual norm 2.482670e-01
#  6 (restart 0) KSP residual norm 8.821197e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.629e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.701271e+02
#  1 (restart 0) KSP residual norm 9.606782e+01
#  2 (restart 0) KSP residual norm 9.417277e+01
#  3 (restart 0) KSP residual norm 1.862060e+00
#  4 (restart 0) KSP residual norm 6.672892e-01
#  5 (restart 0) KSP residual norm 3.157784e-01
#  6 (restart 0) KSP residual norm 1.641656e-01
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.762e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.100848e+02
#  1 (restart 0) KSP residual norm 4.482717e+01
#  2 (restart 0) KSP residual norm 4.462580e+01
#  3 (restart 0) KSP residual norm 1.023985e+00
#  4 (restart 0) KSP residual norm 4.256765e-01
#  5 (restart 0) KSP residual norm 2.523677e-01
#  6 (restart 0) KSP residual norm 1.035223e-01
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.810e-01)
#   Eigenvalue approximations and residual norms for  solve.
#   1 EPS nconv=0 first unconverged value (error) -0.00157708+0.000485657i (9.92038322e-03)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.824542e+02
#  1 (restart 0) KSP residual norm 8.253767e+01
#  2 (restart 0) KSP residual norm 8.077901e+01
#  3 (restart 0) KSP residual norm 2.703695e+00
#  4 (restart 0) KSP residual norm 7.078908e-01
#  5 (restart 0) KSP residual norm 3.409894e-01
#  6 (restart 0) KSP residual norm 1.994071e-01
#  7 (restart 0) KSP residual norm 2.989859e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 2.879e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.061540e+03
#  1 (restart 0) KSP residual norm 5.229992e+00
#  2 (restart 0) KSP residual norm 2.696270e+00
#  3 (restart 0) KSP residual norm 1.131618e+00
#  4 (restart 0) KSP residual norm 3.250829e-01
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.323e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.468890e+03
#  1 (restart 0) KSP residual norm 6.143861e+00
#  2 (restart 0) KSP residual norm 6.008130e+00
#  3 (restart 0) KSP residual norm 3.299278e-01
# FGMRES solver converged in 3 iterations (avg. reduction factor: 6.079e-02)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 3.050659e+02
#  1 (restart 0) KSP residual norm 1.880998e+01
#  2 (restart 0) KSP residual norm 1.872408e+01
#  3 (restart 0) KSP residual norm 1.291729e+00
#  4 (restart 0) KSP residual norm 4.324649e-01
#  5 (restart 0) KSP residual norm 8.549251e-02
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.948e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 6.969827e+02
#  1 (restart 0) KSP residual norm 2.127249e+01
#  2 (restart 0) KSP residual norm 2.077791e+01
#  3 (restart 0) KSP residual norm 1.467862e+00
#  4 (restart 0) KSP residual norm 4.893156e-01
#  5 (restart 0) KSP residual norm 1.078888e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.730e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.974035e+02
#  1 (restart 0) KSP residual norm 2.008207e+01
#  2 (restart 0) KSP residual norm 1.988065e+01
#  3 (restart 0) KSP residual norm 1.378629e+00
#  4 (restart 0) KSP residual norm 3.441911e-01
#  5 (restart 0) KSP residual norm 1.635361e-01
#  6 (restart 0) KSP residual norm 9.230846e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.786e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.294215e+02
#  1 (restart 0) KSP residual norm 4.545523e+01
#  2 (restart 0) KSP residual norm 4.383957e+01
#  3 (restart 0) KSP residual norm 2.005778e+00
#  4 (restart 0) KSP residual norm 4.658140e-01
#  5 (restart 0) KSP residual norm 2.174725e-01
#  6 (restart 0) KSP residual norm 9.303771e-02
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.451e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 4.473539e+02
#  1 (restart 0) KSP residual norm 2.082204e+01
#  2 (restart 0) KSP residual norm 1.953748e+01
#  3 (restart 0) KSP residual norm 1.043971e+00
#  4 (restart 0) KSP residual norm 2.638179e-01
#  5 (restart 0) KSP residual norm 1.120743e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.904e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.286597e+01
#  1 (restart 0) KSP residual norm 2.295585e+01
#  2 (restart 0) KSP residual norm 2.259418e+01
#  3 (restart 0) KSP residual norm 3.016435e+00
#  4 (restart 0) KSP residual norm 5.126320e-01
#  5 (restart 0) KSP residual norm 1.067991e-01
#  6 (restart 0) KSP residual norm 4.574366e-02
#  7 (restart 0) KSP residual norm 1.028611e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 2.818e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.318861e+02
#  1 (restart 0) KSP residual norm 2.401937e+01
#  2 (restart 0) KSP residual norm 2.333306e+01
#  3 (restart 0) KSP residual norm 4.619932e+00
#  4 (restart 0) KSP residual norm 5.269528e-01
#  5 (restart 0) KSP residual norm 1.587924e-01
# FGMRES solver converged in 5 iterations (avg. reduction factor: 1.850e-01)
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.404999e+02
#  1 (restart 0) KSP residual norm 5.311771e+01
#  2 (restart 0) KSP residual norm 4.755112e+01
#  3 (restart 0) KSP residual norm 7.393880e+00
#  4 (restart 0) KSP residual norm 8.992449e-01
#  5 (restart 0) KSP residual norm 2.220602e-01
#  6 (restart 0) KSP residual norm 1.523688e-01
#  7 (restart 0) KSP residual norm 1.929561e-02
# FGMRES solver converged in 7 iterations (avg. reduction factor: 2.600e-01)
#   2 EPS nconv=6 first unconverged value (error) -1.12693e-05+0.00180247i (2.64381697e-02)
#
#  Linear eigensolve converged (6 eigenpairs) due to CONVERGED_TOL; iterations 2
#  Total number of linear systems solved: 32
#  Total number of linear solver iterations: 158
#  Found 6 converged eigenvalues (first = 4.047e-01+3.894e-01i)
#
# Computing solution error estimates and performing postprocessing
#
# m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
# 1,      +4.423454e+00,      -4.597743e+00,      +6.938339e-01,      +1.093164e-01,      +1.380610e-07
#  Wrote mode 1 to disk
# 2,      +4.878758e+00,      +5.217674e-02,      +4.675490e+01,      +1.156093e-01,      +1.460089e-07
#  Wrote mode 2 to disk
# 3,      +4.970088e+00,      -7.227603e+00,      +6.068088e-01,      +4.313579e-01,      +5.447809e-07
#  Wrote mode 3 to disk
# 4,      +6.173305e+00,      +5.248101e-03,      +5.881467e+02,      +7.720956e-02,      +9.751172e-08
#  Wrote mode 4 to disk
# 5,      +6.918562e+00,      +7.203057e-02,      +4.802779e+01,      +8.472593e-02,      +1.070044e-07
#  Wrote mode 5 to disk
# 6,      +8.346343e+00,      +1.434276e-01,      +2.910030e+01,      +1.126438e-01,      +1.422629e-07
#  Wrote mode 6 to disk
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 4.453e-01, global unknowns = 53952
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.019       0.021       0.020
#   Mesh Preprocessing             0.530       0.530       0.530
# Operator Construction            0.326       0.328       0.327
# Linear Solve                     1.805       1.817       1.811
#   Setup                          0.112       0.112       0.112
#   Preconditioner                 1.864       1.875       1.869
# Eigenvalue Solve                 0.432       0.435       0.433
# Div.-Free Projection             1.398       1.402       1.400
# Estimation                       0.042       0.043       0.042
#   Construction                   0.460       0.461       0.461
#   Solve                          5.144       5.145       5.145
# Postprocessing                   0.308       0.312       0.309
# Disk IO                          2.969       2.972       2.971
# --------------------------------------------------------------
# Total                           15.448      15.448      15.448
#
# Error in plotting: 'Data array (E_real) not present in this dataset.'
#      m  Re{f} (GHz)  Im{f} (GHz)           Q  Error (Bkwd.)  Error (Abs.)  \
# 0  1.0     4.423454    -4.597743    0.693834   1.380610e-07      0.109316
# 1  2.0     4.878758     0.052177   46.754899   1.460089e-07      0.115609
# 2  3.0     4.970088    -7.227603    0.606809   5.447809e-07      0.431358
# 3  4.0     6.173305     0.005248  588.146738   9.751172e-08      0.077210
# 4  5.0     6.918562     0.072031   48.027786   1.070044e-07      0.084726
# 5  6.0     8.346343     0.143428   29.100304   1.422629e-07      0.112644
#
#     kappa (kHz)
# 0  6.375379e+06
# 1  1.043475e+05
# 2  8.190535e+06
# 3  1.049620e+04
# 4  1.440533e+05
# 5  2.868129e+05

# %%
from SQDMetal.PALACE.Frequency_Driven_Simulation import PALACE_Driven_Simulation

#Driven Simulation Options
user_defined_options = {
                 "mesh_refinement":  0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                 "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                 "solns_to_save": 1,                                #number of electromagnetic field visualizations to save
                 "solver_order": 1,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                 "solver_tol": 1e-3,                              #error residual tolerance foriterative solver
                 "solver_maxits": 10,                              #number of solver iterations
                 "mesh_max": 120e-3,                                #maxiumum element size for the mesh in mm
                 "mesh_min": 10e-3,                                 #minimum element size for the mesh in mm
                 "mesh_sampling": 130,                              #number of points to mesh along a geometry
                 "fillet_resolution":12,
                 "num_cpus": 10,                                      #number of CPU cores to use for simulation
                 "palace_dir":path_to_palace
                }

#Create the Palace Frequency Driven simulation
driven_sim = PALACE_Driven_Simulation(
    name='qubit-cavity-driven',                  #name of simulation
    metal_design=design,                              #feed in qiskit metal design
    sim_parent_directory="sims/",                     #choose directory where mesh file, config file and HPC batch file will be saved
    mode='simPC',                                     #choose simulation mode 'HPC' or 'simPC'
    meshing='GMSH',                                   #choose meshing 'GMSH' or 'COMSOL'
    user_options=user_defined_options,                #provide options chosen above
    view_design_gmsh_gui=False,                       #view design in GMSH gui
    create_files=True                                 #create mesh, config and HPC batch files
)
from SQDMetal.Utilities.Materials import MaterialInterface

# Add metallic elements and ground plane
driven_sim.add_metallic(1, threshold=1e-10, fuse_threshold=1e-10)
driven_sim.add_ground_plane(threshold=1e-10)


# Add in the RF ports
driven_sim.create_port_CPW_on_Launcher('LP1', 20e-6)
driven_sim.create_port_CPW_on_Launcher('LP2', 20e-6)


# Fine-mesh routed paths
driven_sim.fine_mesh_around_comp_boundaries(['feedline', 'resonator'], min_size=25e-6, max_size=250e-6)


# Setup EPR interfaces
driven_sim.setup_EPR_interfaces(
    metal_air=MaterialInterface('Aluminium-Vacuum'),
    substrate_air=MaterialInterface('Silicon-Vacuum'),
    substrate_metal=MaterialInterface('Silicon-Aluminium')
)

# Set frequency sweep parameters (in GHz)
driven_sim.set_freq_values(
    startGHz=4.5,    # starting frequency in GHz
    endGHz=7,     # end frequency in GHz
    stepGHz=0.01    # frequency step size in GHz
)



driven_sim.prepare_simulation()

from SQDMetal.PALACE.Utilities.GMSH_Navigator import GMSH_Navigator

# Let's look how the mesh looks in GMSH
# Open the GMSH GUI

gmsh_nav = GMSH_Navigator(driven_sim.path_mesh)
gmsh_nav.open_GUI()
results = driven_sim.run()
plt.plot(results['freqs'], results['S21'], label='S21')
# Out:
# >> /opt/homebrew/bin/mpirun -n 10 /Users/mcansarihan/qubit_design/palace/build/bin/palace-arm64.bin qubit-cavity-driven.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: v0.13.0-454-gcd4d7b78
# Running with 10 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 4487 elements in 2 iterations of local bisection for under-resolved interior boundaries
# Added 3047 duplicate vertices for interior boundaries in the mesh
# Added 8268 duplicate boundary elements for interior boundaries in the mesh
# Added 216 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 10 subdomains
#
# Characteristic length and time scales:
#  L₀ = 4.200e-03 m, t₀ = 1.401e-02 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-2.100e-03, -2.800e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+2.100e-03, +8.000e-04, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices           889        1011        1110       10119
#  edges             5035        5380        5659       53804
#  faces             7555        7828        8084       78281
#  elements          3372        3459        3547       34598
#  neighbors            5           6           8
#
#             minimum     maximum
#  h      6.04448e-05   0.0794483
#  kappa      1.11221     3799.27
#
# Configuring Robin absorbing BC (order 1) at attributes:
#  11
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  4: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,+1.0)
#  5: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,+1.0)
#  6: Rs = 6.667e+01 Ω/sq, n = (+0.0,+0.0,-1.0)
#  7: Rs = 6.667e+01 Ω/sq, n = (+0.0,-0.0,+1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: R = 5.000e+01 Ω
#  Index = 2: R = 5.000e+01 Ω
#
# Configuring lumped port excitation source term at attributes:
#  4: Index = 1
#  5: Index = 1
#
# Configuring Dirichlet PEC BC at attributes:
#  1-3
#
# Computing frequency response for:
# Excitation with index 1 has contributions from:
#  Lumped port  1
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 10119, ND (p = 1): 53804, RT (p = 1): 78281
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# It 1/251: ω/2π = 4.500e+00 GHz (total elapsed time = 2.12e-05 s)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 53804 unknowns
#  Level 0 (auxiliary) (p = 1): 10119 unknowns
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 7.248698e-01
#  1 (restart 0) KSP residual norm 6.101957e-01
#  2 (restart 0) KSP residual norm 3.489119e-01
#  3 (restart 0) KSP residual norm 2.270221e-02
#  4 (restart 0) KSP residual norm 1.107816e-02
#  5 (restart 0) KSP residual norm 1.023209e-02
#  6 (restart 0) KSP residual norm 3.039723e-03
#  7 (restart 0) KSP residual norm 2.288863e-03
#  8 (restart 0) KSP residual norm 1.351871e-03
#  9 (restart 0) KSP residual norm 2.584998e-04
# FGMRES solver converged in 9 iterations (avg. reduction factor: 4.139e-01)
#  Sol. ||E|| = 7.187379e+00 (||RHS|| = 7.248698e-01)
#  Field energy E (1.590e-02 J) + H (4.584e-03 J) = 2.049e-02 J
#  S[1][1] = -7.627e-01-3.200e-01i, |S[1][1]| = -1.649e+00, arg(S[1][1]) = -1.572e+02
#  S[2][1] = +2.202e-01-5.168e-01i, |S[2][1]| = -5.009e+00, arg(S[2][1]) = -6.692e+01
#
#  Wrote fields to disk at step 1
#  Updating solution error estimates
#
# It 2/251: ω/2π = 4.510e+00 GHz (total elapsed time = 2.77e+00 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.563468e-03
#  1 (restart 0) KSP residual norm 1.454840e-03
#  2 (restart 0) KSP residual norm 1.205455e-03
#  3 (restart 0) KSP residual norm 6.448993e-04
# FGMRES solver converged in 3 iterations (avg. reduction factor: 9.611e-02)
#  Sol. ||E|| = 7.176029e+00 (||RHS|| = 7.264806e-01)
#  Field energy E (1.585e-02 J) + H (4.582e-03 J) = 2.044e-02 J
#  S[1][1] = -7.631e-01-3.191e-01i, |S[1][1]| = -1.649e+00, arg(S[1][1]) = -1.573e+02
#  S[2][1] = +2.197e-01-5.163e-01i, |S[2][1]| = -5.020e+00, arg(S[2][1]) = -6.695e+01
#
#  Wrote fields to disk at step 2
#  Updating solution error estimates
#
# It 3/251: ω/2π = 4.520e+00 GHz (total elapsed time = 5.20e+00 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.875346e-03
#  1 (restart 0) KSP residual norm 1.802298e-03
#  2 (restart 0) KSP residual norm 1.671938e-03
#  3 (restart 0) KSP residual norm 1.432691e-03
#  4 (restart 0) KSP residual norm 7.200233e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.773e-01)
#  Sol. ||E|| = 7.162547e+00 (||RHS|| = 7.280914e-01)
#  Field energy E (1.579e-02 J) + H (4.586e-03 J) = 2.038e-02 J
#  S[1][1] = -7.640e-01-3.181e-01i, |S[1][1]| = -1.644e+00, arg(S[1][1]) = -1.574e+02
#  S[2][1] = +2.187e-01-5.158e-01i, |S[2][1]| = -5.032e+00, arg(S[2][1]) = -6.703e+01
#
#  Wrote fields to disk at step 3
#  Updating solution error estimates
#
# It 4/251: ω/2π = 4.530e+00 GHz (total elapsed time = 7.60e+00 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.870789e-03
#  1 (restart 0) KSP residual norm 1.787562e-03
#  2 (restart 0) KSP residual norm 1.685546e-03
#  3 (restart 0) KSP residual norm 1.544003e-03
#  4 (restart 0) KSP residual norm 1.051755e-03
#  5 (restart 0) KSP residual norm 7.929447e-04
#  6 (restart 0) KSP residual norm 1.535522e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.439e-01)
#  Sol. ||E|| = 7.149313e+00 (||RHS|| = 7.297022e-01)
#  Field energy E (1.573e-02 J) + H (4.594e-03 J) = 2.033e-02 J
#  S[1][1] = -7.653e-01-3.174e-01i, |S[1][1]| = -1.634e+00, arg(S[1][1]) = -1.575e+02
#  S[2][1] = +2.173e-01-5.156e-01i, |S[2][1]| = -5.043e+00, arg(S[2][1]) = -6.715e+01
#
#  Wrote fields to disk at step 4
#  Updating solution error estimates
#
# It 5/251: ω/2π = 4.540e+00 GHz (total elapsed time = 1.00e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.555251e-03
#  1 (restart 0) KSP residual norm 1.362408e-03
#  2 (restart 0) KSP residual norm 1.094898e-03
#  3 (restart 0) KSP residual norm 3.926220e-04
# FGMRES solver converged in 3 iterations (avg. reduction factor: 8.128e-02)
#  Sol. ||E|| = 7.139890e+00 (||RHS|| = 7.313131e-01)
#  Field energy E (1.569e-02 J) + H (4.595e-03 J) = 2.029e-02 J
#  S[1][1] = -7.658e-01-3.166e-01i, |S[1][1]| = -1.632e+00, arg(S[1][1]) = -1.575e+02
#  S[2][1] = +2.167e-01-5.153e-01i, |S[2][1]| = -5.052e+00, arg(S[2][1]) = -6.720e+01
#
#  Wrote fields to disk at step 5
#  Updating solution error estimates
#
# It 6/251: ω/2π = 4.550e+00 GHz (total elapsed time = 1.26e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.673728e-03
#  1 (restart 0) KSP residual norm 1.542671e-03
#  2 (restart 0) KSP residual norm 1.399078e-03
#  3 (restart 0) KSP residual norm 1.175267e-03
#  4 (restart 0) KSP residual norm 4.214948e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.549e-01)
#  Sol. ||E|| = 7.127860e+00 (||RHS|| = 7.329239e-01)
#  Field energy E (1.564e-02 J) + H (4.598e-03 J) = 2.024e-02 J
#  S[1][1] = -7.667e-01-3.157e-01i, |S[1][1]| = -1.628e+00, arg(S[1][1]) = -1.576e+02
#  S[2][1] = +2.157e-01-5.149e-01i, |S[2][1]| = -5.063e+00, arg(S[2][1]) = -6.727e+01
#
#  Wrote fields to disk at step 6
#  Updating solution error estimates
#
# It 7/251: ω/2π = 4.560e+00 GHz (total elapsed time = 1.48e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.668376e-03
#  1 (restart 0) KSP residual norm 1.511532e-03
#  2 (restart 0) KSP residual norm 1.396341e-03
#  3 (restart 0) KSP residual norm 1.106463e-03
#  4 (restart 0) KSP residual norm 6.516545e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.726e-01)
#  Sol. ||E|| = 7.114161e+00 (||RHS|| = 7.345347e-01)
#  Field energy E (1.558e-02 J) + H (4.600e-03 J) = 2.018e-02 J
#  S[1][1] = -7.674e-01-3.147e-01i, |S[1][1]| = -1.625e+00, arg(S[1][1]) = -1.577e+02
#  S[2][1] = +2.149e-01-5.144e-01i, |S[2][1]| = -5.076e+00, arg(S[2][1]) = -6.733e+01
#
#  Wrote fields to disk at step 7
#  Updating solution error estimates
#
# It 8/251: ω/2π = 4.570e+00 GHz (total elapsed time = 1.67e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.847872e-03
#  1 (restart 0) KSP residual norm 1.755671e-03
#  2 (restart 0) KSP residual norm 1.698628e-03
#  3 (restart 0) KSP residual norm 1.160584e-03
#  4 (restart 0) KSP residual norm 1.093940e-03
#  5 (restart 0) KSP residual norm 6.432318e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.445e-01)
#  Sol. ||E|| = 7.105406e+00 (||RHS|| = 7.361455e-01)
#  Field energy E (1.554e-02 J) + H (4.603e-03 J) = 2.014e-02 J
#  S[1][1] = -7.682e-01-3.141e-01i, |S[1][1]| = -1.619e+00, arg(S[1][1]) = -1.578e+02
#  S[2][1] = +2.140e-01-5.142e-01i, |S[2][1]| = -5.083e+00, arg(S[2][1]) = -6.741e+01
#
#  Wrote fields to disk at step 8
#  Updating solution error estimates
#
# It 9/251: ω/2π = 4.580e+00 GHz (total elapsed time = 1.96e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.821108e-03
#  1 (restart 0) KSP residual norm 1.627300e-03
#  2 (restart 0) KSP residual norm 1.523610e-03
#  3 (restart 0) KSP residual norm 1.452640e-03
#  4 (restart 0) KSP residual norm 7.412316e-04
#  5 (restart 0) KSP residual norm 5.920646e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.404e-01)
#  Sol. ||E|| = 7.093001e+00 (||RHS|| = 7.377563e-01)
#  Field energy E (1.549e-02 J) + H (4.607e-03 J) = 2.009e-02 J
#  S[1][1] = -7.691e-01-3.132e-01i, |S[1][1]| = -1.614e+00, arg(S[1][1]) = -1.578e+02
#  S[2][1] = +2.130e-01-5.139e-01i, |S[2][1]| = -5.094e+00, arg(S[2][1]) = -6.749e+01
#
#  Wrote fields to disk at step 9
#  Updating solution error estimates
#
# It 10/251: ω/2π = 4.590e+00 GHz (total elapsed time = 2.22e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.779855e-03
#  1 (restart 0) KSP residual norm 1.637384e-03
#  2 (restart 0) KSP residual norm 1.554757e-03
#  3 (restart 0) KSP residual norm 9.572322e-04
#  4 (restart 0) KSP residual norm 9.132745e-04
#  5 (restart 0) KSP residual norm 4.892172e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.313e-01)
#  Sol. ||E|| = 7.082425e+00 (||RHS|| = 7.393672e-01)
#  Field energy E (1.544e-02 J) + H (4.611e-03 J) = 2.005e-02 J
#  S[1][1] = -7.699e-01-3.125e-01i, |S[1][1]| = -1.609e+00, arg(S[1][1]) = -1.579e+02
#  S[2][1] = +2.121e-01-5.136e-01i, |S[2][1]| = -5.103e+00, arg(S[2][1]) = -6.756e+01
#
#  Wrote fields to disk at step 10
#  Updating solution error estimates
#
# It 11/251: ω/2π = 4.600e+00 GHz (total elapsed time = 2.47e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.711889e-03
#  1 (restart 0) KSP residual norm 1.524304e-03
#  2 (restart 0) KSP residual norm 1.411911e-03
#  3 (restart 0) KSP residual norm 1.341927e-03
#  4 (restart 0) KSP residual norm 5.697424e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.665e-01)
#  Sol. ||E|| = 7.072080e+00 (||RHS|| = 7.409780e-01)
#  Field energy E (1.540e-02 J) + H (4.613e-03 J) = 2.001e-02 J
#  S[1][1] = -7.705e-01-3.116e-01i, |S[1][1]| = -1.606e+00, arg(S[1][1]) = -1.580e+02
#  S[2][1] = +2.114e-01-5.133e-01i, |S[2][1]| = -5.113e+00, arg(S[2][1]) = -6.762e+01
#
#  Wrote fields to disk at step 11
#  Updating solution error estimates
#
# It 12/251: ω/2π = 4.610e+00 GHz (total elapsed time = 2.69e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.763704e-03
#  1 (restart 0) KSP residual norm 1.603078e-03
#  2 (restart 0) KSP residual norm 1.487318e-03
#  3 (restart 0) KSP residual norm 1.132955e-03
#  4 (restart 0) KSP residual norm 6.643839e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.729e-01)
#  Sol. ||E|| = 7.058338e+00 (||RHS|| = 7.425888e-01)
#  Field energy E (1.534e-02 J) + H (4.615e-03 J) = 1.995e-02 J
#  S[1][1] = -7.714e-01-3.107e-01i, |S[1][1]| = -1.602e+00, arg(S[1][1]) = -1.581e+02
#  S[2][1] = +2.104e-01-5.128e-01i, |S[2][1]| = -5.126e+00, arg(S[2][1]) = -6.769e+01
#
#  Wrote fields to disk at step 12
#  Updating solution error estimates
#
# It 13/251: ω/2π = 4.620e+00 GHz (total elapsed time = 2.89e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.847476e-03
#  1 (restart 0) KSP residual norm 1.719548e-03
#  2 (restart 0) KSP residual norm 1.649720e-03
#  3 (restart 0) KSP residual norm 1.329547e-03
#  4 (restart 0) KSP residual norm 1.005722e-03
#  5 (restart 0) KSP residual norm 6.454811e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.441e-01)
#  Sol. ||E|| = 7.049308e+00 (||RHS|| = 7.441996e-01)
#  Field energy E (1.530e-02 J) + H (4.619e-03 J) = 1.992e-02 J
#  S[1][1] = -7.722e-01-3.100e-01i, |S[1][1]| = -1.597e+00, arg(S[1][1]) = -1.581e+02
#  S[2][1] = +2.095e-01-5.126e-01i, |S[2][1]| = -5.133e+00, arg(S[2][1]) = -6.777e+01
#
#  Wrote fields to disk at step 13
#  Updating solution error estimates
#
# It 14/251: ω/2π = 4.630e+00 GHz (total elapsed time = 3.09e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.821373e-03
#  1 (restart 0) KSP residual norm 1.526786e-03
#  2 (restart 0) KSP residual norm 1.446389e-03
#  3 (restart 0) KSP residual norm 1.258875e-03
#  4 (restart 0) KSP residual norm 7.711413e-04
#  5 (restart 0) KSP residual norm 6.705536e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.459e-01)
#  Sol. ||E|| = 7.037307e+00 (||RHS|| = 7.458105e-01)
#  Field energy E (1.524e-02 J) + H (4.622e-03 J) = 1.987e-02 J
#  S[1][1] = -7.730e-01-3.091e-01i, |S[1][1]| = -1.592e+00, arg(S[1][1]) = -1.582e+02
#  S[2][1] = +2.086e-01-5.122e-01i, |S[2][1]| = -5.144e+00, arg(S[2][1]) = -6.784e+01
#
#  Wrote fields to disk at step 14
#  Updating solution error estimates
#
# It 15/251: ω/2π = 4.640e+00 GHz (total elapsed time = 3.28e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.843860e-03
#  1 (restart 0) KSP residual norm 1.685767e-03
#  2 (restart 0) KSP residual norm 1.595994e-03
#  3 (restart 0) KSP residual norm 1.212839e-03
#  4 (restart 0) KSP residual norm 9.596751e-04
#  5 (restart 0) KSP residual norm 6.446349e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.439e-01)
#  Sol. ||E|| = 7.026733e+00 (||RHS|| = 7.474213e-01)
#  Field energy E (1.520e-02 J) + H (4.625e-03 J) = 1.982e-02 J
#  S[1][1] = -7.737e-01-3.083e-01i, |S[1][1]| = -1.588e+00, arg(S[1][1]) = -1.583e+02
#  S[2][1] = +2.078e-01-5.119e-01i, |S[2][1]| = -5.153e+00, arg(S[2][1]) = -6.791e+01
#
#  Wrote fields to disk at step 15
#  Updating solution error estimates
#
# It 16/251: ω/2π = 4.650e+00 GHz (total elapsed time = 3.47e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.820935e-03
#  1 (restart 0) KSP residual norm 1.599281e-03
#  2 (restart 0) KSP residual norm 1.476683e-03
#  3 (restart 0) KSP residual norm 1.367578e-03
#  4 (restart 0) KSP residual norm 8.157690e-04
#  5 (restart 0) KSP residual norm 6.789174e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.463e-01)
#  Sol. ||E|| = 7.015090e+00 (||RHS|| = 7.490321e-01)
#  Field energy E (1.515e-02 J) + H (4.628e-03 J) = 1.978e-02 J
#  S[1][1] = -7.745e-01-3.075e-01i, |S[1][1]| = -1.584e+00, arg(S[1][1]) = -1.583e+02
#  S[2][1] = +2.069e-01-5.116e-01i, |S[2][1]| = -5.164e+00, arg(S[2][1]) = -6.798e+01
#
#  Wrote fields to disk at step 16
#  Updating solution error estimates
#
# It 17/251: ω/2π = 4.660e+00 GHz (total elapsed time = 3.64e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.852382e-03
#  1 (restart 0) KSP residual norm 1.691083e-03
#  2 (restart 0) KSP residual norm 1.582116e-03
#  3 (restart 0) KSP residual norm 1.045801e-03
#  4 (restart 0) KSP residual norm 9.323708e-04
#  5 (restart 0) KSP residual norm 6.018887e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.403e-01)
#  Sol. ||E|| = 7.004780e+00 (||RHS|| = 7.506429e-01)
#  Field energy E (1.510e-02 J) + H (4.632e-03 J) = 1.974e-02 J
#  S[1][1] = -7.753e-01-3.067e-01i, |S[1][1]| = -1.579e+00, arg(S[1][1]) = -1.584e+02
#  S[2][1] = +2.060e-01-5.113e-01i, |S[2][1]| = -5.173e+00, arg(S[2][1]) = -6.805e+01
#
#  Wrote fields to disk at step 17
#  Updating solution error estimates
#
# It 18/251: ω/2π = 4.670e+00 GHz (total elapsed time = 3.81e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.787154e-03
#  1 (restart 0) KSP residual norm 1.552771e-03
#  2 (restart 0) KSP residual norm 1.477895e-03
#  3 (restart 0) KSP residual norm 1.453284e-03
#  4 (restart 0) KSP residual norm 7.177857e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.758e-01)
#  Sol. ||E|| = 6.994759e+00 (||RHS|| = 7.522537e-01)
#  Field energy E (1.506e-02 J) + H (4.633e-03 J) = 1.969e-02 J
#  S[1][1] = -7.758e-01-3.059e-01i, |S[1][1]| = -1.577e+00, arg(S[1][1]) = -1.585e+02
#  S[2][1] = +2.054e-01-5.109e-01i, |S[2][1]| = -5.182e+00, arg(S[2][1]) = -6.810e+01
#
#  Wrote fields to disk at step 18
#  Updating solution error estimates
#
# It 19/251: ω/2π = 4.680e+00 GHz (total elapsed time = 3.99e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.879236e-03
#  1 (restart 0) KSP residual norm 1.696879e-03
#  2 (restart 0) KSP residual norm 1.600566e-03
#  3 (restart 0) KSP residual norm 1.321239e-03
#  4 (restart 0) KSP residual norm 9.508156e-04
#  5 (restart 0) KSP residual norm 9.058400e-04
#  6 (restart 0) KSP residual norm 1.584607e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.438e-01)
#  Sol. ||E|| = 6.982957e+00 (||RHS|| = 7.538646e-01)
#  Field energy E (1.501e-02 J) + H (4.641e-03 J) = 1.965e-02 J
#  S[1][1] = -7.771e-01-3.052e-01i, |S[1][1]| = -1.568e+00, arg(S[1][1]) = -1.586e+02
#  S[2][1] = +2.041e-01-5.108e-01i, |S[2][1]| = -5.192e+00, arg(S[2][1]) = -6.822e+01
#
#  Wrote fields to disk at step 19
#  Updating solution error estimates
#
# It 20/251: ω/2π = 4.690e+00 GHz (total elapsed time = 4.18e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.562389e-03
#  1 (restart 0) KSP residual norm 1.122584e-03
#  2 (restart 0) KSP residual norm 9.633023e-04
#  3 (restart 0) KSP residual norm 4.572545e-04
# FGMRES solver converged in 3 iterations (avg. reduction factor: 8.459e-02)
#  Sol. ||E|| = 6.974050e+00 (||RHS|| = 7.554754e-01)
#  Field energy E (1.497e-02 J) + H (4.641e-03 J) = 1.961e-02 J
#  S[1][1] = -7.775e-01-3.044e-01i, |S[1][1]| = -1.567e+00, arg(S[1][1]) = -1.586e+02
#  S[2][1] = +2.035e-01-5.104e-01i, |S[2][1]| = -5.200e+00, arg(S[2][1]) = -6.826e+01
#
#  Wrote fields to disk at step 20
#  Updating solution error estimates
#
# It 21/251: ω/2π = 4.700e+00 GHz (total elapsed time = 4.38e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.726191e-03
#  1 (restart 0) KSP residual norm 1.513957e-03
#  2 (restart 0) KSP residual norm 1.405926e-03
#  3 (restart 0) KSP residual norm 1.303625e-03
#  4 (restart 0) KSP residual norm 6.595931e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.718e-01)
#  Sol. ||E|| = 6.963705e+00 (||RHS|| = 7.570862e-01)
#  Field energy E (1.493e-02 J) + H (4.643e-03 J) = 1.957e-02 J
#  S[1][1] = -7.781e-01-3.036e-01i, |S[1][1]| = -1.564e+00, arg(S[1][1]) = -1.587e+02
#  S[2][1] = +2.028e-01-5.101e-01i, |S[2][1]| = -5.210e+00, arg(S[2][1]) = -6.832e+01
#
#  Wrote fields to disk at step 21
#  Updating solution error estimates
#
# It 22/251: ω/2π = 4.710e+00 GHz (total elapsed time = 4.56e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.851691e-03
#  1 (restart 0) KSP residual norm 1.670688e-03
#  2 (restart 0) KSP residual norm 1.574887e-03
#  3 (restart 0) KSP residual norm 1.489509e-03
#  4 (restart 0) KSP residual norm 7.384187e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.766e-01)
#  Sol. ||E|| = 6.952523e+00 (||RHS|| = 7.586970e-01)
#  Field energy E (1.488e-02 J) + H (4.645e-03 J) = 1.952e-02 J
#  S[1][1] = -7.788e-01-3.027e-01i, |S[1][1]| = -1.560e+00, arg(S[1][1]) = -1.588e+02
#  S[2][1] = +2.020e-01-5.097e-01i, |S[2][1]| = -5.221e+00, arg(S[2][1]) = -6.838e+01
#
#  Wrote fields to disk at step 22
#  Updating solution error estimates
#
# It 23/251: ω/2π = 4.720e+00 GHz (total elapsed time = 4.75e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.903709e-03
#  1 (restart 0) KSP residual norm 1.726377e-03
#  2 (restart 0) KSP residual norm 1.669595e-03
#  3 (restart 0) KSP residual norm 1.652520e-03
#  4 (restart 0) KSP residual norm 9.372381e-04
#  5 (restart 0) KSP residual norm 8.969402e-04
#  6 (restart 0) KSP residual norm 1.841943e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.497e-01)
#  Sol. ||E|| = 6.939906e+00 (||RHS|| = 7.603079e-01)
#  Field energy E (1.483e-02 J) + H (4.653e-03 J) = 1.948e-02 J
#  S[1][1] = -7.800e-01-3.019e-01i, |S[1][1]| = -1.552e+00, arg(S[1][1]) = -1.588e+02
#  S[2][1] = +2.007e-01-5.095e-01i, |S[2][1]| = -5.231e+00, arg(S[2][1]) = -6.850e+01
#
#  Wrote fields to disk at step 23
#  Updating solution error estimates
#
# It 24/251: ω/2π = 4.730e+00 GHz (total elapsed time = 4.94e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.568963e-03
#  1 (restart 0) KSP residual norm 1.164096e-03
#  2 (restart 0) KSP residual norm 9.844546e-04
#  3 (restart 0) KSP residual norm 5.039560e-04
# FGMRES solver converged in 3 iterations (avg. reduction factor: 8.713e-02)
#  Sol. ||E|| = 6.931058e+00 (||RHS|| = 7.619187e-01)
#  Field energy E (1.479e-02 J) + H (4.654e-03 J) = 1.944e-02 J
#  S[1][1] = -7.805e-01-3.011e-01i, |S[1][1]| = -1.550e+00, arg(S[1][1]) = -1.589e+02
#  S[2][1] = +2.002e-01-5.091e-01i, |S[2][1]| = -5.239e+00, arg(S[2][1]) = -6.854e+01
#
#  Wrote fields to disk at step 24
#  Updating solution error estimates
#
# It 25/251: ω/2π = 4.740e+00 GHz (total elapsed time = 5.10e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.761171e-03
#  1 (restart 0) KSP residual norm 1.514710e-03
#  2 (restart 0) KSP residual norm 1.441169e-03
#  3 (restart 0) KSP residual norm 1.394990e-03
#  4 (restart 0) KSP residual norm 6.586166e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.714e-01)
#  Sol. ||E|| = 6.920364e+00 (||RHS|| = 7.635295e-01)
#  Field energy E (1.474e-02 J) + H (4.655e-03 J) = 1.940e-02 J
#  S[1][1] = -7.811e-01-3.003e-01i, |S[1][1]| = -1.547e+00, arg(S[1][1]) = -1.590e+02
#  S[2][1] = +1.994e-01-5.088e-01i, |S[2][1]| = -5.249e+00, arg(S[2][1]) = -6.860e+01
#
#  Wrote fields to disk at step 25
#  Updating solution error estimates
#
# It 26/251: ω/2π = 4.750e+00 GHz (total elapsed time = 5.29e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.845385e-03
#  1 (restart 0) KSP residual norm 1.610559e-03
#  2 (restart 0) KSP residual norm 1.519564e-03
#  3 (restart 0) KSP residual norm 1.464603e-03
#  4 (restart 0) KSP residual norm 7.235563e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.754e-01)
#  Sol. ||E|| = 6.909391e+00 (||RHS|| = 7.651403e-01)
#  Field energy E (1.470e-02 J) + H (4.658e-03 J) = 1.935e-02 J
#  S[1][1] = -7.818e-01-2.994e-01i, |S[1][1]| = -1.544e+00, arg(S[1][1]) = -1.590e+02
#  S[2][1] = +1.986e-01-5.084e-01i, |S[2][1]| = -5.259e+00, arg(S[2][1]) = -6.866e+01
#
#  Wrote fields to disk at step 26
#  Updating solution error estimates
#
# It 27/251: ω/2π = 4.760e+00 GHz (total elapsed time = 5.50e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.889613e-03
#  1 (restart 0) KSP residual norm 1.698829e-03
#  2 (restart 0) KSP residual norm 1.638777e-03
#  3 (restart 0) KSP residual norm 1.630338e-03
#  4 (restart 0) KSP residual norm 9.347394e-04
#  5 (restart 0) KSP residual norm 6.836920e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.455e-01)
#  Sol. ||E|| = 6.895729e+00 (||RHS|| = 7.667511e-01)
#  Field energy E (1.464e-02 J) + H (4.663e-03 J) = 1.930e-02 J
#  S[1][1] = -7.828e-01-2.985e-01i, |S[1][1]| = -1.537e+00, arg(S[1][1]) = -1.591e+02
#  S[2][1] = +1.975e-01-5.080e-01i, |S[2][1]| = -5.271e+00, arg(S[2][1]) = -6.876e+01
#
#  Wrote fields to disk at step 27
#  Updating solution error estimates
#
# It 28/251: ω/2π = 4.770e+00 GHz (total elapsed time = 5.73e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.857049e-03
#  1 (restart 0) KSP residual norm 1.633407e-03
#  2 (restart 0) KSP residual norm 1.428733e-03
#  3 (restart 0) KSP residual norm 1.000595e-03
#  4 (restart 0) KSP residual norm 7.622703e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.775e-01)
#  Sol. ||E|| = 6.876491e+00 (||RHS|| = 7.683620e-01)
#  Field energy E (1.456e-02 J) + H (4.668e-03 J) = 1.922e-02 J
#  S[1][1] = -7.838e-01-2.971e-01i, |S[1][1]| = -1.533e+00, arg(S[1][1]) = -1.592e+02
#  S[2][1] = +1.963e-01-5.072e-01i, |S[2][1]| = -5.290e+00, arg(S[2][1]) = -6.884e+01
#
#  Wrote fields to disk at step 28
#  Updating solution error estimates
#
# It 29/251: ω/2π = 4.780e+00 GHz (total elapsed time = 6.02e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.911898e-03
#  1 (restart 0) KSP residual norm 1.471530e-03
#  2 (restart 0) KSP residual norm 1.336394e-03
#  3 (restart 0) KSP residual norm 1.186771e-03
#  4 (restart 0) KSP residual norm 7.034960e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.739e-01)
#  Sol. ||E|| = 6.877754e+00 (||RHS|| = 7.699728e-01)
#  Field energy E (1.456e-02 J) + H (4.672e-03 J) = 1.923e-02 J
#  S[1][1] = -7.848e-01-2.973e-01i, |S[1][1]| = -1.522e+00, arg(S[1][1]) = -1.593e+02
#  S[2][1] = +1.954e-01-5.078e-01i, |S[2][1]| = -5.286e+00, arg(S[2][1]) = -6.895e+01
#
#  Wrote fields to disk at step 29
#  Updating solution error estimates
#
# It 30/251: ω/2π = 4.790e+00 GHz (total elapsed time = 6.24e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.869229e-03
#  1 (restart 0) KSP residual norm 1.241048e-03
#  2 (restart 0) KSP residual norm 1.226219e-03
#  3 (restart 0) KSP residual norm 1.152208e-03
#  4 (restart 0) KSP residual norm 7.112289e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.742e-01)
#  Sol. ||E|| = 6.867061e+00 (||RHS|| = 7.715836e-01)
#  Field energy E (1.452e-02 J) + H (4.669e-03 J) = 1.918e-02 J
#  S[1][1] = -7.845e-01-2.961e-01i, |S[1][1]| = -1.530e+00, arg(S[1][1]) = -1.593e+02
#  S[2][1] = +1.955e-01-5.070e-01i, |S[2][1]| = -5.298e+00, arg(S[2][1]) = -6.892e+01
#
#  Wrote fields to disk at step 30
#  Updating solution error estimates
#
# It 31/251: ω/2π = 4.800e+00 GHz (total elapsed time = 6.47e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.927802e-03
#  1 (restart 0) KSP residual norm 1.807945e-03
#  2 (restart 0) KSP residual norm 1.571392e-03
#  3 (restart 0) KSP residual norm 1.370096e-03
#  4 (restart 0) KSP residual norm 5.372894e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.624e-01)
#  Sol. ||E|| = 6.855540e+00 (||RHS|| = 7.731944e-01)
#  Field energy E (1.447e-02 J) + H (4.676e-03 J) = 1.914e-02 J
#  S[1][1] = -7.856e-01-2.953e-01i, |S[1][1]| = -1.521e+00, arg(S[1][1]) = -1.594e+02
#  S[2][1] = +1.943e-01-5.068e-01i, |S[2][1]| = -5.307e+00, arg(S[2][1]) = -6.903e+01
#
#  Wrote fields to disk at step 31
#  Updating solution error estimates
#
# It 32/251: ω/2π = 4.810e+00 GHz (total elapsed time = 6.66e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.732403e-03
#  1 (restart 0) KSP residual norm 1.502204e-03
#  2 (restart 0) KSP residual norm 1.469864e-03
#  3 (restart 0) KSP residual norm 1.464929e-03
#  4 (restart 0) KSP residual norm 6.380517e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.694e-01)
#  Sol. ||E|| = 6.844037e+00 (||RHS|| = 7.748052e-01)
#  Field energy E (1.442e-02 J) + H (4.678e-03 J) = 1.910e-02 J
#  S[1][1] = -7.863e-01-2.944e-01i, |S[1][1]| = -1.519e+00, arg(S[1][1]) = -1.595e+02
#  S[2][1] = +1.935e-01-5.064e-01i, |S[2][1]| = -5.318e+00, arg(S[2][1]) = -6.909e+01
#
#  Wrote fields to disk at step 32
#  Updating solution error estimates
#
# It 33/251: ω/2π = 4.820e+00 GHz (total elapsed time = 6.86e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.830897e-03
#  1 (restart 0) KSP residual norm 1.634596e-03
#  2 (restart 0) KSP residual norm 1.458627e-03
#  3 (restart 0) KSP residual norm 1.320003e-03
#  4 (restart 0) KSP residual norm 8.426069e-04
#  5 (restart 0) KSP residual norm 8.262926e-04
#  6 (restart 0) KSP residual norm 2.718623e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.655e-01)
#  Sol. ||E|| = 6.834469e+00 (||RHS|| = 7.764161e-01)
#  Field energy E (1.438e-02 J) + H (4.684e-03 J) = 1.906e-02 J
#  S[1][1] = -7.872e-01-2.938e-01i, |S[1][1]| = -1.512e+00, arg(S[1][1]) = -1.595e+02
#  S[2][1] = +1.925e-01-5.063e-01i, |S[2][1]| = -5.326e+00, arg(S[2][1]) = -6.918e+01
#
#  Wrote fields to disk at step 33
#  Updating solution error estimates
#
# It 34/251: ω/2π = 4.830e+00 GHz (total elapsed time = 7.09e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.598251e-03
#  1 (restart 0) KSP residual norm 1.191632e-03
#  2 (restart 0) KSP residual norm 1.096579e-03
#  3 (restart 0) KSP residual norm 1.089610e-03
#  4 (restart 0) KSP residual norm 2.855721e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.384e-01)
#  Sol. ||E|| = 6.824822e+00 (||RHS|| = 7.780269e-01)
#  Field energy E (1.434e-02 J) + H (4.687e-03 J) = 1.902e-02 J
#  S[1][1] = -7.878e-01-2.930e-01i, |S[1][1]| = -1.509e+00, arg(S[1][1]) = -1.596e+02
#  S[2][1] = +1.918e-01-5.060e-01i, |S[2][1]| = -5.334e+00, arg(S[2][1]) = -6.924e+01
#
#  Wrote fields to disk at step 34
#  Updating solution error estimates
#
# It 35/251: ω/2π = 4.840e+00 GHz (total elapsed time = 7.28e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.615544e-03
#  1 (restart 0) KSP residual norm 1.283235e-03
#  2 (restart 0) KSP residual norm 1.108846e-03
#  3 (restart 0) KSP residual norm 1.029179e-03
#  4 (restart 0) KSP residual norm 4.128242e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.517e-01)
#  Sol. ||E|| = 6.814432e+00 (||RHS|| = 7.796377e-01)
#  Field energy E (1.429e-02 J) + H (4.689e-03 J) = 1.898e-02 J
#  S[1][1] = -7.885e-01-2.921e-01i, |S[1][1]| = -1.506e+00, arg(S[1][1]) = -1.597e+02
#  S[2][1] = +1.911e-01-5.056e-01i, |S[2][1]| = -5.344e+00, arg(S[2][1]) = -6.930e+01
#
#  Wrote fields to disk at step 35
#  Updating solution error estimates
#
# It 36/251: ω/2π = 4.850e+00 GHz (total elapsed time = 7.49e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.679549e-03
#  1 (restart 0) KSP residual norm 1.381951e-03
#  2 (restart 0) KSP residual norm 1.167133e-03
#  3 (restart 0) KSP residual norm 9.867511e-04
#  4 (restart 0) KSP residual norm 5.102525e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.599e-01)
#  Sol. ||E|| = 6.802948e+00 (||RHS|| = 7.812485e-01)
#  Field energy E (1.425e-02 J) + H (4.692e-03 J) = 1.894e-02 J
#  S[1][1] = -7.892e-01-2.912e-01i, |S[1][1]| = -1.502e+00, arg(S[1][1]) = -1.597e+02
#  S[2][1] = +1.902e-01-5.052e-01i, |S[2][1]| = -5.355e+00, arg(S[2][1]) = -6.937e+01
#
#  Wrote fields to disk at step 36
#  Updating solution error estimates
#
# It 37/251: ω/2π = 4.860e+00 GHz (total elapsed time = 7.68e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.735337e-03
#  1 (restart 0) KSP residual norm 1.499610e-03
#  2 (restart 0) KSP residual norm 1.378312e-03
#  3 (restart 0) KSP residual norm 1.364762e-03
#  4 (restart 0) KSP residual norm 7.009244e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.730e-01)
#  Sol. ||E|| = 6.791227e+00 (||RHS|| = 7.828594e-01)
#  Field energy E (1.420e-02 J) + H (4.694e-03 J) = 1.889e-02 J
#  S[1][1] = -7.898e-01-2.903e-01i, |S[1][1]| = -1.500e+00, arg(S[1][1]) = -1.598e+02
#  S[2][1] = +1.895e-01-5.048e-01i, |S[2][1]| = -5.366e+00, arg(S[2][1]) = -6.942e+01
#
#  Wrote fields to disk at step 37
#  Updating solution error estimates
#
# It 38/251: ω/2π = 4.870e+00 GHz (total elapsed time = 7.87e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.878249e-03
#  1 (restart 0) KSP residual norm 1.679951e-03
#  2 (restart 0) KSP residual norm 1.494621e-03
#  3 (restart 0) KSP residual norm 1.390671e-03
#  4 (restart 0) KSP residual norm 8.534780e-04
#  5 (restart 0) KSP residual norm 8.314142e-04
#  6 (restart 0) KSP residual norm 2.931719e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.684e-01)
#  Sol. ||E|| = 6.782827e+00 (||RHS|| = 7.844702e-01)
#  Field energy E (1.416e-02 J) + H (4.700e-03 J) = 1.886e-02 J
#  S[1][1] = -7.907e-01-2.897e-01i, |S[1][1]| = -1.492e+00, arg(S[1][1]) = -1.599e+02
#  S[2][1] = +1.885e-01-5.047e-01i, |S[2][1]| = -5.372e+00, arg(S[2][1]) = -6.952e+01
#
#  Wrote fields to disk at step 38
#  Updating solution error estimates
#
# It 39/251: ω/2π = 4.880e+00 GHz (total elapsed time = 8.05e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.606768e-03
#  1 (restart 0) KSP residual norm 1.197929e-03
#  2 (restart 0) KSP residual norm 1.133446e-03
#  3 (restart 0) KSP residual norm 1.129644e-03
#  4 (restart 0) KSP residual norm 4.133391e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.514e-01)
#  Sol. ||E|| = 6.773666e+00 (||RHS|| = 7.860810e-01)
#  Field energy E (1.412e-02 J) + H (4.702e-03 J) = 1.883e-02 J
#  S[1][1] = -7.912e-01-2.889e-01i, |S[1][1]| = -1.490e+00, arg(S[1][1]) = -1.599e+02
#  S[2][1] = +1.879e-01-5.044e-01i, |S[2][1]| = -5.381e+00, arg(S[2][1]) = -6.957e+01
#
#  Wrote fields to disk at step 39
#  Updating solution error estimates
#
# It 40/251: ω/2π = 4.890e+00 GHz (total elapsed time = 8.25e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.686295e-03
#  1 (restart 0) KSP residual norm 1.372156e-03
#  2 (restart 0) KSP residual norm 1.222835e-03
#  3 (restart 0) KSP residual norm 1.203610e-03
#  4 (restart 0) KSP residual norm 5.178271e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.601e-01)
#  Sol. ||E|| = 6.763237e+00 (||RHS|| = 7.876918e-01)
#  Field energy E (1.408e-02 J) + H (4.705e-03 J) = 1.879e-02 J
#  S[1][1] = -7.919e-01-2.881e-01i, |S[1][1]| = -1.487e+00, arg(S[1][1]) = -1.600e+02
#  S[2][1] = +1.871e-01-5.040e-01i, |S[2][1]| = -5.390e+00, arg(S[2][1]) = -6.963e+01
#
#  Wrote fields to disk at step 40
#  Updating solution error estimates
#
# It 41/251: ω/2π = 4.900e+00 GHz (total elapsed time = 8.45e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.748891e-03
#  1 (restart 0) KSP residual norm 1.480270e-03
#  2 (restart 0) KSP residual norm 1.393694e-03
#  3 (restart 0) KSP residual norm 1.393461e-03
#  4 (restart 0) KSP residual norm 7.589482e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.761e-01)
#  Sol. ||E|| = 6.754204e+00 (||RHS|| = 7.893026e-01)
#  Field energy E (1.404e-02 J) + H (4.705e-03 J) = 1.875e-02 J
#  S[1][1] = -7.923e-01-2.873e-01i, |S[1][1]| = -1.486e+00, arg(S[1][1]) = -1.601e+02
#  S[2][1] = +1.865e-01-5.037e-01i, |S[2][1]| = -5.399e+00, arg(S[2][1]) = -6.968e+01
#
#  Wrote fields to disk at step 41
#  Updating solution error estimates
#
# It 42/251: ω/2π = 4.910e+00 GHz (total elapsed time = 8.64e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.945487e-03
#  1 (restart 0) KSP residual norm 1.725406e-03
#  2 (restart 0) KSP residual norm 1.626502e-03
#  3 (restart 0) KSP residual norm 1.619800e-03
#  4 (restart 0) KSP residual norm 1.015702e-03
#  5 (restart 0) KSP residual norm 4.303244e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.224e-01)
#  Sol. ||E|| = 6.740516e+00 (||RHS|| = 7.909135e-01)
#  Field energy E (1.399e-02 J) + H (4.713e-03 J) = 1.870e-02 J
#  S[1][1] = -7.935e-01-2.863e-01i, |S[1][1]| = -1.478e+00, arg(S[1][1]) = -1.602e+02
#  S[2][1] = +1.853e-01-5.033e-01i, |S[2][1]| = -5.411e+00, arg(S[2][1]) = -6.979e+01
#
#  Wrote fields to disk at step 42
#  Updating solution error estimates
#
# It 43/251: ω/2π = 4.920e+00 GHz (total elapsed time = 8.83e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.672151e-03
#  1 (restart 0) KSP residual norm 1.320789e-03
#  2 (restart 0) KSP residual norm 9.999132e-04
#  3 (restart 0) KSP residual norm 8.826045e-04
#  4 (restart 0) KSP residual norm 4.762518e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.566e-01)
#  Sol. ||E|| = 6.727786e+00 (||RHS|| = 7.925243e-01)
#  Field energy E (1.393e-02 J) + H (4.716e-03 J) = 1.865e-02 J
#  S[1][1] = -7.941e-01-2.853e-01i, |S[1][1]| = -1.475e+00, arg(S[1][1]) = -1.602e+02
#  S[2][1] = +1.845e-01-5.028e-01i, |S[2][1]| = -5.423e+00, arg(S[2][1]) = -6.985e+01
#
#  Wrote fields to disk at step 43
#  Updating solution error estimates
#
# It 44/251: ω/2π = 4.930e+00 GHz (total elapsed time = 9.01e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.707743e-03
#  1 (restart 0) KSP residual norm 1.357733e-03
#  2 (restart 0) KSP residual norm 1.068945e-03
#  3 (restart 0) KSP residual norm 9.990461e-04
#  4 (restart 0) KSP residual norm 5.730442e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.639e-01)
#  Sol. ||E|| = 6.720199e+00 (||RHS|| = 7.941351e-01)
#  Field energy E (1.390e-02 J) + H (4.719e-03 J) = 1.862e-02 J
#  S[1][1] = -7.948e-01-2.847e-01i, |S[1][1]| = -1.471e+00, arg(S[1][1]) = -1.603e+02
#  S[2][1] = +1.838e-01-5.027e-01i, |S[2][1]| = -5.429e+00, arg(S[2][1]) = -6.992e+01
#
#  Wrote fields to disk at step 44
#  Updating solution error estimates
#
# It 45/251: ω/2π = 4.940e+00 GHz (total elapsed time = 9.20e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.767953e-03
#  1 (restart 0) KSP residual norm 1.378839e-03
#  2 (restart 0) KSP residual norm 1.317220e-03
#  3 (restart 0) KSP residual norm 1.284007e-03
#  4 (restart 0) KSP residual norm 7.389405e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.746e-01)
#  Sol. ||E|| = 6.710360e+00 (||RHS|| = 7.957459e-01)
#  Field energy E (1.386e-02 J) + H (4.720e-03 J) = 1.858e-02 J
#  S[1][1] = -7.952e-01-2.838e-01i, |S[1][1]| = -1.470e+00, arg(S[1][1]) = -1.604e+02
#  S[2][1] = +1.832e-01-5.023e-01i, |S[2][1]| = -5.439e+00, arg(S[2][1]) = -6.996e+01
#
#  Wrote fields to disk at step 45
#  Updating solution error estimates
#
# It 46/251: ω/2π = 4.950e+00 GHz (total elapsed time = 9.44e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.911317e-03
#  1 (restart 0) KSP residual norm 1.616477e-03
#  2 (restart 0) KSP residual norm 1.478225e-03
#  3 (restart 0) KSP residual norm 1.473140e-03
#  4 (restart 0) KSP residual norm 9.713268e-04
#  5 (restart 0) KSP residual norm 6.284044e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.395e-01)
#  Sol. ||E|| = 6.697905e+00 (||RHS|| = 7.973568e-01)
#  Field energy E (1.381e-02 J) + H (4.726e-03 J) = 1.853e-02 J
#  S[1][1] = -7.963e-01-2.830e-01i, |S[1][1]| = -1.463e+00, arg(S[1][1]) = -1.604e+02
#  S[2][1] = +1.821e-01-5.020e-01i, |S[2][1]| = -5.450e+00, arg(S[2][1]) = -7.006e+01
#
#  Wrote fields to disk at step 46
#  Updating solution error estimates
#
# It 47/251: ω/2π = 4.960e+00 GHz (total elapsed time = 9.66e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.791463e-03
#  1 (restart 0) KSP residual norm 1.358858e-03
#  2 (restart 0) KSP residual norm 9.427858e-04
#  3 (restart 0) KSP residual norm 9.109530e-04
#  4 (restart 0) KSP residual norm 5.398145e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.612e-01)
#  Sol. ||E|| = 6.688953e+00 (||RHS|| = 7.989676e-01)
#  Field energy E (1.377e-02 J) + H (4.729e-03 J) = 1.850e-02 J
#  S[1][1] = -7.968e-01-2.822e-01i, |S[1][1]| = -1.460e+00, arg(S[1][1]) = -1.605e+02
#  S[2][1] = +1.814e-01-5.017e-01i, |S[2][1]| = -5.458e+00, arg(S[2][1]) = -7.012e+01
#
#  Wrote fields to disk at step 47
#  Updating solution error estimates
#
# It 48/251: ω/2π = 4.970e+00 GHz (total elapsed time = 9.85e+01 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.735649e-03
#  1 (restart 0) KSP residual norm 1.286523e-03
#  2 (restart 0) KSP residual norm 1.228045e-03
#  3 (restart 0) KSP residual norm 1.192441e-03
#  4 (restart 0) KSP residual norm 6.994131e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.719e-01)
#  Sol. ||E|| = 6.682128e+00 (||RHS|| = 8.005784e-01)
#  Field energy E (1.374e-02 J) + H (4.729e-03 J) = 1.847e-02 J
#  S[1][1] = -7.972e-01-2.815e-01i, |S[1][1]| = -1.459e+00, arg(S[1][1]) = -1.605e+02
#  S[2][1] = +1.809e-01-5.015e-01i, |S[2][1]| = -5.464e+00, arg(S[2][1]) = -7.016e+01
#
#  Wrote fields to disk at step 48
#  Updating solution error estimates
#
# It 49/251: ω/2π = 4.980e+00 GHz (total elapsed time = 1.00e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.888261e-03
#  1 (restart 0) KSP residual norm 1.575231e-03
#  2 (restart 0) KSP residual norm 1.481162e-03
#  3 (restart 0) KSP residual norm 1.478492e-03
#  4 (restart 0) KSP residual norm 9.608835e-04
#  5 (restart 0) KSP residual norm 3.552244e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.134e-01)
#  Sol. ||E|| = 6.670574e+00 (||RHS|| = 8.021892e-01)
#  Field energy E (1.370e-02 J) + H (4.736e-03 J) = 1.843e-02 J
#  S[1][1] = -7.981e-01-2.807e-01i, |S[1][1]| = -1.452e+00, arg(S[1][1]) = -1.606e+02
#  S[2][1] = +1.799e-01-5.012e-01i, |S[2][1]| = -5.474e+00, arg(S[2][1]) = -7.026e+01
#
#  Wrote fields to disk at step 49
#  Updating solution error estimates
#
# It 50/251: ω/2π = 4.990e+00 GHz (total elapsed time = 1.02e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.633233e-03
#  1 (restart 0) KSP residual norm 1.182458e-03
#  2 (restart 0) KSP residual norm 8.261221e-04
#  3 (restart 0) KSP residual norm 7.403924e-04
# FGMRES solver converged in 3 iterations (avg. reduction factor: 9.730e-02)
#  Sol. ||E|| = 6.661606e+00 (||RHS|| = 8.038000e-01)
#  Field energy E (1.366e-02 J) + H (4.735e-03 J) = 1.840e-02 J
#  S[1][1] = -7.985e-01-2.799e-01i, |S[1][1]| = -1.451e+00, arg(S[1][1]) = -1.607e+02
#  S[2][1] = +1.794e-01-5.008e-01i, |S[2][1]| = -5.482e+00, arg(S[2][1]) = -7.029e+01
#
#  Wrote fields to disk at step 50
#  Updating solution error estimates
#
# It 51/251: ω/2π = 5.000e+00 GHz (total elapsed time = 1.04e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.980237e-03
#  1 (restart 0) KSP residual norm 1.745966e-03
#  2 (restart 0) KSP residual norm 1.622119e-03
#  3 (restart 0) KSP residual norm 1.609990e-03
#  4 (restart 0) KSP residual norm 1.091235e-03
#  5 (restart 0) KSP residual norm 3.247606e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.095e-01)
#  Sol. ||E|| = 6.650880e+00 (||RHS|| = 8.054109e-01)
#  Field energy E (1.362e-02 J) + H (4.742e-03 J) = 1.836e-02 J
#  S[1][1] = -7.994e-01-2.790e-01i, |S[1][1]| = -1.445e+00, arg(S[1][1]) = -1.608e+02
#  S[2][1] = +1.784e-01-5.006e-01i, |S[2][1]| = -5.492e+00, arg(S[2][1]) = -7.038e+01
#
#  Wrote fields to disk at step 51
#  Updating solution error estimates
#
# It 52/251: ω/2π = 5.010e+00 GHz (total elapsed time = 1.06e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.620404e-03
#  1 (restart 0) KSP residual norm 1.176814e-03
#  2 (restart 0) KSP residual norm 9.345656e-04
#  3 (restart 0) KSP residual norm 9.278467e-04
#  4 (restart 0) KSP residual norm 3.972734e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.490e-01)
#  Sol. ||E|| = 6.641232e+00 (||RHS|| = 8.070217e-01)
#  Field energy E (1.358e-02 J) + H (4.745e-03 J) = 1.832e-02 J
#  S[1][1] = -7.999e-01-2.782e-01i, |S[1][1]| = -1.443e+00, arg(S[1][1]) = -1.608e+02
#  S[2][1] = +1.778e-01-5.002e-01i, |S[2][1]| = -5.500e+00, arg(S[2][1]) = -7.044e+01
#
#  Wrote fields to disk at step 52
#  Updating solution error estimates
#
# It 53/251: ω/2π = 5.020e+00 GHz (total elapsed time = 1.08e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.670904e-03
#  1 (restart 0) KSP residual norm 1.297632e-03
#  2 (restart 0) KSP residual norm 9.838490e-04
#  3 (restart 0) KSP residual norm 9.514274e-04
#  4 (restart 0) KSP residual norm 5.346120e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.604e-01)
#  Sol. ||E|| = 6.632073e+00 (||RHS|| = 8.086325e-01)
#  Field energy E (1.354e-02 J) + H (4.747e-03 J) = 1.829e-02 J
#  S[1][1] = -8.005e-01-2.774e-01i, |S[1][1]| = -1.440e+00, arg(S[1][1]) = -1.609e+02
#  S[2][1] = +1.771e-01-4.999e-01i, |S[2][1]| = -5.509e+00, arg(S[2][1]) = -7.050e+01
#
#  Wrote fields to disk at step 53
#  Updating solution error estimates
#
# It 54/251: ω/2π = 5.030e+00 GHz (total elapsed time = 1.10e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.760060e-03
#  1 (restart 0) KSP residual norm 1.443782e-03
#  2 (restart 0) KSP residual norm 1.352538e-03
#  3 (restart 0) KSP residual norm 1.317145e-03
#  4 (restart 0) KSP residual norm 7.601244e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.750e-01)
#  Sol. ||E|| = 6.622874e+00 (||RHS|| = 8.102433e-01)
#  Field energy E (1.350e-02 J) + H (4.748e-03 J) = 1.825e-02 J
#  S[1][1] = -8.010e-01-2.766e-01i, |S[1][1]| = -1.439e+00, arg(S[1][1]) = -1.609e+02
#  S[2][1] = +1.765e-01-4.996e-01i, |S[2][1]| = -5.517e+00, arg(S[2][1]) = -7.054e+01
#
#  Wrote fields to disk at step 54
#  Updating solution error estimates
#
# It 55/251: ω/2π = 5.040e+00 GHz (total elapsed time = 1.12e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.942033e-03
#  1 (restart 0) KSP residual norm 1.642893e-03
#  2 (restart 0) KSP residual norm 1.406567e-03
#  3 (restart 0) KSP residual norm 1.372082e-03
#  4 (restart 0) KSP residual norm 7.892680e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.766e-01)
#  Sol. ||E|| = 6.612677e+00 (||RHS|| = 8.118541e-01)
#  Field energy E (1.346e-02 J) + H (4.751e-03 J) = 1.821e-02 J
#  S[1][1] = -8.016e-01-2.758e-01i, |S[1][1]| = -1.435e+00, arg(S[1][1]) = -1.610e+02
#  S[2][1] = +1.757e-01-4.992e-01i, |S[2][1]| = -5.527e+00, arg(S[2][1]) = -7.061e+01
#
#  Wrote fields to disk at step 55
#  Updating solution error estimates
#
# It 56/251: ω/2π = 5.050e+00 GHz (total elapsed time = 1.15e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.942384e-03
#  1 (restart 0) KSP residual norm 1.741526e-03
#  2 (restart 0) KSP residual norm 1.732603e-03
#  3 (restart 0) KSP residual norm 1.620623e-03
#  4 (restart 0) KSP residual norm 9.785998e-04
#  5 (restart 0) KSP residual norm 6.391519e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.394e-01)
#  Sol. ||E|| = 6.599727e+00 (||RHS|| = 8.134650e-01)
#  Field energy E (1.341e-02 J) + H (4.758e-03 J) = 1.816e-02 J
#  S[1][1] = -8.026e-01-2.748e-01i, |S[1][1]| = -1.429e+00, arg(S[1][1]) = -1.611e+02
#  S[2][1] = +1.746e-01-4.989e-01i, |S[2][1]| = -5.538e+00, arg(S[2][1]) = -7.071e+01
#
#  Wrote fields to disk at step 56
#  Updating solution error estimates
#
# It 57/251: ω/2π = 5.060e+00 GHz (total elapsed time = 1.17e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.799570e-03
#  1 (restart 0) KSP residual norm 1.448555e-03
#  2 (restart 0) KSP residual norm 1.286532e-03
#  3 (restart 0) KSP residual norm 1.202570e-03
#  4 (restart 0) KSP residual norm 6.781099e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.698e-01)
#  Sol. ||E|| = 6.591181e+00 (||RHS|| = 8.150758e-01)
#  Field energy E (1.337e-02 J) + H (4.760e-03 J) = 1.813e-02 J
#  S[1][1] = -8.032e-01-2.741e-01i, |S[1][1]| = -1.425e+00, arg(S[1][1]) = -1.612e+02
#  S[2][1] = +1.739e-01-4.986e-01i, |S[2][1]| = -5.546e+00, arg(S[2][1]) = -7.077e+01
#
#  Wrote fields to disk at step 57
#  Updating solution error estimates
#
# It 58/251: ω/2π = 5.070e+00 GHz (total elapsed time = 1.19e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.849543e-03
#  1 (restart 0) KSP residual norm 1.394271e-03
#  2 (restart 0) KSP residual norm 1.366421e-03
#  3 (restart 0) KSP residual norm 1.270565e-03
#  4 (restart 0) KSP residual norm 8.755232e-04
#  5 (restart 0) KSP residual norm 3.685129e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.142e-01)
#  Sol. ||E|| = 6.581627e+00 (||RHS|| = 8.166866e-01)
#  Field energy E (1.333e-02 J) + H (4.765e-03 J) = 1.810e-02 J
#  S[1][1] = -8.040e-01-2.733e-01i, |S[1][1]| = -1.420e+00, arg(S[1][1]) = -1.612e+02
#  S[2][1] = +1.731e-01-4.984e-01i, |S[2][1]| = -5.554e+00, arg(S[2][1]) = -7.085e+01
#
#  Wrote fields to disk at step 58
#  Updating solution error estimates
#
# It 59/251: ω/2π = 5.080e+00 GHz (total elapsed time = 1.21e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.636752e-03
#  1 (restart 0) KSP residual norm 1.134192e-03
#  2 (restart 0) KSP residual norm 9.970254e-04
#  3 (restart 0) KSP residual norm 8.856221e-04
#  4 (restart 0) KSP residual norm 3.908276e-04
# ...
#
# It 234/251: ω/2π = 6.830e+00 GHz (total elapsed time = 6.12e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.806512e-03
#  1 (restart 0) KSP residual norm 1.683316e-03
#  2 (restart 0) KSP residual norm 1.630029e-03
#  3 (restart 0) KSP residual norm 1.601479e-03
#  4 (restart 0) KSP residual norm 1.598258e-03
#  5 (restart 0) KSP residual norm 1.016610e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.473e-01)
#  Sol. ||E|| = 5.359605e+00 (||RHS|| = 1.100191e+00)
#  Field energy E (8.793e-03 J) + H (5.616e-03 J) = 1.441e-02 J
#  S[1][1] = -8.757e-01-1.361e-01i, |S[1][1]| = -1.050e+00, arg(S[1][1]) = -1.712e+02
#  S[2][1] = +7.465e-02-4.561e-01i, |S[2][1]| = -6.703e+00, arg(S[2][1]) = -8.071e+01
#
#  Wrote fields to disk at step 234
#  Updating solution error estimates
#
# It 235/251: ω/2π = 6.840e+00 GHz (total elapsed time = 6.15e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.266279e-03
#  1 (restart 0) KSP residual norm 2.223004e-03
#  2 (restart 0) KSP residual norm 2.166019e-03
#  3 (restart 0) KSP residual norm 2.131209e-03
#  4 (restart 0) KSP residual norm 2.121023e-03
#  5 (restart 0) KSP residual norm 1.554351e-03
#  6 (restart 0) KSP residual norm 1.446960e-03
#  7 (restart 0) KSP residual norm 6.459247e-04
# FGMRES solver converged in 7 iterations (avg. reduction factor: 3.454e-01)
#  Sol. ||E|| = 5.341758e+00 (||RHS|| = 1.101802e+00)
#  Field energy E (8.741e-03 J) + H (5.606e-03 J) = 1.435e-02 J
#  S[1][1] = -8.760e-01-1.349e-01i, |S[1][1]| = -1.048e+00, arg(S[1][1]) = -1.712e+02
#  S[2][1] = +7.409e-02-4.558e-01i, |S[2][1]| = -6.712e+00, arg(S[2][1]) = -8.077e+01
#
#  Wrote fields to disk at step 235
#  Updating solution error estimates
#
# It 236/251: ω/2π = 6.850e+00 GHz (total elapsed time = 6.19e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.744787e-03
#  1 (restart 0) KSP residual norm 1.605965e-03
#  2 (restart 0) KSP residual norm 1.497857e-03
#  3 (restart 0) KSP residual norm 1.465620e-03
#  4 (restart 0) KSP residual norm 1.450882e-03
#  5 (restart 0) KSP residual norm 8.418374e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.380e-01)
#  Sol. ||E|| = 5.335975e+00 (||RHS|| = 1.103413e+00)
#  Field energy E (8.723e-03 J) + H (5.606e-03 J) = 1.433e-02 J
#  S[1][1] = -8.763e-01-1.343e-01i, |S[1][1]| = -1.047e+00, arg(S[1][1]) = -1.713e+02
#  S[2][1] = +7.369e-02-4.556e-01i, |S[2][1]| = -6.716e+00, arg(S[2][1]) = -8.081e+01
#
#  Wrote fields to disk at step 236
#  Updating solution error estimates
#
# It 237/251: ω/2π = 6.860e+00 GHz (total elapsed time = 6.22e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.004302e-03
#  1 (restart 0) KSP residual norm 1.962679e-03
#  2 (restart 0) KSP residual norm 1.877905e-03
#  3 (restart 0) KSP residual norm 1.794959e-03
#  4 (restart 0) KSP residual norm 1.749229e-03
#  5 (restart 0) KSP residual norm 1.085017e-03
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.503e-01)
#  Sol. ||E|| = 5.323486e+00 (||RHS|| = 1.105024e+00)
#  Field energy E (8.687e-03 J) + H (5.596e-03 J) = 1.428e-02 J
#  S[1][1] = -8.763e-01-1.334e-01i, |S[1][1]| = -1.047e+00, arg(S[1][1]) = -1.713e+02
#  S[2][1] = +7.340e-02-4.553e-01i, |S[2][1]| = -6.724e+00, arg(S[2][1]) = -8.084e+01
#
#  Wrote fields to disk at step 237
#  Updating solution error estimates
#
# It 238/251: ω/2π = 6.870e+00 GHz (total elapsed time = 6.25e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.243941e-03
#  1 (restart 0) KSP residual norm 2.198994e-03
#  2 (restart 0) KSP residual norm 2.127574e-03
#  3 (restart 0) KSP residual norm 1.926971e-03
#  4 (restart 0) KSP residual norm 1.891727e-03
#  5 (restart 0) KSP residual norm 1.158616e-03
#  6 (restart 0) KSP residual norm 8.797944e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 3.044e-01)
#  Sol. ||E|| = 5.313604e+00 (||RHS|| = 1.106635e+00)
#  Field energy E (8.658e-03 J) + H (5.597e-03 J) = 1.426e-02 J
#  S[1][1] = -8.772e-01-1.326e-01i, |S[1][1]| = -1.040e+00, arg(S[1][1]) = -1.714e+02
#  S[2][1] = +7.250e-02-4.552e-01i, |S[2][1]| = -6.726e+00, arg(S[2][1]) = -8.095e+01
#
#  Wrote fields to disk at step 238
#  Updating solution error estimates
#
# It 239/251: ω/2π = 6.880e+00 GHz (total elapsed time = 6.28e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.991881e-03
#  1 (restart 0) KSP residual norm 1.788570e-03
#  2 (restart 0) KSP residual norm 1.553755e-03
#  3 (restart 0) KSP residual norm 1.341555e-03
#  4 (restart 0) KSP residual norm 1.264754e-03
#  5 (restart 0) KSP residual norm 6.374038e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.249e-01)
#  Sol. ||E|| = 5.308988e+00 (||RHS|| = 1.108245e+00)
#  Field energy E (8.647e-03 J) + H (5.586e-03 J) = 1.423e-02 J
#  S[1][1] = -8.768e-01-1.321e-01i, |S[1][1]| = -1.045e+00, arg(S[1][1]) = -1.714e+02
#  S[2][1] = +7.271e-02-4.552e-01i, |S[2][1]| = -6.727e+00, arg(S[2][1]) = -8.092e+01
#
#  Wrote fields to disk at step 239
#  Updating solution error estimates
#
# It 240/251: ω/2π = 6.890e+00 GHz (total elapsed time = 6.31e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.867108e-03
#  1 (restart 0) KSP residual norm 1.832457e-03
#  2 (restart 0) KSP residual norm 1.775049e-03
#  3 (restart 0) KSP residual norm 1.752538e-03
#  4 (restart 0) KSP residual norm 1.751170e-03
#  5 (restart 0) KSP residual norm 8.334458e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.372e-01)
#  Sol. ||E|| = 5.296575e+00 (||RHS|| = 1.109856e+00)
#  Field energy E (8.611e-03 J) + H (5.583e-03 J) = 1.419e-02 J
#  S[1][1] = -8.772e-01-1.312e-01i, |S[1][1]| = -1.042e+00, arg(S[1][1]) = -1.715e+02
#  S[2][1] = +7.213e-02-4.549e-01i, |S[2][1]| = -6.734e+00, arg(S[2][1]) = -8.099e+01
#
#  Wrote fields to disk at step 240
#  Updating solution error estimates
#
# It 241/251: ω/2π = 6.900e+00 GHz (total elapsed time = 6.34e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.943728e-03
#  1 (restart 0) KSP residual norm 1.906133e-03
#  2 (restart 0) KSP residual norm 1.803247e-03
#  3 (restart 0) KSP residual norm 1.712037e-03
#  4 (restart 0) KSP residual norm 1.664625e-03
#  5 (restart 0) KSP residual norm 9.243774e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.421e-01)
#  Sol. ||E|| = 5.282304e+00 (||RHS|| = 1.111467e+00)
#  Field energy E (8.570e-03 J) + H (5.575e-03 J) = 1.415e-02 J
#  S[1][1] = -8.773e-01-1.301e-01i, |S[1][1]| = -1.042e+00, arg(S[1][1]) = -1.716e+02
#  S[2][1] = +7.172e-02-4.545e-01i, |S[2][1]| = -6.742e+00, arg(S[2][1]) = -8.103e+01
#
#  Wrote fields to disk at step 241
#  Updating solution error estimates
#
# It 242/251: ω/2π = 6.910e+00 GHz (total elapsed time = 6.36e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.967219e-03
#  1 (restart 0) KSP residual norm 1.910650e-03
#  2 (restart 0) KSP residual norm 1.763702e-03
#  3 (restart 0) KSP residual norm 1.627606e-03
#  4 (restart 0) KSP residual norm 1.362605e-03
#  5 (restart 0) KSP residual norm 9.376406e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.427e-01)
#  Sol. ||E|| = 5.276312e+00 (||RHS|| = 1.113078e+00)
#  Field energy E (8.553e-03 J) + H (5.575e-03 J) = 1.413e-02 J
#  S[1][1] = -8.779e-01-1.296e-01i, |S[1][1]| = -1.037e+00, arg(S[1][1]) = -1.716e+02
#  S[2][1] = +7.110e-02-4.546e-01i, |S[2][1]| = -6.743e+00, arg(S[2][1]) = -8.111e+01
#
#  Wrote fields to disk at step 242
#  Updating solution error estimates
#
# It 243/251: ω/2π = 6.920e+00 GHz (total elapsed time = 6.39e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.985409e-03
#  1 (restart 0) KSP residual norm 1.889635e-03
#  2 (restart 0) KSP residual norm 1.592481e-03
#  3 (restart 0) KSP residual norm 1.316723e-03
#  4 (restart 0) KSP residual norm 7.526715e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.612e-01)
#  Sol. ||E|| = 5.264916e+00 (||RHS|| = 1.114689e+00)
#  Field energy E (8.520e-03 J) + H (5.566e-03 J) = 1.409e-02 J
#  S[1][1] = -8.775e-01-1.286e-01i, |S[1][1]| = -1.042e+00, arg(S[1][1]) = -1.717e+02
#  S[2][1] = +7.113e-02-4.541e-01i, |S[2][1]| = -6.751e+00, arg(S[2][1]) = -8.110e+01
#
#  Wrote fields to disk at step 243
#  Updating solution error estimates
#
# It 244/251: ω/2π = 6.930e+00 GHz (total elapsed time = 6.42e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.905660e-03
#  1 (restart 0) KSP residual norm 1.865435e-03
#  2 (restart 0) KSP residual norm 1.692690e-03
#  3 (restart 0) KSP residual norm 1.620932e-03
#  4 (restart 0) KSP residual norm 1.525033e-03
#  5 (restart 0) KSP residual norm 6.562483e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.259e-01)
#  Sol. ||E|| = 5.259730e+00 (||RHS|| = 1.116299e+00)
#  Field energy E (8.505e-03 J) + H (5.568e-03 J) = 1.407e-02 J
#  S[1][1] = -8.783e-01-1.281e-01i, |S[1][1]| = -1.036e+00, arg(S[1][1]) = -1.717e+02
#  S[2][1] = +7.040e-02-4.543e-01i, |S[2][1]| = -6.751e+00, arg(S[2][1]) = -8.119e+01
#
#  Wrote fields to disk at step 244
#  Updating solution error estimates
#
# It 245/251: ω/2π = 6.940e+00 GHz (total elapsed time = 6.44e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.885419e-03
#  1 (restart 0) KSP residual norm 1.847904e-03
#  2 (restart 0) KSP residual norm 1.657404e-03
#  3 (restart 0) KSP residual norm 1.500162e-03
#  4 (restart 0) KSP residual norm 1.347799e-03
#  5 (restart 0) KSP residual norm 9.188169e-04
# FGMRES solver converged in 5 iterations (avg. reduction factor: 2.415e-01)
#  Sol. ||E|| = 5.252278e+00 (||RHS|| = 1.117910e+00)
#  Field energy E (8.484e-03 J) + H (5.563e-03 J) = 1.405e-02 J
#  S[1][1] = -8.782e-01-1.274e-01i, |S[1][1]| = -1.037e+00, arg(S[1][1]) = -1.717e+02
#  S[2][1] = +7.018e-02-4.541e-01i, |S[2][1]| = -6.755e+00, arg(S[2][1]) = -8.121e+01
#
#  Wrote fields to disk at step 245
#  Updating solution error estimates
#
# It 246/251: ω/2π = 6.950e+00 GHz (total elapsed time = 6.47e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.161190e-03
#  1 (restart 0) KSP residual norm 2.146921e-03
#  2 (restart 0) KSP residual norm 2.019576e-03
#  3 (restart 0) KSP residual norm 1.890470e-03
#  4 (restart 0) KSP residual norm 1.704542e-03
#  5 (restart 0) KSP residual norm 1.545923e-03
#  6 (restart 0) KSP residual norm 7.535905e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.960e-01)
#  Sol. ||E|| = 5.241816e+00 (||RHS|| = 1.119521e+00)
#  Field energy E (8.454e-03 J) + H (5.565e-03 J) = 1.402e-02 J
#  S[1][1] = -8.787e-01-1.265e-01i, |S[1][1]| = -1.034e+00, arg(S[1][1]) = -1.718e+02
#  S[2][1] = +6.960e-02-4.538e-01i, |S[2][1]| = -6.761e+00, arg(S[2][1]) = -8.128e+01
#
#  Wrote fields to disk at step 246
#  Updating solution error estimates
#
# It 247/251: ω/2π = 6.960e+00 GHz (total elapsed time = 6.51e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.935290e-03
#  1 (restart 0) KSP residual norm 1.928292e-03
#  2 (restart 0) KSP residual norm 1.749697e-03
#  3 (restart 0) KSP residual norm 1.449703e-03
#  4 (restart 0) KSP residual norm 1.407230e-03
#  5 (restart 0) KSP residual norm 1.160350e-03
#  6 (restart 0) KSP residual norm 5.290953e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.790e-01)
#  Sol. ||E|| = 5.234789e+00 (||RHS|| = 1.121132e+00)
#  Field energy E (8.434e-03 J) + H (5.566e-03 J) = 1.400e-02 J
#  S[1][1] = -8.790e-01-1.257e-01i, |S[1][1]| = -1.032e+00, arg(S[1][1]) = -1.719e+02
#  S[2][1] = +6.912e-02-4.538e-01i, |S[2][1]| = -6.764e+00, arg(S[2][1]) = -8.134e+01
#
#  Wrote fields to disk at step 247
#  Updating solution error estimates
#
# It 248/251: ω/2π = 6.970e+00 GHz (total elapsed time = 6.53e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.733923e-03
#  1 (restart 0) KSP residual norm 1.731253e-03
#  2 (restart 0) KSP residual norm 1.583745e-03
#  3 (restart 0) KSP residual norm 1.329539e-03
#  4 (restart 0) KSP residual norm 7.528860e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.609e-01)
#  Sol. ||E|| = 5.225715e+00 (||RHS|| = 1.122743e+00)
#  Field energy E (8.407e-03 J) + H (5.562e-03 J) = 1.397e-02 J
#  S[1][1] = -8.789e-01-1.249e-01i, |S[1][1]| = -1.034e+00, arg(S[1][1]) = -1.719e+02
#  S[2][1] = +6.890e-02-4.535e-01i, |S[2][1]| = -6.770e+00, arg(S[2][1]) = -8.136e+01
#
#  Wrote fields to disk at step 248
#  Updating solution error estimates
#
# It 249/251: ω/2π = 6.980e+00 GHz (total elapsed time = 6.56e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.934522e-03
#  1 (restart 0) KSP residual norm 1.934396e-03
#  2 (restart 0) KSP residual norm 1.825207e-03
#  3 (restart 0) KSP residual norm 1.639562e-03
#  4 (restart 0) KSP residual norm 1.405947e-03
#  5 (restart 0) KSP residual norm 1.273707e-03
#  6 (restart 0) KSP residual norm 5.958808e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.845e-01)
#  Sol. ||E|| = 5.219860e+00 (||RHS|| = 1.124354e+00)
#  Field energy E (8.391e-03 J) + H (5.565e-03 J) = 1.396e-02 J
#  S[1][1] = -8.795e-01-1.243e-01i, |S[1][1]| = -1.029e+00, arg(S[1][1]) = -1.720e+02
#  S[2][1] = +6.828e-02-4.535e-01i, |S[2][1]| = -6.771e+00, arg(S[2][1]) = -8.144e+01
#
#  Wrote fields to disk at step 249
#  Updating solution error estimates
#
# It 250/251: ω/2π = 6.990e+00 GHz (total elapsed time = 6.59e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 1.800025e-03
#  1 (restart 0) KSP residual norm 1.797764e-03
#  2 (restart 0) KSP residual norm 1.653114e-03
#  3 (restart 0) KSP residual norm 1.333131e-03
#  4 (restart 0) KSP residual norm 9.491361e-04
# FGMRES solver converged in 4 iterations (avg. reduction factor: 1.704e-01)
#  Sol. ||E|| = 5.213766e+00 (||RHS|| = 1.125964e+00)
#  Field energy E (8.373e-03 J) + H (5.559e-03 J) = 1.393e-02 J
#  S[1][1] = -8.793e-01-1.236e-01i, |S[1][1]| = -1.032e+00, arg(S[1][1]) = -1.720e+02
#  S[2][1] = +6.820e-02-4.533e-01i, |S[2][1]| = -6.776e+00, arg(S[2][1]) = -8.144e+01
#
#  Wrote fields to disk at step 250
#  Updating solution error estimates
#
# It 251/251: ω/2π = 7.000e+00 GHz (total elapsed time = 6.62e+02 s)
#
#  Residual norms for FGMRES solve
#  0 (restart 0) KSP residual norm 2.220884e-03
#  1 (restart 0) KSP residual norm 2.214181e-03
#  2 (restart 0) KSP residual norm 2.159547e-03
#  3 (restart 0) KSP residual norm 1.904790e-03
#  4 (restart 0) KSP residual norm 1.766022e-03
#  5 (restart 0) KSP residual norm 1.377738e-03
#  6 (restart 0) KSP residual norm 6.499581e-04
# FGMRES solver converged in 6 iterations (avg. reduction factor: 2.885e-01)
#  Sol. ||E|| = 5.201631e+00 (||RHS|| = 1.127575e+00)
#  Field energy E (8.338e-03 J) + H (5.564e-03 J) = 1.390e-02 J
#  S[1][1] = -8.798e-01-1.225e-01i, |S[1][1]| = -1.028e+00, arg(S[1][1]) = -1.721e+02
#  S[2][1] = +6.749e-02-4.530e-01i, |S[2][1]| = -6.783e+00, arg(S[2][1]) = -8.153e+01
#
#  Wrote fields to disk at step 251
#  Updating solution error estimates
# WARNING:py.warnings:ComplexWarning: Casting complex values to real discards the imaginary part
#  /opt/homebrew/anaconda3/envs/sqdmetal_env/lib/python3.11/site-packages/matplotlib/cbook/__init__.py: 1335
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 9.107e-01, global unknowns = 53804
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.028       0.031       0.030
#   Mesh Preprocessing             0.700       0.700       0.700
# Operator Construction            2.688       2.886       2.800
# Linear Solve                    26.266      26.450      26.343
#   Setup                         32.707      32.872      32.789
#   Preconditioner                85.025      85.230      85.138
# Estimation                       1.870       2.074       1.986
#   Construction                   0.538       0.539       0.538
#   Solve                        407.675     407.798     407.757
# Postprocessing                  11.668      12.398      11.754
# Disk IO                         97.368      98.083      97.980
# --------------------------------------------------------------
# Total                          667.846     667.874     667.859
